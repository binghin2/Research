# %%
from copy import deepcopy
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Dict, List, Optional, Tuple

import json
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset


TASKS = ["Baseline", "Logic", "Nback", "Stroop", "Sudoku"]
STRESS_TASKS = {"Logic", "Nback", "Stroop", "Sudoku"}


@dataclass
class HyperParameters:
    random_seed: int = 42
    val_ratio: float = 0.1
    min_val_subjects: int = 4
    max_val_subjects: int = 5

    window_size: int = 60
    stride: int = 10
    hrv_window: int = 30

    batch_size: int = 64
    epochs: int = 50
    learning_rate: float = 1e-3
    dropout_rate: float = 0.3
    weight_decay: float = 1e-4
    patience: int = 8

    transformer_heads: int = 8
    transformer_layers: int = 2
    transformer_ff_dim: int = 256
    transformer_dropout: float = 0.1

    # subject-wise zscore | baseline zscore | none
    normalization_mode: str = "subject_zscore"

    # focal | weighted_bce
    loss_name: str = "focal"
    focal_gamma: float = 2.0
    focal_alpha: Optional[float] = None
    save_model: bool = True

    # 개발/디버깅용: None이면 전체 LOSO fold 수행
    max_folds: Optional[int] = None


def find_dataset_root() -> Path:
    cwd = Path.cwd().resolve()
    for base in [cwd, *cwd.parents]:
        candidate = base / "Dataset" / "CATSA"
        if candidate.exists():
            return candidate

    fallback = Path("/home/binghin2/Myproject/Dataset/CATSA")
    if fallback.exists():
        return fallback

    raise FileNotFoundError("Could not find Dataset/CATSA. Please set dataset_root manually.")


def discover_complete_subjects(dataset_root: Path) -> List[str]:
    subjects: List[str] = []
    for subject_dir in sorted(dataset_root.glob("Sub*"), key=lambda p: int(p.name[3:])):
        if not subject_dir.is_dir():
            continue
        has_all = all((subject_dir / task / "HR.csv").exists() for task in TASKS)
        if has_all:
            subjects.append(subject_dir.name)
    return subjects


def read_hr_csv(file_path: Path) -> np.ndarray:
    df = pd.read_csv(file_path)
    numeric_cols = [c for c in df.columns if pd.api.types.is_numeric_dtype(df[c])]
    if numeric_cols:
        values = df[numeric_cols[0]].to_numpy(dtype=np.float32)
    else:
        values = pd.to_numeric(df.iloc[:, 0], errors="coerce").to_numpy(dtype=np.float32)
    values = values[~np.isnan(values)]
    if len(values) == 0:
        raise ValueError(f"No valid HR values in {file_path}")
    return values


def detect_hrv_from_hr(hr: np.ndarray, hrv_window: int = 30) -> np.ndarray:
    hr = np.asarray(hr, dtype=np.float32)
    hr = np.clip(hr, 30.0, 220.0)

    rr_ms = 60000.0 / hr
    drr = np.diff(rr_ms, prepend=rr_ms[0])

    w = max(3, int(hrv_window))
    kernel = np.ones(w, dtype=np.float32) / float(w)

    rmssd_local = np.sqrt(np.convolve(drr * drr, kernel, mode="same") + 1e-8)

    rr_mean = np.convolve(rr_ms, kernel, mode="same")
    rr_sq_mean = np.convolve(rr_ms * rr_ms, kernel, mode="same")
    sdnn_local = np.sqrt(np.maximum(rr_sq_mean - rr_mean * rr_mean, 0.0) + 1e-8)

    hrv_signal = 0.5 * rmssd_local + 0.5 * sdnn_local
    return hrv_signal.astype(np.float32)


def sliding_windows(signal: np.ndarray, window_size: int, stride: int) -> np.ndarray:
    if len(signal) < window_size:
        return np.empty((0, window_size), dtype=np.float32)
    windows = [signal[i:i + window_size] for i in range(0, len(signal) - window_size + 1, stride)]
    return np.asarray(windows, dtype=np.float32)


def compute_subject_stats(
    sub_path: Path,
    hrv_window: int,
    use_baseline_as_non_stress: bool,
    use_stress_tasks_only: bool,
) -> Tuple[float, float, float, float]:
    if use_stress_tasks_only:
        candidate_tasks = [t for t in TASKS if t in STRESS_TASKS]
    else:
        candidate_tasks = TASKS.copy()

    hr_values_list: List[np.ndarray] = []
    hrv_values_list: List[np.ndarray] = []
    for task in candidate_tasks:
        if task == "Baseline" and not use_baseline_as_non_stress:
            continue
        hr_raw = read_hr_csv(sub_path / task / "HR.csv")
        hrv_raw = detect_hrv_from_hr(hr_raw, hrv_window=hrv_window)
        hr_values_list.append(hr_raw)
        hrv_values_list.append(hrv_raw)

    all_hr = np.concatenate(hr_values_list, axis=0)
    all_hrv = np.concatenate(hrv_values_list, axis=0)

    hr_mean = float(np.mean(all_hr))
    hr_std = float(np.std(all_hr)) + 1e-8
    hrv_mean = float(np.mean(all_hrv))
    hrv_std = float(np.std(all_hrv)) + 1e-8
    return hr_mean, hr_std, hrv_mean, hrv_std


def build_split_arrays(
    dataset_root: Path,
    subject_list: List[str],
    window_size: int,
    stride: int,
    hrv_window: int,
    normalization_mode: str = "subject_zscore",
    use_baseline_as_non_stress: bool = True,
    use_stress_tasks_only: bool = False,
) -> Tuple[np.ndarray, np.ndarray]:
    x_chunks: List[np.ndarray] = []
    y_chunks: List[np.ndarray] = []

    for sub in subject_list:
        sub_path = dataset_root / sub

        if use_stress_tasks_only:
            candidate_tasks = [t for t in TASKS if t in STRESS_TASKS]
        else:
            candidate_tasks = TASKS.copy()

        baseline_hr = read_hr_csv(sub_path / "Baseline" / "HR.csv")
        baseline_hrv = detect_hrv_from_hr(baseline_hr, hrv_window=hrv_window)

        baseline_hr_mean = float(np.mean(baseline_hr))
        baseline_hr_std = float(np.std(baseline_hr)) + 1e-8
        baseline_hrv_mean = float(np.mean(baseline_hrv))
        baseline_hrv_std = float(np.std(baseline_hrv)) + 1e-8

        hr_mean, hr_std, hrv_mean, hrv_std = compute_subject_stats(
            sub_path,
            hrv_window=hrv_window,
            use_baseline_as_non_stress=use_baseline_as_non_stress,
            use_stress_tasks_only=use_stress_tasks_only,
        )

        for task in candidate_tasks:
            if task == "Baseline" and not use_baseline_as_non_stress:
                continue

            hr_raw = read_hr_csv(sub_path / task / "HR.csv")
            hrv_raw = detect_hrv_from_hr(hr_raw, hrv_window=hrv_window)

            if normalization_mode == "subject_zscore":
                hr_norm = (hr_raw - hr_mean) / hr_std
                hrv_norm = (hrv_raw - hrv_mean) / hrv_std
            elif normalization_mode == "baseline_zscore":
                hr_norm = (hr_raw - baseline_hr_mean) / baseline_hr_std
                hrv_norm = (hrv_raw - baseline_hrv_mean) / baseline_hrv_std
            elif normalization_mode == "none":
                hr_norm = hr_raw
                hrv_norm = hrv_raw
            else:
                raise ValueError(f"Unknown normalization_mode: {normalization_mode}")

            hr_windows = sliding_windows(hr_norm, window_size=window_size, stride=stride)
            hrv_windows = sliding_windows(hrv_norm, window_size=window_size, stride=stride)
            if len(hr_windows) == 0 or len(hrv_windows) == 0:
                continue

            n = min(len(hr_windows), len(hrv_windows))
            x_pair = np.stack([hr_windows[:n], hrv_windows[:n]], axis=1)  # [N, 2, W]

            label = 1 if task in STRESS_TASKS else 0
            labels = np.full((n,), label, dtype=np.int64)
            x_chunks.append(x_pair)
            y_chunks.append(labels)

    if not x_chunks:
        raise ValueError("No samples generated. Check data files or window settings.")

    x = np.concatenate(x_chunks, axis=0)
    y = np.concatenate(y_chunks, axis=0)
    return x.astype(np.float32), y.astype(np.int64)


def build_loso_folds(subjects: List[str], hp: HyperParameters) -> List[Dict[str, List[str]]]:
    folds: List[Dict[str, List[str]]] = []
    for fold_idx, test_subject in enumerate(subjects):
        remaining = [s for s in subjects if s != test_subject]

        val_count = int(round(len(remaining) * hp.val_ratio))
        val_count = max(hp.min_val_subjects, val_count)
        val_count = min(hp.max_val_subjects, val_count)
        val_count = min(val_count, len(remaining) - 1)

        rng = np.random.default_rng(hp.random_seed + fold_idx)
        shuffled = remaining.copy()
        rng.shuffle(shuffled)

        val_subjects = sorted(shuffled[:val_count], key=lambda x: int(x[3:]))
        train_subjects = sorted(shuffled[val_count:], key=lambda x: int(x[3:]))

        folds.append({
            "train": train_subjects,
            "val": val_subjects,
            "test": [test_subject],
        })

    return folds


class HRHRV1DCNNTransformer(nn.Module):
    def __init__(self, hp: HyperParameters):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv1d(2, 32, kernel_size=5, padding=2),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(2),
            nn.Conv1d(32, 64, kernel_size=5, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(2),
            nn.Conv1d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
        )

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=128,
            nhead=hp.transformer_heads,
            dim_feedforward=hp.transformer_ff_dim,
            dropout=hp.transformer_dropout,
            batch_first=True,
            activation="gelu",
        )
        self.transformer = nn.TransformerEncoder(
            encoder_layer,
            num_layers=hp.transformer_layers,
        )

        self.max_len = max(16, hp.window_size)
        self.pos_embedding = nn.Parameter(torch.zeros(1, self.max_len, 128))

        self.classifier = nn.Sequential(
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(hp.dropout_rate),
            nn.Linear(64, 1),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.cnn(x)
        x = x.transpose(1, 2)  # [B, L, C]

        seq_len = x.size(1)
        if seq_len > self.pos_embedding.size(1):
            pos = nn.functional.interpolate(
                self.pos_embedding.transpose(1, 2),
                size=seq_len,
                mode="linear",
                align_corners=False,
            ).transpose(1, 2)
        else:
            pos = self.pos_embedding[:, :seq_len, :]

        x = x + pos
        x = self.transformer(x)
        x = x.mean(dim=1)
        return self.classifier(x).squeeze(1)


class BinaryFocalLossWithLogits(nn.Module):
    def __init__(self, gamma: float = 2.0, alpha: Optional[float] = None, pos_weight: Optional[torch.Tensor] = None):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha
        if pos_weight is not None:
            self.register_buffer("pos_weight", pos_weight)
        else:
            self.pos_weight = None

    def forward(self, logits: torch.Tensor, targets: torch.Tensor) -> torch.Tensor:
        targets = targets.float()
        bce = F.binary_cross_entropy_with_logits(
            logits,
            targets,
            reduction="none",
            pos_weight=self.pos_weight,
        )
        probs = torch.sigmoid(logits)
        pt = probs * targets + (1.0 - probs) * (1.0 - targets)
        focal_factor = (1.0 - pt).pow(self.gamma)

        if self.alpha is not None:
            alpha_t = self.alpha * targets + (1.0 - self.alpha) * (1.0 - targets)
            loss = alpha_t * focal_factor * bce
        else:
            loss = focal_factor * bce

        return loss.mean()


def compute_pos_weight(y: np.ndarray) -> torch.Tensor:
    pos = float(np.sum(y == 1))
    neg = float(np.sum(y == 0))
    if pos == 0:
        return torch.tensor([1.0], dtype=torch.float32)
    return torch.tensor([neg / pos], dtype=torch.float32)


def make_criterion(y_train: np.ndarray, hp: HyperParameters, device: torch.device) -> Tuple[nn.Module, Dict[str, object]]:
    pos_weight = compute_pos_weight(y_train).to(device)

    if hp.loss_name == "weighted_bce":
        return nn.BCEWithLogitsLoss(pos_weight=pos_weight), {
            "loss_name": "weighted_bce",
            "pos_weight": float(pos_weight.item()),
            "focal_gamma": 0.0,
            "focal_alpha": 0.0,
        }

    if hp.loss_name == "focal":
        pos = float(np.sum(y_train == 1))
        neg = float(np.sum(y_train == 0))
        alpha = hp.focal_alpha
        if alpha is None:
            alpha = neg / max(pos + neg, 1.0)

        criterion = BinaryFocalLossWithLogits(
            gamma=hp.focal_gamma,
            alpha=float(alpha),
            pos_weight=None,
        )
        return criterion, {
            "loss_name": "focal",
            "pos_weight": 1.0,
            "focal_gamma": float(hp.focal_gamma),
            "focal_alpha": float(alpha),
            "weighting_note": "Focal uses alpha only to avoid duplicate class weighting",
        }

    raise ValueError(f"Unknown loss_name: {hp.loss_name}")


def make_loader(x: np.ndarray, y: np.ndarray, batch_size: int, shuffle: bool) -> DataLoader:
    ds = TensorDataset(torch.from_numpy(x), torch.from_numpy(y).float())
    return DataLoader(ds, batch_size=batch_size, shuffle=shuffle)


@torch.no_grad()
def evaluate(model: nn.Module, loader: DataLoader, criterion: nn.Module, device: torch.device) -> Dict[str, float]:
    model.eval()
    total_loss = 0.0
    total = 0
    tp = tn = fp = fn = 0

    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)
        logits = model(xb)
        loss = criterion(logits, yb)

        total_loss += float(loss.item()) * xb.size(0)
        total += xb.size(0)

        preds = (torch.sigmoid(logits) >= 0.5).long()
        y_int = yb.long()

        tp += int(((preds == 1) & (y_int == 1)).sum().item())
        tn += int(((preds == 0) & (y_int == 0)).sum().item())
        fp += int(((preds == 1) & (y_int == 0)).sum().item())
        fn += int(((preds == 0) & (y_int == 1)).sum().item())

    acc = (tp + tn) / max(total, 1)
    precision = tp / max(tp + fp, 1)
    recall = tp / max(tp + fn, 1)
    f1 = 2 * precision * recall / max(precision + recall, 1e-8)

    return {
        "loss": total_loss / max(total, 1),
        "accuracy": acc,
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "tn": float(tn),
        "fp": float(fp),
        "fn": float(fn),
        "tp": float(tp),
    }


def train_one_epoch(
    model: nn.Module,
    loader: DataLoader,
    optimizer: torch.optim.Optimizer,
    criterion: nn.Module,
    device: torch.device,
    clip_grad: float = 1.0,
) -> float:
    model.train()
    total_loss = 0.0
    total = 0

    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)

        optimizer.zero_grad(set_to_none=True)
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_grad)
        optimizer.step()

        total_loss += float(loss.item()) * xb.size(0)
        total += xb.size(0)

    return total_loss / max(total, 1)


def run_loso_training(
    model_name: str = "hr_hrv_1dcnn_transformer_loso_torch",
    hp: HyperParameters = HyperParameters(),
) -> Dict[str, object]:
    np.random.seed(hp.random_seed)
    torch.manual_seed(hp.random_seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(hp.random_seed)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    dataset_root = find_dataset_root()

    save_dir = Path.cwd() / "Save_model" / "LOSO"
    save_dir.mkdir(parents=True, exist_ok=True)

    subjects = discover_complete_subjects(dataset_root)
    folds = build_loso_folds(subjects, hp)
    if hp.max_folds is not None:
        folds = folds[: hp.max_folds]

    fold_results: List[Dict[str, object]] = []

    for fold_idx, split in enumerate(folds, start=1):
        test_subject = split["test"][0]
        print(f"\n=== Fold {fold_idx}/{len(folds)} | Test: {test_subject} ===")
        print(f"Train subjects: {len(split['train'])}, Val subjects: {len(split['val'])}, Test subjects: 1")

        x_train, y_train = build_split_arrays(
            dataset_root,
            split["train"],
            hp.window_size,
            hp.stride,
            hp.hrv_window,
            normalization_mode=hp.normalization_mode,
        )
        x_val, y_val = build_split_arrays(
            dataset_root,
            split["val"],
            hp.window_size,
            hp.stride,
            hp.hrv_window,
            normalization_mode=hp.normalization_mode,
        )
        x_test, y_test = build_split_arrays(
            dataset_root,
            split["test"],
            hp.window_size,
            hp.stride,
            hp.hrv_window,
            normalization_mode=hp.normalization_mode,
        )

        train_loader = make_loader(x_train, y_train, hp.batch_size, shuffle=True)
        val_loader = make_loader(x_val, y_val, hp.batch_size, shuffle=False)
        test_loader = make_loader(x_test, y_test, hp.batch_size, shuffle=False)

        model = HRHRV1DCNNTransformer(hp=hp).to(device)
        criterion, loss_cfg = make_criterion(y_train, hp, device)
        optimizer = torch.optim.Adam(
            model.parameters(),
            lr=hp.learning_rate,
            weight_decay=hp.weight_decay,
        )
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode="min", factor=0.5, patience=4
        )

        best_val_loss = float("inf")
        best_epoch = -1
        wait = 0
        history_rows: List[Dict[str, float]] = []
        best_state_dict = None
        fold_tag = f"fold_{fold_idx:02d}_{test_subject}"
        best_model_path = save_dir / f"{model_name}_{fold_tag}_best.pt"
        final_model_path = save_dir / f"{model_name}_{fold_tag}.pt"

        for epoch in range(1, hp.epochs + 1):
            train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
            val_metrics = evaluate(model, val_loader, criterion, device)
            scheduler.step(val_metrics["loss"])
            history_rows.append({"epoch": float(epoch), "train_loss": float(train_loss), "val_loss": float(val_metrics["loss"]), "val_accuracy": float(val_metrics["accuracy"]), "val_f1": float(val_metrics["f1"]), "lr": float(optimizer.param_groups[0]["lr"])})

            if val_metrics["loss"] < best_val_loss:
                best_val_loss = val_metrics["loss"]
                best_epoch = epoch
                wait = 0
                best_state_dict = deepcopy(model.state_dict())
                if hp.save_model:
                    torch.save(
                        {
                            "model_state_dict": best_state_dict,
                            "hyperparameters": asdict(hp),
                            "model_name": model_name,
                            "fold_index": fold_idx,
                            "test_subject": test_subject,
                            "best_epoch": best_epoch,
                            "best_val_loss": best_val_loss,
                        },
                        best_model_path,
                    )
            else:
                wait += 1
                if wait >= hp.patience:
                    print(f"Early stopping at epoch {epoch} (best epoch: {best_epoch})")
                    break

        if best_state_dict is not None:
            model.load_state_dict(best_state_dict)

        test_metrics = evaluate(model, test_loader, criterion, device)

        if hp.save_model:
            torch.save(
                {
                    "model_state_dict": model.state_dict(),
                    "hyperparameters": asdict(hp),
                    "model_name": model_name,
                    "fold_index": fold_idx,
                    "test_subject": test_subject,
                    "best_epoch": best_epoch,
                    "best_val_loss": best_val_loss,
                    "test_metrics": {k: float(v) for k, v in test_metrics.items()},
                },
                final_model_path,
            )

        fold_result = {
            "fold_index": fold_idx,
            "test_subject": test_subject,
            "split": split,
            "sample_shapes": {
                "x_train": list(x_train.shape),
                "x_val": list(x_val.shape),
                "x_test": list(x_test.shape),
            },
            "class_distribution": {
                "train": {"non_stress": int(np.sum(y_train == 0)), "stress": int(np.sum(y_train == 1))},
                "val": {"non_stress": int(np.sum(y_val == 0)), "stress": int(np.sum(y_val == 1))},
                "test": {"non_stress": int(np.sum(y_test == 0)), "stress": int(np.sum(y_test == 1))},
            },
            "best_epoch": int(best_epoch),
            "best_val_loss": float(best_val_loss),
            "test_metrics": {k: float(v) for k, v in test_metrics.items()},
            "normalization_mode": hp.normalization_mode,
            "loss_config": loss_cfg,
            "hrv_window": int(hp.hrv_window),
            "history": history_rows,
            "model_saved": bool(hp.save_model),
            "model_files": {
                "best_model": str(best_model_path) if hp.save_model else None,
                "final_model": str(final_model_path) if hp.save_model else None,
            },
        }
        fold_results.append(fold_result)

        print(
            "Fold test metrics:",
            {
                "accuracy": round(float(test_metrics["accuracy"]), 4),
                "f1": round(float(test_metrics["f1"]), 4),
                "loss": round(float(test_metrics["loss"]), 4),
            },
        )

    summary_df = pd.DataFrame([
        {
            "fold_index": fr["fold_index"],
            "test_subject": fr["test_subject"],
            "accuracy": fr["test_metrics"]["accuracy"],
            "precision": fr["test_metrics"]["precision"],
            "recall": fr["test_metrics"]["recall"],
            "f1": fr["test_metrics"]["f1"],
            "loss": fr["test_metrics"]["loss"],
        }
        for fr in fold_results
    ])

    metric_cols = ["accuracy", "precision", "recall", "f1", "loss"]
    agg_mean = summary_df[metric_cols].mean().to_dict() if len(summary_df) else {}
    agg_std = summary_df[metric_cols].std(ddof=0).to_dict() if len(summary_df) else {}

    metadata = {
        "created_at": datetime.now().isoformat(),
        "model_name": model_name,
        "model_type": "2-channel (HR + detected HRV) 1D CNN + Transformer (PyTorch, LOSO)",
        "dataset_root": str(dataset_root),
        "label_definition": {
            "non_stress": ["Baseline"],
            "stress": ["Logic", "Nback", "Stroop", "Sudoku"],
        },
        "split_rule": "LOSO: 1 test subject + ~10% of remaining (4~5) for validation",
        "total_complete_subjects": len(subjects),
        "num_folds_run": len(fold_results),
        "hyperparameters": asdict(hp),
        "aggregate_metrics": {
            "mean": {k: float(v) for k, v in agg_mean.items()},
            "std": {k: float(v) for k, v in agg_std.items()},
        },
        "fold_results": fold_results,
        "device": str(device),
    }

    metadata_path = save_dir / f"{model_name}_hyperparameters.json"
    with metadata_path.open("w", encoding="utf-8") as f:
        json.dump(metadata, f, ensure_ascii=False, indent=2)

    print("\n=== LOSO Training Complete ===")
    print(f"Saved metadata (hyperparameters + metrics): {metadata_path}")
    if hp.save_model:
        print("Saved per-fold best/final checkpoints under LOSO save_dir")
    if agg_mean:
        print("Aggregate mean metrics:", {k: round(float(v), 4) for k, v in agg_mean.items()})
        print("Aggregate std metrics:", {k: round(float(v), 4) for k, v in agg_std.items()})

    return metadata


# ===== 실행 파트 =====
hp = HyperParameters(
    random_seed=42,
    val_ratio=0.1,
    min_val_subjects=4,
    max_val_subjects=5,
    window_size=60,
    stride=10,
    hrv_window=30,
    batch_size=64,
    epochs=50,
    learning_rate=1e-3,
    dropout_rate=0.3,
    weight_decay=1e-4,
    patience=8,
    transformer_heads=8,
    transformer_layers=2,
    transformer_ff_dim=256,
    transformer_dropout=0.1,
    normalization_mode="subject_zscore",
    loss_name="focal",
    focal_gamma=2.0,
    focal_alpha=None,
    save_model=True,
    max_folds=None,  # 빠른 테스트 시 정수로 제한 가능 (예: 3)
)

result_loso = run_loso_training(model_name="hr_hrv_1dcnn_transformer_loso_torch", hp=hp)
result_loso
# Out:
# === Fold 1/50 | Test: Sub1 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 24 (best epoch: 16)
# Fold test metrics: {'accuracy': 0.4688, 'f1': 0.6383, 'loss': 0.1299}
#
# === Fold 2/50 | Test: Sub2 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 27 (best epoch: 19)
# Fold test metrics: {'accuracy': 0.9692, 'f1': 0.9804, 'loss': 0.0264}
#
# === Fold 3/50 | Test: Sub3 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.5538, 'f1': 0.701, 'loss': 0.0598}
#
# === Fold 4/50 | Test: Sub4 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.7385, 'f1': 0.8132, 'loss': 0.046}
#
# === Fold 5/50 | Test: Sub5 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.2923, 'f1': 0.4524, 'loss': 0.0907}
#
# === Fold 6/50 | Test: Sub6 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 20 (best epoch: 12)
# Fold test metrics: {'accuracy': 0.6769, 'f1': 0.7586, 'loss': 0.0426}
#
# === Fold 7/50 | Test: Sub7 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 33 (best epoch: 25)
# Fold test metrics: {'accuracy': 0.8923, 'f1': 0.9293, 'loss': 0.0377}
#
# === Fold 8/50 | Test: Sub8 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 44 (best epoch: 36)
# Fold test metrics: {'accuracy': 0.5846, 'f1': 0.7097, 'loss': 0.0744}
#
# === Fold 9/50 | Test: Sub9 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8696, 'loss': 0.0347}
#
# === Fold 10/50 | Test: Sub10 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.8308, 'f1': 0.8866, 'loss': 0.0355}
#
# === Fold 11/50 | Test: Sub11 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 18 (best epoch: 10)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8696, 'loss': 0.0305}
#
# === Fold 12/50 | Test: Sub12 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.6615, 'f1': 0.7609, 'loss': 0.0484}
#
# === Fold 13/50 | Test: Sub13 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.875, 'f1': 0.9167, 'loss': 0.0349}
#
# === Fold 14/50 | Test: Sub14 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.3385, 'f1': 0.5057, 'loss': 0.096}
#
# === Fold 15/50 | Test: Sub15 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 19 (best epoch: 11)
# Fold test metrics: {'accuracy': 0.6308, 'f1': 0.75, 'loss': 0.0513}
#
# === Fold 16/50 | Test: Sub16 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 22 (best epoch: 14)
# Fold test metrics: {'accuracy': 0.625, 'f1': 0.7143, 'loss': 0.0517}
#
# === Fold 17/50 | Test: Sub17 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.7231, 'f1': 0.8163, 'loss': 0.05}
#
# === Fold 18/50 | Test: Sub18 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.8571, 'loss': 0.028}
#
# === Fold 19/50 | Test: Sub20 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Fold test metrics: {'accuracy': 0.6923, 'f1': 0.7619, 'loss': 0.0369}
#
# === Fold 20/50 | Test: Sub21 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 39 (best epoch: 31)
# Fold test metrics: {'accuracy': 0.8615, 'f1': 0.9091, 'loss': 0.0349}
#
# === Fold 21/50 | Test: Sub22 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.7231, 'f1': 0.8, 'loss': 0.0401}
#
# === Fold 22/50 | Test: Sub23 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.5781, 'f1': 0.64, 'loss': 0.0461}
#
# === Fold 23/50 | Test: Sub24 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 33 (best epoch: 25)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0165}
#
# === Fold 24/50 | Test: Sub26 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.6615, 'f1': 0.75, 'loss': 0.0427}
#
# === Fold 25/50 | Test: Sub27 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.4769, 'f1': 0.6304, 'loss': 0.0642}
#
# === Fold 26/50 | Test: Sub28 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 27 (best epoch: 19)
# Fold test metrics: {'accuracy': 0.7846, 'f1': 0.86, 'loss': 0.0533}
#
# === Fold 27/50 | Test: Sub29 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 26 (best epoch: 18)
# Fold test metrics: {'accuracy': 0.5231, 'f1': 0.6517, 'loss': 0.0575}
#
# === Fold 28/50 | Test: Sub30 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 32 (best epoch: 24)
# Fold test metrics: {'accuracy': 0.6769, 'f1': 0.8, 'loss': 0.062}
#
# === Fold 29/50 | Test: Sub31 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 28 (best epoch: 20)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0124}
#
# === Fold 30/50 | Test: Sub32 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8966, 'loss': 0.0555}
#
# === Fold 31/50 | Test: Sub33 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.5538, 'f1': 0.7129, 'loss': 0.076}
#
# === Fold 32/50 | Test: Sub34 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.9846, 'f1': 0.9903, 'loss': 0.034}
#
# === Fold 33/50 | Test: Sub35 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.8769, 'f1': 0.9167, 'loss': 0.0353}
#
# === Fold 34/50 | Test: Sub36 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.7969, 'f1': 0.8539, 'loss': 0.034}
#
# === Fold 35/50 | Test: Sub37 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 17 (best epoch: 9)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0271}
#
# === Fold 36/50 | Test: Sub38 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 42 (best epoch: 34)
# Fold test metrics: {'accuracy': 0.4615, 'f1': 0.6316, 'loss': 0.1073}
#
# === Fold 37/50 | Test: Sub40 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.6, 'f1': 0.6977, 'loss': 0.0558}
#
# === Fold 38/50 | Test: Sub41 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.4615, 'f1': 0.5783, 'loss': 0.0628}
#
# === Fold 39/50 | Test: Sub42 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.4154, 'f1': 0.587, 'loss': 0.0819}
#
# === Fold 40/50 | Test: Sub43 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 24 (best epoch: 16)
# Fold test metrics: {'accuracy': 0.5077, 'f1': 0.6098, 'loss': 0.0588}
#
# === Fold 41/50 | Test: Sub44 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 50 (best epoch: 42)
# Fold test metrics: {'accuracy': 0.5692, 'f1': 0.7021, 'loss': 0.0885}
#
# === Fold 42/50 | Test: Sub45 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.8462, 'f1': 0.8936, 'loss': 0.0305}
#
# === Fold 43/50 | Test: Sub46 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.6615, 'f1': 0.766, 'loss': 0.0481}
#
# === Fold 44/50 | Test: Sub47 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 28 (best epoch: 20)
# Fold test metrics: {'accuracy': 0.7538, 'f1': 0.8298, 'loss': 0.0406}
#
# === Fold 45/50 | Test: Sub48 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8947, 'loss': 0.0572}
#
# === Fold 46/50 | Test: Sub49 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.6154, 'f1': 0.7475, 'loss': 0.061}
#
# === Fold 47/50 | Test: Sub50 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 46 (best epoch: 38)
# Fold test metrics: {'accuracy': 0.5231, 'f1': 0.6076, 'loss': 0.0533}
#
# === Fold 48/50 | Test: Sub51 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.8571, 'loss': 0.0427}
#
# === Fold 49/50 | Test: Sub52 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.9385, 'f1': 0.96, 'loss': 0.0295}
#
# === Fold 50/50 | Test: Sub53 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.5538, 'f1': 0.6667, 'loss': 0.0715}
#
# === LOSO Training Complete ===
# Saved metadata (hyperparameters + metrics): /home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_hyperparameters.json
# Saved per-fold best/final checkpoints under LOSO save_dir
# Aggregate mean metrics: {'accuracy': 0.6964, 'precision': 0.8817, 'recall': 0.7147, 'f1': 0.7826, 'loss': 0.0517}
# Aggregate std metrics: {'accuracy': 0.1775, 'precision': 0.1138, 'recall': 0.1669, 'f1': 0.1345, 'loss': 0.0229}
# {'created_at': '2026-04-21T20:08:39.633471',
#  'model_name': 'hr_hrv_1dcnn_transformer_loso_torch',
#  'model_type': '2-channel (HR + detected HRV) 1D CNN + Transformer (PyTorch, LOSO)',
#  'dataset_root': '/home/binghin2/Myproject/Dataset/CATSA',
#  'label_definition': {'non_stress': ['Baseline'],
#   'stress': ['Logic', 'Nback', 'Stroop', 'Sudoku']},
#  'split_rule': 'LOSO: 1 test subject + ~10% of remaining (4~5) for validation',
#  'total_complete_subjects': 50,
#  'num_folds_run': 50,
#  'hyperparameters': {'random_seed': 42,
#   'val_ratio': 0.1,
#   'min_val_subjects': 4,
#   'max_val_subjects': 5,
#   'window_size': 60,
#   'stride': 10,
#   'hrv_window': 30,
#   'batch_size': 64,
#   'epochs': 50,
#   'learning_rate': 0.001,
#   'dropout_rate': 0.3,
#   'weight_decay': 0.0001,
#   'patience': 8,
#   'transformer_heads': 8,
#   'transformer_layers': 2,
#   'transformer_ff_dim': 256,
#   'transformer_dropout': 0.1,
#   'normalization_mode': 'subject_zscore',
#   'loss_name': 'focal',
#   'focal_gamma': 2.0,
#   'focal_alpha': None,
#   'save_model': True,
#   'max_folds': None},
#  'aggregate_metrics': {'mean': {'accuracy': 0.6964134615384614,
#    'precision': 0.8816580552906315,
#    'recall': 0.7147134238310707,
#    'f1': 0.7826492123096992,
#    'loss': 0.051730615680894015},
#   'std': {'accuracy': 0.17750451750647672,
#    'precision': 0.11381328320807622,
#    'recall': 0.1669140566503839,
#    'f1': 0.13446995244805035,
#    'loss': 0.022866866905523846}},
#  'fold_results': [{'fold_index': 1,
#    'test_subject': 'Sub1',
#    'split': {'train': ['Sub2',
#      'Sub3',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub37',
#      'Sub38',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub7', 'Sub27', 'Sub36', 'Sub43', 'Sub51'],
#     'test': ['Sub1']},
#    'sample_shapes': {'x_train': [2856, 2, 60],
#     'x_val': [324, 2, 60],
#     'x_test': [64, 2, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2284},
#     'val': {'non_stress': 65, 'stress': 259},
#     'test': {'non_stress': 13, 'stress': 51}},
#    'best_epoch': 16,
#    'best_val_loss': 0.04557840695121774,
#    'test_metrics': {'loss': 0.12987369298934937,
#     'accuracy': 0.46875,
#     'precision': 0.6976744186046512,
#     'recall': 0.5882352941176471,
#     'f1': 0.6382978723404256,
#     'tn': 0.0,
#     'fp': 13.0,
#     'fn': 21.0,
#     'tp': 30.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20028011204481794,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'hrv_window': 30,
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.051066314712876364,
#      'val_loss': 0.053202797601252426,
#      'val_accuracy': 0.7407407407407407,
#      'val_f1': 0.8384615384615385,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.05035311301924935,
#      'val_loss': 0.050605136809157736,
#      'val_accuracy': 0.6481481481481481,
#      'val_f1': 0.7432432432432432,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.04879078004999655,
#      'val_loss': 0.05145552082930082,
#      'val_accuracy': 0.7253086419753086,
#      'val_f1': 0.8102345415778252,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.04959146804711064,
#      'val_loss': 0.05195037482513322,
#      'val_accuracy': 0.7098765432098766,
#      'val_f1': 0.8065843621399177,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.049720704482466564,
#      'val_loss': 0.050856710997996504,
#      'val_accuracy': 0.6512345679012346,
#      'val_f1': 0.7460674157303371,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.0484437193585878,
#      'val_loss': 0.051021076221432954,
#      'val_accuracy': 0.7098765432098766,
#      'val_f1': 0.8008474576271186,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.0472730122903148,
#      'val_loss': 0.05034373229208552,
#      'val_accuracy': 0.6728395061728395,
#      'val_f1': 0.7685589519650655,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.04792804254286764,
#      'val_loss': 0.04945580332459491,
#      'val_accuracy': 0.7191358024691358,
#      'val_f1': 0.8131416837782341,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.047784504300656436,
#      'val_loss': 0.050734375385038645,
#      'val_accuracy': 0.6450617283950617,
#      'val_f1': 0.7319347319347319,
#      'lr': 0.001},
#     {'epoch': 10.0,
#      'train_loss': 0.04728770316565404,
#      'val_loss': 0.04866039322942128,
#      'val_accuracy': 0.654320987654321,
#      'val_f1': 0.7383177570093458,
#      'lr': 0.001},
#     {'epoch': 11.0,
#      'train_loss': 0.04620929559071859,
#      'val_loss': 0.04926734363637221,
#      'val_accuracy': 0.7067901234567902,
#      'val_f1': 0.8057259713701431,
#      'lr': 0.001},
#     {'epoch': 12.0,
#      'train_loss': 0.04600015778292795,
#      'val_loss': 0.04796542441127477,
#      'val_accuracy': 0.6635802469135802,
#      'val_f1': 0.7386091127098321,
#      'lr': 0.001},
#     {'epoch': 13.0,
#      'train_loss': 0.04649367631107819,
#      'val_loss': 0.04942292070453182,
#      'val_accuracy': 0.691358024691358,
#      'val_f1': 0.7854077253218884,
#      'lr': 0.001},
#     {'epoch': 14.0,
#      'train_loss': 0.04595831773277758,
#      'val_loss': 0.04843203580857795,
#      'val_accuracy': 0.7037037037037037,
#      'val_f1': 0.791304347826087,
#      'lr': 0.001},
#     {'epoch': 15.0,
#      'train_loss': 0.04552373262930985,
#      'val_loss': 0.053365575385360436,
#      'val_accuracy': 0.6666666666666666,
#      'val_f1': 0.7534246575342466,
#      'lr': 0.001},
#     {'epoch': 16.0,
#      'train_loss': 0.045840558666391536,
#      'val_loss': 0.04557840695121774,
#      'val_accuracy': 0.6975308641975309,
#      'val_f1': 0.776255707762557,
#      'lr': 0.001},
#     {'epoch': 17.0,
#      'train_loss': 0.0443011558606845,
#      'val_loss': 0.04939412585471147,
#      'val_accuracy': 0.654320987654321,
#      'val_f1': 0.7294685990338164,
#      'lr': 0.001},
#     {'epoch': 18.0,
#      'train_loss': 0.045314393614103145,
#      'val_loss': 0.04816272838708059,
#      'val_accuracy': 0.7098765432098766,
#      'val_f1': 0.7956521739130434,
#      'lr': 0.001},
#     {'epoch': 19.0,
#      'train_loss': 0.04472225249147549,
#      'val_loss': 0.049824603419337005,
#      'val_accuracy': 0.6481481481481481,
#      'val_f1': 0.7348837209302326,
#      'lr': 0.001},
#     {'epoch': 20.0,
#      'train_loss': 0.04446782981481205,
#      'val_loss': 0.04825559420580113,
#      'val_accuracy': 0.6790123456790124,
#      'val_f1': 0.7678571428571428,
#      'lr': 0.001},
#     {'epoch': 21.0,
#      'train_loss': 0.0447530714737601,
#      'val_loss': 0.04879400101892742,
#      'val_accuracy': 0.7006172839506173,
#      'val_f1': 0.787746170678337,
#      'lr': 0.0005},
#     {'epoch': 22.0,
#      'train_loss': 0.043526243053230586,
#      'val_loss': 0.047720159978870254,
#      'val_accuracy': 0.6820987654320988,
#      'val_f1': 0.7726269315673289,
#      'lr': 0.0005},
#     {'epoch': 23.0,
#      'train_loss': 0.04220809406634806,
#      'val_loss': 0.04626479772505937,
#      'val_accuracy': 0.7129629629629629,
#      'val_f1': 0.8017057569296375,
#      'lr': 0.0005},
#     {'epoch': 24.0,
#      'train_loss': 0.042079204928223826,
#      'val_loss': 0.047216971646304486,
#      'val_accuracy': 0.7006172839506173,
#      'val_f1': 0.780045351473923,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_01_Sub1_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_01_Sub1.pt'}},
#   {'fold_index': 2,
#    'test_subject': 'Sub2',
#    'split': {'train': ['Sub1',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub38',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub51',
#      'Sub53'],
#     'val': ['Sub3', 'Sub7', 'Sub33', 'Sub45', 'Sub52'],
#     'test': ['Sub2']},
#    'sample_shapes': {'x_train': [2854, 2, 60],
#     'x_val': [325, 2, 60],
#     'x_test': [65, 2, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2282},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 19,
#    'best_val_loss': 0.04576034960838465,
#    'test_metrics': {'loss': 0.02636807583845579,
#     'accuracy': 0.9692307692307692,
#     'precision': 1.0,
#     'recall': 0.9615384615384616,
#     'f1': 0.9803921568627451,
#     'tn': 13.0,
#     'fp': 0.0,
#     'fn': 2.0,
#     'tp': 50.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20042046250875964,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'hrv_window': 30,
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.05271063658089678,
#      'val_loss': 0.048240790739655495,
#      'val_accuracy': 0.7292307692307692,
#      'val_f1': 0.8166666666666667,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.05097498164395394,
#      'val_loss': 0.04903984910593583,
#      'val_accuracy': 0.7138461538461538,
#      'val_f1': 0.8050314465408805,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.051322877574150765,
#      'val_loss': 0.051964054187903036,
#      'val_accuracy': 0.6246153846153846,
#      'val_f1': 0.7188940092165897,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.05105322773275295,
#      'val_loss': 0.047131636882057557,
#      'val_accuracy': 0.7292307692307692,
#      'val_f1': 0.8189300411522634,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.0502123166718889,
#      'val_loss': 0.048087279452727394,
#      'val_accuracy': 0.6430769230769231,
#      'val_f1': 0.7387387387387386,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.049336351240190826,
#      'val_loss': 0.04849209189414978,
#      'val_accuracy': 0.6092307692307692,
#      'val_f1': 0.7080459770114943,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.05022227598619194,
#      'val_loss': 0.04847182971353714,
#      'val_accuracy': 0.7630769230769231,
#      'val_f1': 0.8438133874239352,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.04951740673938329,
#      'val_loss': 0.04838141275139955,
#      'val_accuracy': 0.6707692307692308,
#      'val_f1': 0.7648351648351648,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.049457405383823295,
#      'val_loss': 0.04942551858150042,
#      'val_accuracy': 0.6276923076923077,
#      'val_f1': 0.724373576309795,
#      'lr': 0.0005},
#     {'epoch': 10.0,
#      'train_loss': 0.0492879943041093,
#      'val_loss': 0.046403987464996486,
#      'val_accuracy': 0.7261538461538461,
#      'val_f1': 0.8134171907756813,
#      'lr': 0.0005},
#     {'epoch': 11.0,
#      'train_loss': 0.048478225085521465,
#      'val_loss': 0.04691451569016163,
#      'val_accuracy': 0.68,
#      'val_f1': 0.7729257641921398,
#      'lr': 0.0005},
#     {'epoch': 12.0,
#      'train_loss': 0.04798121301335894,
#      'val_loss': 0.04804534128079047,
#      'val_accuracy': 0.7476923076923077,
#      'val_f1': 0.8298755186721991,
#      'lr': 0.0005},
#     {'epoch': 13.0,
#      'train_loss': 0.04838930923536096,
#      'val_loss': 0.04678346295196276,
#      'val_accuracy': 0.683076923076923,
#      'val_f1': 0.7736263736263735,
#      'lr': 0.0005},
#     {'epoch': 14.0,
#      'train_loss': 0.04802601589196699,
#      'val_loss': 0.04704149646827808,
#      'val_accuracy': 0.7323076923076923,
#      'val_f1': 0.8176100628930817,
#      'lr': 0.0005},
#     {'epoch': 15.0,
#      'train_loss': 0.04736448698575963,
#      'val_loss': 0.048542553318234594,
#      'val_accuracy': 0.7415384615384616,
#      'val_f1': 0.8242677824267782,
#      'lr': 0.00025},
#     {'epoch': 16.0,
#      'train_loss': 0.04690227265448193,
#      'val_loss': 0.047114415736152576,
#      'val_accuracy': 0.7107692307692308,
#      'val_f1': 0.798283261802575,
#      'lr': 0.00025},
#     {'epoch': 17.0,
#      'train_loss': 0.047737162001561514,
#      'val_loss': 0.04601010945553963,
#      'val_accuracy': 0.7476923076923077,
#      'val_f1': 0.8291666666666666,
#      'lr': 0.00025},
#     {'epoch': 18.0,
#      'train_loss': 0.04696278910517442,
#      'val_loss': 0.04645505282168205,
#      'val_accuracy': 0.7384615384615385,
#      'val_f1': 0.8210526315789475,
#      'lr': 0.00025},
#     {'epoch': 19.0,
#      'train_loss': 0.04651520657336787,
#      'val_loss': 0.04576034960838465,
#      'val_accuracy': 0.7323076923076923,
#      'val_f1': 0.8160676532769555,
#      'lr': 0.00025},
#     {'epoch': 20.0,
#      'train_loss': 0.0464420160637632,
#      'val_loss': 0.04790964934688348,
#      'val_accuracy': 0.7323076923076923,
#      'val_f1': 0.8176100628930817,
#      'lr': 0.00025},
#     {'epoch': 21.0,
#      'train_loss': 0.04635188506149961,
#      'val_loss': 0.04831673417526942,
#      'val_accuracy': 0.7630769230769231,
#      'val_f1': 0.8438133874239352,
#      'lr': 0.00025},
#     {'epoch': 22.0,
#      'train_loss': 0.045743225475208024,
#      'val_loss': 0.04858011919145401,
#      'val_accuracy': 0.76,
#      'val_f1': 0.8408163265306122,
#      'lr': 0.00025},
#     {'epoch': 23.0,
#      'train_loss': 0.04564688980485396,
#      'val_loss': 0.04663826347543643,
#      'val_accuracy': 0.7138461538461538,
#      'val_f1': 0.8017057569296375,
#      'lr': 0.00025},
#     {'epoch': 24.0,
#      'train_loss': 0.04525749094799923,
#      'val_loss': 0.048149811230026755,
#      'val_accuracy': 0.76,
#      'val_f1': 0.8395061728395061,
#      'lr': 0.000125},
#     {'epoch': 25.0,
#      'train_loss': 0.044727975088834096,
#      'val_loss': 0.04823164156423165,
#      'val_accuracy': 0.7415384615384616,
#      'val_f1': 0.8257261410788381,
#      'lr': 0.000125},
#     {'epoch': 26.0,
#      'train_loss': 0.0443174878387244,
#      'val_loss': 0.05041896296808353,
#      'val_accuracy': 0.7415384615384616,
#      'val_f1': 0.8227848101265823,
#      'lr': 0.000125},
#     {'epoch': 27.0,
#      'train_loss': 0.04352517054007032,
#      'val_loss': 0.05096368575898501,
#      'val_accuracy': 0.7415384615384616,
#      'val_f1': 0.8235294117647058,
#      'lr': 0.000125}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_02_Sub2_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_02_Sub2.pt'}},
#   {'fold_index': 3,
#    'test_subject': 'Sub3',
#    'split': {'train': ['Sub2',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub7',
#      'Sub8',
#      'Sub9',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub38',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub45',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub51',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub1', 'Sub10', 'Sub31', 'Sub46', 'Sub50'],
#     'test': ['Sub3']},
#    'sample_shapes': {'x_train': [2855, 2, 60],
#     'x_val': [324, 2, 60],
#     'x_test': [65, 2, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2283},
#     'val': {'non_stress': 65, 'stress': 259},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 6,
#    'best_val_loss': 0.04861317356519493,
#    'test_metrics': {'loss': 0.05979421385205709,
#     'accuracy': 0.5538461538461539,
#     'precision': 0.7555555555555555,
#     'recall': 0.6538461538461539,
#     'f1': 0.7010309278350516,
#     'tn': 2.0,
#     'fp': 11.0,
#     'fn': 18.0,
#     'tp': 34.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20035026269702277,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'hrv_window': 30,
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.05164393192832399,
#      'val_loss': 0.054947275645387025,
#      'val_accuracy': 0.7253086419753086,
#      'val_f1': 0.8187372708757638,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.049614331599866446,
#      'val_loss': 0.053466545417904854,
#      'val_accuracy': 0.7839506172839507,
#      'val_f1': 0.8616600790513834,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.04885771640702012,
#      'val_loss': 0.05272592992786272,
#      'val_accuracy': 0.7901234567901234,
#      'val_f1': 0.8661417322834645,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.04994268374951416,
#      'val_loss': 0.04933633004533656,
#      'val_accuracy': 0.7654320987654321,
#      'val_f1': 0.8461538461538461,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.04942054723612899,
#      'val_loss': 0.05165947302256101,
#      'val_accuracy': 0.7654320987654321,
#      'val_f1': 0.8473895582329318,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.04909300705884467,
#      'val_loss': 0.04861317356519493,
#      'val_accuracy': 0.7993827160493827,
#      'val_f1': 0.8722986247544204,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.048442430440630055,
#      'val_loss': 0.05161788772193738,
#      'val_accuracy': 0.75,
#      'val_f1': 0.8336755646817248,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.048243168849765525,
#      'val_loss': 0.055232286637212025,
#      'val_accuracy': 0.7067901234567902,
#      'val_f1': 0.8033126293995858,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.04777774815749371,
#      'val_loss': 0.053436817716301224,
#      'val_accuracy': 0.7191358024691358,
#      'val_f1': 0.8100208768267224,
#      'lr': 0.001},
#     {'epoch': 10.0,
#      'train_loss': 0.04739371806565809,
#      'val_loss': 0.04878493777855679,
#      'val_accuracy': 0.6759259259259259,
#      'val_f1': 0.7712418300653595,
#      'lr': 0.001},
#     {'epoch': 11.0,
#      'train_loss': 0.047970193856756244,
#      'val_loss': 0.05234337289944107,
#      'val_accuracy': 0.8209876543209876,
#      'val_f1': 0.8875968992248062,
#      'lr': 0.0005},
#     {'epoch': 12.0,
#      'train_loss': 0.046216049132747954,
#      'val_loss': 0.05414032756730362,
#      'val_accuracy': 0.7376543209876543,
#      'val_f1': 0.8247422680412371,
#      'lr': 0.0005},
#     {'epoch': 13.0,
#      'train_loss': 0.04632985910788935,
#      'val_loss': 0.053716180524156415,
#      'val_accuracy': 0.7469135802469136,
#      'val_f1': 0.8305785123966942,
#      'lr': 0.0005},
#     {'epoch': 14.0,
#      'train_loss': 0.04689522848942443,
#      'val_loss': 0.05294135309479855,
#      'val_accuracy': 0.7777777777777778,
#      'val_f1': 0.8554216867469879,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_03_Sub3_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_03_Sub3.pt'}},
#   {'fold_index': 4,
#    'test_subject': 'Sub4',
#    'split': {'train': ['Sub1',
#      'Sub2',
#      'Sub3',
#      'Sub5',
#      'Sub6',
#      'Sub7',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub38',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub44',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub51',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub8', 'Sub14', 'Sub43', 'Sub45', 'Sub50'],
#     'test': ['Sub4']},
#    'sample_shapes': {'x_train': [2854, 2, 60],
#     'x_val': [325, 2, 60],
#     'x_test': [65, 2, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2282},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 8,
#    'best_val_loss': 0.054896616305296235,
#    'test_metrics': {'loss': 0.04600190127698275,
#     'accuracy': 0.7384615384615385,
#     'precision': 0.9487179487179487,
#     'recall': 0.7115384615384616,
#     'f1': 0.8131868131868132,
#     'tn': 11.0,
#     'fp': 2.0,
#     'fn': 15.0,
#     'tp': 37.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20042046250875964,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'hrv_window': 30,
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.051808185716170733,
#      'val_loss': 0.05709526219047033,
#      'val_accuracy': 0.6584615384615384,
#      'val_f1': 0.7766599597585514,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.05055872812219742,
#      'val_loss': 0.058847628935025285,
#      'val_accuracy': 0.6738461538461539,
#      'val_f1': 0.7896825396825397,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.04986640232463107,
#      'val_loss': 0.058795561102720405,
#      'val_accuracy': 0.52,
#      'val_f1': 0.6338028169014085,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.050235770577493045,
#      'val_loss': 0.059668578236148906,
#      'val_accuracy': 0.6338461538461538,
#      'val_f1': 0.7494736842105263,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.04864140717441917,
#      'val_loss': 0.05860756341654521,
#      'val_accuracy': 0.6246153846153846,
#      'val_f1': 0.7404255319148936,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.04847891344711675,
#      'val_loss': 0.05707227702324207,
#      'val_accuracy': 0.6615384615384615,
#      'val_f1': 0.7717842323651452,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.04869024070748601,
#      'val_loss': 0.06048934101485289,
#      'val_accuracy': 0.6676923076923077,
#      'val_f1': 0.7777777777777778,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.04872208130144538,
#      'val_loss': 0.054896616305296235,
#      'val_accuracy': 0.6430769230769231,
#      'val_f1': 0.7510729613733904,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.047956421258634176,
#      'val_loss': 0.05693199733702036,
#      'val_accuracy': 0.6707692307692308,
#      'val_f1': 0.7793814432989691,
#      'lr': 0.001},
#     {'epoch': 10.0,
#      'train_loss': 0.047850773127432376,
#      'val_loss': 0.05672450124071195,
#      'val_accuracy': 0.6707692307692308,
#      'val_f1': 0.7793814432989691,
#      'lr': 0.001},
#     {'epoch': 11.0,
#      'train_loss': 0.04707788984071314,
#      'val_loss': 0.05593958177818702,
#      'val_accuracy': 0.6707692307692308,
#      'val_f1': 0.7766179540709811,
#      'lr': 0.001},
#     {'epoch': 12.0,
#      'train_loss': 0.04680574697604861,
#      'val_loss': 0.05571162751660897,
#      'val_accuracy': 0.6707692307692308,
#      'val_f1': 0.7747368421052632,
#      'lr': 0.001},
#     {'epoch': 13.0,
#      'train_loss': 0.04755250990557854,
#      'val_loss': 0.05858636673253316,
#      'val_accuracy': 0.6123076923076923,
#      'val_f1': 0.7272727272727273,
#      'lr': 0.0005},
#     {'epoch': 14.0,
#      'train_loss': 0.04594228083963526,
#      'val_loss': 0.05871480079224477,
#      'val_accuracy': 0.6707692307692308,
#      'val_f1': 0.7784679089026916,
#      'lr': 0.0005},
#     {'epoch': 15.0,
#      'train_loss': 0.04575506309027762,
#      'val_loss': 0.05746284908400132,
#      'val_accuracy': 0.6492307692307693,
#      'val_f1': 0.7584745762711864,
#      'lr': 0.0005},
#     {'epoch': 16.0,
#      'train_loss': 0.045758236901862016,
#      'val_loss': 0.058724865282957374,
#      'val_accuracy': 0.6584615384615384,
#      'val_f1': 0.7663157894736841,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_04_Sub4_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_04_Sub4.pt'}},
#   {'fold_index': 5,
#    'test_subject': 'Sub5',
#    'split': {'train': ['Sub1',
#      'Sub2',
#      'Sub3',
#      'Sub4',
#      'Sub6',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub14',
#      'Sub15',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub50',
#      'Sub51',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub7', 'Sub13', 'Sub16', 'Sub38', 'Sub49'],
#     'test': ['Sub5']},
#    'sample_shapes': {'x_train': [2856, 2, 60],
#     'x_val': [323, 2, 60],
#     'x_test': [65, 2, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2284},
#     'val': {'non_stress': 65, 'stress': 258},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 4,
#    'best_val_loss': 0.05164112219869537,
#    'test_metrics': {'loss': 0.09069611092026417,
#     'accuracy': 0.2923076923076923,
#     'precision': 0.59375,
#     'recall': 0.36538461538461536,
#     'f1': 0.45238095238095233,
#     'tn': 0.0,
#     'fp': 13.0,
#     'fn': 33.0,
#     'tp': 19.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20028011204481794,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'hrv_window': 30,
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.0519671158588567,
#      'val_loss': 0.05443292164212041,
#      'val_accuracy': 0.7368421052631579,
#      'val_f1': 0.836223506743738,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.049585034710769894,
#      'val_loss': 0.052050046553552706,
#      'val_accuracy': 0.5015479876160991,
#      'val_f1': 0.5839793281653747,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.049592586312474325,
#      'val_loss': 0.05489271649681378,
#      'val_accuracy': 0.7678018575851393,
#      'val_f1': 0.8592870544090057,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.04870382196554283,
#      'val_loss': 0.05164112219869537,
#      'val_accuracy': 0.628482972136223,
#      'val_f1': 0.7209302325581395,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.048153375533698986,
#      'val_loss': 0.05282296090395458,
#      'val_accuracy': 0.56656346749226,
#      'val_f1': 0.6585365853658538,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.047032930854321864,
#      'val_loss': 0.05631604004109238,
#      'val_accuracy': 0.5944272445820433,
#      'val_f1': 0.7015945330296127,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.047223313067223174,
#      'val_loss': 0.05596229793855649,
#      'val_accuracy': 0.6965944272445821,
#      'val_f1': 0.7983539094650205,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.04639026357763622,
#      'val_loss': 0.0585129387538315,
#      'val_accuracy': 0.7275541795665634,
#      'val_f1': 0.8247011952191236,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.046201380481030424,
#      'val_loss': 0.055970420616883614,
#      'val_accuracy': 0.628482972136223,
#      'val_f1': 0.7260273972602739,
#      'lr': 0.0005},
#     {'epoch': 10.0,
#      'train_loss': 0.045250204096989134,
#      'val_loss': 0.055532949327868945,
#      'val_accuracy': 0.6842105263157895,
#      'val_f1': 0.782051282051282,
#      'lr': 0.0005},
#     {'epoch': 11.0,
#      'train_loss': 0.04498836089770834,
#      'val_loss': 0.054921047813936655,
#      'val_accuracy': 0.6718266253869969,
#      'val_f1': 0.7675438596491226,
#      'lr': 0.0005},
#     {'epoch': 12.0,
#      'train_loss': 0.04508438776312422,
#      'val_loss': 0.05597002589757966,
#      'val_accuracy': 0.7058823529411765,
#      'val_f1': 0.8041237113402062,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_05_Sub5_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_05_Sub5.pt'}},
#   {'fold_index': 6,
#    'test_subject': 'Sub6',
#    'split': {'train': ['Sub1',
#      'Sub3',
#      'Sub4',
#      'Sub5',
#      'Sub7',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub40',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub51',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub2', 'Sub8', 'Sub28', 'Sub38', 'Sub41'],
#     'test': ['Sub6']},
#    'sample_shapes': {'x_train': [2854, 2, 60],
#     'x_val': [325, 2, 60],
#     'x_test': [65, 2, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2282},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 12,
#    'best_val_loss': 0.05371912909241823,
#    'test_metrics': {'loss': 0.04261359526560857,
#     'accuracy': 0.676923076923077,
#     'precision': 0.9428571428571428,
#     'recall': 0.6346153846153846,
#     'f1': 0.7586206896551724,
#     'tn': 11.0,
#     'fp': 2.0,
#     'fn': 19.0,
#     'tp': 33.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20042046250875964,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'hrv_window': 30,
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.052234164738705215,
#      'val_loss': 0.055588013850725614,
#      'val_accuracy': 0.4338461538461538,
#      'val_f1': 0.47428571428571425,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.050420304492752956,
#      'val_loss': 0.05594156347788297,
#      'val_accuracy': 0.7046153846153846,
#      'val_f1': 0.813953488372093,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.04976213688700452,
#      'val_loss': 0.05695137525407168,
#      'val_accuracy': 0.6984615384615385,
#      'val_f1': 0.8108108108108109,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.049246035873910805,
#      'val_loss': 0.055954248458147046,
#      'val_accuracy': 0.6738461538461539,
#      'val_f1': 0.7827868852459018,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.04906172930839267,
#      'val_loss': 0.05621084096340033,
#      'val_accuracy': 0.68,
#      'val_f1': 0.7877551020408164,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.04835287950927759,
#      'val_loss': 0.05398949947494727,
#      'val_accuracy': 0.6461538461538462,
#      'val_f1': 0.7526881720430108,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.04908503916247708,
#      'val_loss': 0.05841680273413658,
#      'val_accuracy': 0.68,
#      'val_f1': 0.7894736842105262,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.04837893886516457,
#      'val_loss': 0.054763707770751076,
#      'val_accuracy': 0.6738461538461539,
#      'val_f1': 0.7836734693877551,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.04730575318176093,
#      'val_loss': 0.05631891472981526,
#      'val_accuracy': 0.6430769230769231,
#      'val_f1': 0.7531914893617022,
#      'lr': 0.001},
#     {'epoch': 10.0,
#      'train_loss': 0.04732386726878202,
#      'val_loss': 0.054895193473650856,
#      'val_accuracy': 0.5846153846153846,
#      'val_f1': 0.6952595936794582,
#      'lr': 0.001},
#     {'epoch': 11.0,
#      'train_loss': 0.04689117193159392,
#      'val_loss': 0.05646766120424637,
#      'val_accuracy': 0.6738461538461539,
#      'val_f1': 0.7800829875518672,
#      'lr': 0.0005},
#     {'epoch': 12.0,
#      'train_loss': 0.046066126464419044,
#      'val_loss': 0.05371912909241823,
#      'val_accuracy': 0.6461538461538462,
#      'val_f1': 0.7526881720430108,
#      'lr': 0.0005},
#     {'epoch': 13.0,
#      'train_loss': 0.04518483184178809,
#      'val_loss': 0.057301300030488236,
#      'val_accuracy': 0.6861538461538461,
#      'val_f1': 0.7926829268292682,
#      'lr': 0.0005},
#     {'epoch': 14.0,
#      'train_loss': 0.046051036357649906,
#      'val_loss': 0.05599754951321162,
#      'val_accuracy': 0.6738461538461539,
#      'val_f1': 0.7763713080168776,
#      'lr': 0.0005},
#     {'epoch': 15.0,
#      'train_loss': 0.044856706959180426,
#      'val_loss': 0.0574934707238124,
#      'val_accuracy': 0.683076923076923,
#      'val_f1': 0.7885010266940453,
#      'lr': 0.0005},
#     {'epoch': 16.0,
#      'train_loss': 0.04407955738229608,
#      'val_loss': 0.05847373053431511,
#      'val_accuracy': 0.6553846153846153,
#      'val_f1': 0.7637130801687765,
#      'lr': 0.0005},
#     {'epoch': 17.0,
#      'train_loss': 0.04406370569513909,
#      'val_loss': 0.0575517519735373,
#      'val_accuracy': 0.6707692307692308,
#      'val_f1': 0.7784679089026916,
#      'lr': 0.00025},
#     {'epoch': 18.0,
#      'train_loss': 0.04311975575043717,
#      'val_loss': 0.061846491935161445,
#      'val_accuracy': 0.676923076923077,
#      'val_f1': 0.7817047817047816,
#      'lr': 0.00025},
#     {'epoch': 19.0,
#      'train_loss': 0.0421106683739057,
#      'val_loss': 0.05981371359183238,
#      'val_accuracy': 0.6492307692307693,
#      'val_f1': 0.7564102564102563,
#      'lr': 0.00025},
#     {'epoch': 20.0,
#      'train_loss': 0.042157890017979115,
#      'val_loss': 0.0632977972466212,
#      'val_accuracy': 0.6707692307692308,
#      'val_f1': 0.7784679089026916,
#      'lr': 0.00025}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_06_Sub6_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_06_Sub6.pt'}},
#   {'fold_index': 7,
#    'test_subject': 'Sub7',
#    'split': {'train': ['Sub1',
#      'Sub2',
#      'Sub3',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub38',
#      'Sub41',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub51',
#      'Sub53'],
#     'val': ['Sub13', 'Sub23', 'Sub30', 'Sub40', 'Sub52'],
#     'test': ['Sub7']},
#    'sample_shapes': {'x_train': [2856, 2, 60],
#     'x_val': [323, 2, 60],
#     'x_test': [65, 2, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2284},
#     'val': {'non_stress': 65, 'stress': 258},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 25,
#    'best_val_loss': 0.0401181771359392,
#    'test_metrics': {'loss': 0.03773500340489241,
#     'accuracy': 0.8923076923076924,
#     'precision': 0.9787234042553191,
#     'recall': 0.8846153846153846,
#     'f1': 0.9292929292929293,
#     'tn': 12.0,
#     'fp': 1.0,
#     'fn': 6.0,
#     'tp': 46.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20028011204481794,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'hrv_window': 30,
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.052668293484118806,
#      'val_loss': 0.0443875622753942,
#      'val_accuracy': 0.8018575851393189,
#      'val_f1': 0.8719999999999999,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.0514922517270935,
#      'val_loss': 0.0466757103074169,
#      'val_accuracy': 0.8328173374613003,
#      'val_f1': 0.8961538461538461,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.051791671392213065,
#      'val_loss': 0.0456907459053185,
#      'val_accuracy': 0.7739938080495357,
#      'val_f1': 0.8501026694045173,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.051468081866242306,
#      'val_loss': 0.045275836404493716,
#      'val_accuracy': 0.7585139318885449,
#      'val_f1': 0.8354430379746837,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.050757293315494764,
#      'val_loss': 0.04784973976620395,
#      'val_accuracy': 0.8328173374613003,
# ...
#      'val_f1': 0.7945205479452054,
#      'lr': 0.0005},
#     {'epoch': 32.0,
#      'train_loss': 0.04149069199289624,
#      'val_loss': 0.03682086694939637,
#      'val_accuracy': 0.7407407407407407,
#      'val_f1': 0.8165938864628821,
#      'lr': 0.0005},
#     {'epoch': 33.0,
#      'train_loss': 0.039918960286418524,
#      'val_loss': 0.04010591393819562,
#      'val_accuracy': 0.7469135802469136,
#      'val_f1': 0.8193832599118943,
#      'lr': 0.0005},
#     {'epoch': 34.0,
#      'train_loss': 0.04227459477668468,
#      'val_loss': 0.03811646897897676,
#      'val_accuracy': 0.7746913580246914,
#      'val_f1': 0.847599164926931,
#      'lr': 0.0005},
#     {'epoch': 35.0,
#      'train_loss': 0.041616471368826,
#      'val_loss': 0.036962449125209705,
#      'val_accuracy': 0.7376543209876543,
#      'val_f1': 0.8148148148148148,
#      'lr': 0.0005},
#     {'epoch': 36.0,
#      'train_loss': 0.04039778219447871,
#      'val_loss': 0.036702482432218984,
#      'val_accuracy': 0.7098765432098766,
#      'val_f1': 0.7863636363636364,
#      'lr': 0.0005},
#     {'epoch': 37.0,
#      'train_loss': 0.04050974100828171,
#      'val_loss': 0.03711575084009472,
#      'val_accuracy': 0.75,
#      'val_f1': 0.821978021978022,
#      'lr': 0.0005},
#     {'epoch': 38.0,
#      'train_loss': 0.039194773124521125,
#      'val_loss': 0.03545546769681904,
#      'val_accuracy': 0.7592592592592593,
#      'val_f1': 0.8311688311688311,
#      'lr': 0.0005},
#     {'epoch': 39.0,
#      'train_loss': 0.03928598908482416,
#      'val_loss': 0.03861161535835744,
#      'val_accuracy': 0.6944444444444444,
#      'val_f1': 0.7724137931034483,
#      'lr': 0.0005},
#     {'epoch': 40.0,
#      'train_loss': 0.03918285844178834,
#      'val_loss': 0.035840193890495066,
#      'val_accuracy': 0.7129629629629629,
#      'val_f1': 0.7900677200902935,
#      'lr': 0.0005},
#     {'epoch': 41.0,
#      'train_loss': 0.03944192342525397,
#      'val_loss': 0.03920734516793379,
#      'val_accuracy': 0.7006172839506173,
#      'val_f1': 0.7780320366132724,
#      'lr': 0.0005},
#     {'epoch': 42.0,
#      'train_loss': 0.03833051543232647,
#      'val_loss': 0.03770300255007582,
#      'val_accuracy': 0.6882716049382716,
#      'val_f1': 0.765661252900232,
#      'lr': 0.0005},
#     {'epoch': 43.0,
#      'train_loss': 0.037766072900407996,
#      'val_loss': 0.03900135908689764,
#      'val_accuracy': 0.7006172839506173,
#      'val_f1': 0.7780320366132724,
#      'lr': 0.00025},
#     {'epoch': 44.0,
#      'train_loss': 0.03612488520359408,
#      'val_loss': 0.0380868767330676,
#      'val_accuracy': 0.7006172839506173,
#      'val_f1': 0.7780320366132724,
#      'lr': 0.00025},
#     {'epoch': 45.0,
#      'train_loss': 0.036476627199693655,
#      'val_loss': 0.03776462118566772,
#      'val_accuracy': 0.691358024691358,
#      'val_f1': 0.7641509433962264,
#      'lr': 0.00025},
#     {'epoch': 46.0,
#      'train_loss': 0.035778462835921926,
#      'val_loss': 0.03689727747100003,
#      'val_accuracy': 0.7006172839506173,
#      'val_f1': 0.7759815242494227,
#      'lr': 0.00025}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_47_Sub50_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_47_Sub50.pt'}},
#   {'fold_index': 48,
#    'test_subject': 'Sub51',
#    'split': {'train': ['Sub2',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub7',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub36',
#      'Sub37',
#      'Sub38',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub44',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub1', 'Sub3', 'Sub35', 'Sub43', 'Sub45'],
#     'test': ['Sub51']},
#    'sample_shapes': {'x_train': [2855, 2, 60],
#     'x_val': [324, 2, 60],
#     'x_test': [65, 2, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2283},
#     'val': {'non_stress': 65, 'stress': 259},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 6,
#    'best_val_loss': 0.05368539976117052,
#    'test_metrics': {'loss': 0.04270720169521295,
#     'accuracy': 0.8,
#     'precision': 1.0,
#     'recall': 0.75,
#     'f1': 0.8571428571428571,
#     'tn': 13.0,
#     'fp': 0.0,
#     'fn': 13.0,
#     'tp': 39.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20035026269702277,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'hrv_window': 30,
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.052130872829313245,
#      'val_loss': 0.05551967884839317,
#      'val_accuracy': 0.7376543209876543,
#      'val_f1': 0.8316831683168316,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.050341819635153655,
#      'val_loss': 0.058859627739882764,
#      'val_accuracy': 0.6790123456790124,
#      'val_f1': 0.7833333333333333,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.05021644742236246,
#      'val_loss': 0.05626877972189291,
#      'val_accuracy': 0.6419753086419753,
#      'val_f1': 0.7510729613733905,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.04970549561226848,
#      'val_loss': 0.056067667441603575,
#      'val_accuracy': 0.7746913580246914,
#      'val_f1': 0.8598848368522072,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.04904652487506173,
#      'val_loss': 0.054232428379264876,
#      'val_accuracy': 0.5370370370370371,
#      'val_f1': 0.6394230769230769,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.0493644180079684,
#      'val_loss': 0.05368539976117052,
#      'val_accuracy': 0.6882716049382716,
#      'val_f1': 0.7855626326963907,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.04949649293269251,
#      'val_loss': 0.05476737951422915,
#      'val_accuracy': 0.5925925925925926,
#      'val_f1': 0.695852534562212,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.04892856137086548,
#      'val_loss': 0.05689103344892278,
#      'val_accuracy': 0.7345679012345679,
#      'val_f1': 0.8244897959183674,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.048336482241149545,
#      'val_loss': 0.056567840140174935,
#      'val_accuracy': 0.6882716049382716,
#      'val_f1': 0.7818574514038876,
#      'lr': 0.001},
#     {'epoch': 10.0,
#      'train_loss': 0.04810965118339308,
#      'val_loss': 0.055461109742338276,
#      'val_accuracy': 0.7654320987654321,
#      'val_f1': 0.8467741935483871,
#      'lr': 0.001},
#     {'epoch': 11.0,
#      'train_loss': 0.04757853934831669,
#      'val_loss': 0.056740665118451473,
#      'val_accuracy': 0.6666666666666666,
#      'val_f1': 0.7662337662337662,
#      'lr': 0.0005},
#     {'epoch': 12.0,
#      'train_loss': 0.04693211250516036,
#      'val_loss': 0.0582480062213209,
#      'val_accuracy': 0.7006172839506173,
#      'val_f1': 0.7940552016985138,
#      'lr': 0.0005},
#     {'epoch': 13.0,
#      'train_loss': 0.04605310217798696,
#      'val_loss': 0.059861570274756276,
#      'val_accuracy': 0.654320987654321,
#      'val_f1': 0.7543859649122807,
#      'lr': 0.0005},
#     {'epoch': 14.0,
#      'train_loss': 0.04667580367021928,
#      'val_loss': 0.05665375614239846,
#      'val_accuracy': 0.7469135802469136,
#      'val_f1': 0.8305785123966942,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_48_Sub51_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_48_Sub51.pt'}},
#   {'fold_index': 49,
#    'test_subject': 'Sub52',
#    'split': {'train': ['Sub1',
#      'Sub2',
#      'Sub3',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub7',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub51'],
#     'val': ['Sub8', 'Sub38', 'Sub40', 'Sub41', 'Sub53'],
#     'test': ['Sub52']},
#    'sample_shapes': {'x_train': [2854, 2, 60],
#     'x_val': [325, 2, 60],
#     'x_test': [65, 2, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2282},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 1,
#    'best_val_loss': 0.06178915748229394,
#    'test_metrics': {'loss': 0.029483098450761577,
#     'accuracy': 0.9384615384615385,
#     'precision': 1.0,
#     'recall': 0.9230769230769231,
#     'f1': 0.9600000000000001,
#     'tn': 13.0,
#     'fp': 0.0,
#     'fn': 4.0,
#     'tp': 48.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20042046250875964,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'hrv_window': 30,
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.05148565407630941,
#      'val_loss': 0.06178915748229394,
#      'val_accuracy': 0.563076923076923,
#      'val_f1': 0.6978723404255319,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.049630000135262864,
#      'val_loss': 0.06253169542321792,
#      'val_accuracy': 0.5446153846153846,
#      'val_f1': 0.6740088105726872,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.049833014145357755,
#      'val_loss': 0.06725988590373443,
#      'val_accuracy': 0.5415384615384615,
#      'val_f1': 0.6739606126914661,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.04819828182323128,
#      'val_loss': 0.06887991959658953,
#      'val_accuracy': 0.5538461538461539,
#      'val_f1': 0.693446088794926,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.04776419858437112,
#      'val_loss': 0.06839066002231378,
#      'val_accuracy': 0.5292307692307693,
#      'val_f1': 0.6514806378132119,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.04699690341583983,
#      'val_loss': 0.06936148342031699,
#      'val_accuracy': 0.5230769230769231,
#      'val_f1': 0.6501128668171557,
#      'lr': 0.0005},
#     {'epoch': 7.0,
#      'train_loss': 0.046936292467559225,
#      'val_loss': 0.0666361287694711,
#      'val_accuracy': 0.52,
#      'val_f1': 0.6533333333333333,
#      'lr': 0.0005},
#     {'epoch': 8.0,
#      'train_loss': 0.04613599706945005,
#      'val_loss': 0.06514401333836409,
#      'val_accuracy': 0.5015384615384615,
#      'val_f1': 0.6334841628959276,
#      'lr': 0.0005},
#     {'epoch': 9.0,
#      'train_loss': 0.04633897824112402,
#      'val_loss': 0.065766032991501,
#      'val_accuracy': 0.5261538461538462,
#      'val_f1': 0.6577777777777778,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_49_Sub52_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_49_Sub52.pt'}},
#   {'fold_index': 50,
#    'test_subject': 'Sub53',
#    'split': {'train': ['Sub1',
#      'Sub2',
#      'Sub3',
#      'Sub4',
#      'Sub6',
#      'Sub7',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub40',
#      'Sub42',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub51',
#      'Sub52'],
#     'val': ['Sub5', 'Sub26', 'Sub38', 'Sub41', 'Sub43'],
#     'test': ['Sub53']},
#    'sample_shapes': {'x_train': [2854, 2, 60],
#     'x_val': [325, 2, 60],
#     'x_test': [65, 2, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2282},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 4,
#    'best_val_loss': 0.06009744670528632,
#    'test_metrics': {'loss': 0.07145378629748637,
#     'accuracy': 0.5538461538461539,
#     'precision': 0.8285714285714286,
#     'recall': 0.5576923076923077,
#     'f1': 0.6666666666666667,
#     'tn': 7.0,
#     'fp': 6.0,
#     'fn': 23.0,
#     'tp': 29.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20042046250875964,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'hrv_window': 30,
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.050448352874327806,
#      'val_loss': 0.06277156934142113,
#      'val_accuracy': 0.5076923076923077,
#      'val_f1': 0.6396396396396397,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.04870414121706918,
#      'val_loss': 0.06081907074038799,
#      'val_accuracy': 0.6369230769230769,
#      'val_f1': 0.7620967741935484,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.048654724280568544,
#      'val_loss': 0.06116998628928111,
#      'val_accuracy': 0.6030769230769231,
#      'val_f1': 0.732919254658385,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.047794844208581516,
#      'val_loss': 0.06009744670528632,
#      'val_accuracy': 0.5723076923076923,
#      'val_f1': 0.7073684210526316,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.04714400573948838,
#      'val_loss': 0.0635502927005291,
#      'val_accuracy': 0.5753846153846154,
#      'val_f1': 0.703862660944206,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.04736657006001673,
#      'val_loss': 0.06634890319063114,
#      'val_accuracy': 0.5230769230769231,
#      'val_f1': 0.651685393258427,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.04720679888033165,
#      'val_loss': 0.061831700366276963,
#      'val_accuracy': 0.6676923076923077,
#      'val_f1': 0.7874015748031495,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.04661369623685518,
#      'val_loss': 0.06242085611590972,
#      'val_accuracy': 0.5261538461538462,
#      'val_f1': 0.6577777777777778,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.046218588413081976,
#      'val_loss': 0.07009370032411355,
#      'val_accuracy': 0.5446153846153846,
#      'val_f1': 0.672566371681416,
#      'lr': 0.0005},
#     {'epoch': 10.0,
#      'train_loss': 0.044621601520653115,
#      'val_loss': 0.07036131234123157,
#      'val_accuracy': 0.563076923076923,
#      'val_f1': 0.6885964912280701,
#      'lr': 0.0005},
#     {'epoch': 11.0,
#      'train_loss': 0.04431524767834737,
#      'val_loss': 0.0653584056863418,
#      'val_accuracy': 0.6153846153846154,
#      'val_f1': 0.7412008281573499,
#      'lr': 0.0005},
#     {'epoch': 12.0,
#      'train_loss': 0.04515579696836051,
#      'val_loss': 0.06902199922845914,
#      'val_accuracy': 0.6061538461538462,
#      'val_f1': 0.7344398340248964,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_50_Sub53_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HR&HRV/Save_model/LOSO/hr_hrv_1dcnn_transformer_loso_torch_fold_50_Sub53.pt'}}],
#  'device': 'cuda'}

# %%
# LOSO 결과 시각화: Accuracy/F1, Confusion Matrix, Train/Val Loss curves
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

if "result_loso" not in globals():
    raise RuntimeError("먼저 1번 셀을 실행해 result_loso를 생성해 주세요.")

fold_results = result_loso.get("fold_results", [])
if len(fold_results) == 0:
    raise RuntimeError("fold_results가 비어 있습니다. 1번 셀 학습 결과를 확인해 주세요.")

# 1) Fold metric 요약
metrics_df = pd.DataFrame([
    {
        "fold_index": fr["fold_index"],
        "test_subject": fr["test_subject"],
        "accuracy": fr["test_metrics"]["accuracy"],
        "f1": fr["test_metrics"]["f1"],
        "tn": fr["test_metrics"]["tn"],
        "fp": fr["test_metrics"]["fp"],
        "fn": fr["test_metrics"]["fn"],
        "tp": fr["test_metrics"]["tp"],
    }
    for fr in fold_results
])

acc_mean = float(metrics_df["accuracy"].mean())
f1_mean = float(metrics_df["f1"].mean())
acc_std = float(metrics_df["accuracy"].std(ddof=0))
f1_std = float(metrics_df["f1"].std(ddof=0))

print("=== LOSO Aggregate Metrics ===")
print(f"Accuracy mean±std: {acc_mean:.4f} ± {acc_std:.4f}")
print(f"F1-score mean±std: {f1_mean:.4f} ± {f1_std:.4f}")

plt.figure(figsize=(6, 4))
bars = plt.bar(["Accuracy", "F1-score"], [acc_mean, f1_mean], color=["#4e79a7", "#f28e2b"], edgecolor="black")
plt.ylim(0, 1.0)
plt.title("LOSO Mean Metrics")
plt.ylabel("Score")
plt.grid(axis="y", linestyle="--", alpha=0.4)
for b, v in zip(bars, [acc_mean, f1_mean]):
    plt.text(b.get_x() + b.get_width() / 2, v + 0.02, f"{v:.4f}", ha="center", va="bottom")
plt.tight_layout()
plt.show()

# 2) Confusion Matrix (fold 합산 후 row-normalized)
tn = float(metrics_df["tn"].sum())
fp = float(metrics_df["fp"].sum())
fn = float(metrics_df["fn"].sum())
tp = float(metrics_df["tp"].sum())
conf_counts = np.array([[tn, fp], [fn, tp]], dtype=np.float64)
row_sums = conf_counts.sum(axis=1, keepdims=True)
conf_ratio = np.divide(conf_counts, np.maximum(row_sums, 1.0))

print("Confusion Matrix Count [[TN, FP], [FN, TP]]:")
print(conf_counts.astype(int))
print("Confusion Matrix Row Ratio [[TN, FP], [FN, TP]]:")
print(np.round(conf_ratio, 4))

fig, ax = plt.subplots(figsize=(5, 4))
im = ax.imshow(conf_ratio, cmap="Blues", vmin=0.0, vmax=1.0)
ax.set_title("LOSO Confusion Matrix (Row-normalized)")
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")
ax.set_xticks([0, 1])
ax.set_yticks([0, 1])
ax.set_xticklabels(["Non-stress", "Stress"])
ax.set_yticklabels(["Non-stress", "Stress"])
for i in range(conf_ratio.shape[0]):
    for j in range(conf_ratio.shape[1]):
        ax.text(j, i, f"{conf_ratio[i, j]:.3f}", ha="center", va="center", color="black", fontsize=12, fontweight="bold")
fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
plt.tight_layout()
plt.show()

# 3) Train/Val Loss 곡선 (fold 평균)
history_frames = []
for fr in fold_results:
    history_rows = fr.get("history", [])
    if len(history_rows) == 0:
        continue

    h = pd.DataFrame(history_rows)
    if "epoch" in h.columns and "train_loss" in h.columns and "val_loss" in h.columns:
        h["fold_index"] = fr["fold_index"]
        history_frames.append(h[["fold_index", "epoch", "train_loss", "val_loss"]])

if len(history_frames) == 0:
    print("history가 없어 Train/Val loss 곡선을 그릴 수 없습니다. 1번 셀을 다시 실행해 주세요.")
else:
    hist_all = pd.concat(history_frames, ignore_index=True)
    hist_mean = hist_all.groupby("epoch", as_index=False)[["train_loss", "val_loss"]].mean()

    plt.figure(figsize=(7, 4))
    plt.plot(hist_mean["epoch"], hist_mean["train_loss"], label="Train Loss", linewidth=2)
    plt.plot(hist_mean["epoch"], hist_mean["val_loss"], label="Val Loss", linewidth=2)
    plt.title("LOSO Mean Train/Val Loss Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.grid(alpha=0.3, linestyle="--")
    plt.legend()
    plt.tight_layout()
    plt.show()

{
    "accuracy_mean": acc_mean,
    "f1_mean": f1_mean,
    "confusion_matrix_count": conf_counts.astype(int).tolist(),
    "confusion_matrix_row_ratio": conf_ratio.tolist(),
}
# Out:
# === LOSO Aggregate Metrics ===
# Accuracy mean±std: 0.6964 ± 0.1775
# F1-score mean±std: 0.7826 ± 0.1345
# Confusion Matrix Count [[TN, FP], [FN, TP]]:
# [[ 405  245]
#  [ 740 1854]]
# Confusion Matrix Row Ratio [[TN, FP], [FN, TP]]:
# [[0.6231 0.3769]
#  [0.2853 0.7147]]
# {'accuracy_mean': 0.6964134615384614,
#  'f1_mean': 0.7826492123096992,
#  'confusion_matrix_count': [[405, 245], [740, 1854]],
#  'confusion_matrix_row_ratio': [[0.6230769230769231, 0.3769230769230769],
#   [0.28527370855821127, 0.7147262914417888]]}

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# result 변수에 의존하지 않고, 노트북 함수로 데이터 루트/피험자 탐색
dataset_root = find_dataset_root()
all_subjects = discover_complete_subjects(dataset_root)

print(f"총 {len(all_subjects)}명의 데이터를 로드하여 HR+HRV PCA를 수행합니다... (시간이 조금 걸릴 수 있습니다)")
x_all, y_all = build_split_arrays(
    dataset_root,
    all_subjects,
    window_size=60,
    stride=10,
    hrv_window=30,
    normalization_mode="subject_zscore",
)

# (N, 2, 60) -> (N, 120)
x_all_2d = x_all.reshape(x_all.shape[0], -1)

pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_all_2d)

plt.figure(figsize=(10, 7))

plt.scatter(
    x_pca[y_all == 0, 0],
    x_pca[y_all == 0, 1],
    color="#4e79a7",
    alpha=0.5,
    label="Non-stress (0)",
    edgecolors="none",
    s=20,
)

plt.scatter(
    x_pca[y_all == 1, 0],
    x_pca[y_all == 1, 1],
    color="#f28e2b",
    alpha=0.5,
    label="Stress (1)",
    edgecolors="none",
    s=20,
)

plt.title(f"2D PCA of HR+HRV Time-Series (All {len(all_subjects)} Subjects, Subject Z-Score)", fontsize=15, fontweight="bold")
plt.xlabel(f"Principal Component 1 ({pca.explained_variance_ratio_[0]*100:.1f}%)", fontsize=12)
plt.ylabel(f"Principal Component 2 ({pca.explained_variance_ratio_[1]*100:.1f}%)", fontsize=12)

leg = plt.legend(fontsize=12, markerscale=2)
for lh in leg.legend_handles:
    lh.set_alpha(1)

plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# 총 50명의 데이터를 로드하여 HR+HRV PCA를 수행합니다... (시간이 조금 걸릴 수 있습니다)
