# %%
from copy import deepcopy
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Dict, List, Optional, Tuple

import json
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset


TASKS = ["Baseline", "Logic", "Nback", "Stroop", "Sudoku"]
STRESS_TASKS = {"Logic", "Nback", "Stroop", "Sudoku"}


@dataclass
class HyperParameters:
    random_seed: int = 42
    val_ratio: float = 0.1
    min_val_subjects: int = 4
    max_val_subjects: int = 5

    window_size: int = 240
    stride: int = 10
    batch_size: int = 64
    epochs: int = 50
    learning_rate: float = 1e-3
    dropout_rate: float = 0.3
    weight_decay: float = 1e-4
    patience: int = 8

    transformer_heads: int = 8
    transformer_layers: int = 2
    transformer_ff_dim: int = 256
    transformer_dropout: float = 0.1

    # subject-wise zscore | baseline zscore | none
    normalization_mode: str = "subject_zscore"

    # focal | weighted_bce
    loss_name: str = "focal"
    focal_gamma: float = 2.0
    focal_alpha: Optional[float] = None
    save_model: bool = True

    # 개발/디버깅용: None이면 전체 LOSO fold 수행
    max_folds: Optional[int] = None


def find_dataset_root() -> Path:
    cwd = Path.cwd().resolve()
    for base in [cwd, *cwd.parents]:
        candidate = base / "Dataset" / "CATSA"
        if candidate.exists():
            return candidate

    fallback = Path("/home/binghin2/Myproject/Dataset/CATSA")
    if fallback.exists():
        return fallback

    raise FileNotFoundError("Could not find Dataset/CATSA. Please set dataset_root manually.")


def discover_complete_subjects(dataset_root: Path) -> List[str]:
    subjects: List[str] = []
    for subject_dir in sorted(dataset_root.glob("Sub*"), key=lambda p: int(p.name[3:])):
        if not subject_dir.is_dir():
            continue
        has_all = all((subject_dir / task / "TEMP.csv").exists() for task in TASKS)
        if has_all:
            subjects.append(subject_dir.name)
    return subjects


def read_temp_csv(file_path: Path) -> np.ndarray:
    df = pd.read_csv(file_path)
    numeric_cols = [c for c in df.columns if pd.api.types.is_numeric_dtype(df[c])]
    if numeric_cols:
        values = df[numeric_cols[0]].to_numpy(dtype=np.float32)
    else:
        values = pd.to_numeric(df.iloc[:, 0], errors="coerce").to_numpy(dtype=np.float32)
    values = values[~np.isnan(values)]
    if len(values) == 0:
        raise ValueError(f"No valid TEMP values in {file_path}")
    return values


def sliding_windows(signal: np.ndarray, window_size: int, stride: int) -> np.ndarray:
    if len(signal) < window_size:
        return np.empty((0, window_size), dtype=np.float32)
    windows = [signal[i:i + window_size] for i in range(0, len(signal) - window_size + 1, stride)]
    return np.asarray(windows, dtype=np.float32)


def compute_subject_stats(sub_path: Path, use_baseline_as_non_stress: bool, use_stress_tasks_only: bool) -> Tuple[float, float]:
    if use_stress_tasks_only:
        candidate_tasks = [t for t in TASKS if t in STRESS_TASKS]
    else:
        candidate_tasks = TASKS.copy()

    values_list: List[np.ndarray] = []
    for task in candidate_tasks:
        if task == "Baseline" and not use_baseline_as_non_stress:
            continue
        values_list.append(read_temp_csv(sub_path / task / "TEMP.csv"))

    all_values = np.concatenate(values_list, axis=0)
    sub_mean = float(np.mean(all_values))
    sub_std = float(np.std(all_values)) + 1e-8
    return sub_mean, sub_std


def build_split_arrays(
    dataset_root: Path,
    subject_list: List[str],
    window_size: int,
    stride: int,
    normalization_mode: str = "subject_zscore",
    use_baseline_as_non_stress: bool = True,
    use_stress_tasks_only: bool = False,
) -> Tuple[np.ndarray, np.ndarray]:
    x_chunks: List[np.ndarray] = []
    y_chunks: List[np.ndarray] = []

    for sub in subject_list:
        sub_path = dataset_root / sub

        if use_stress_tasks_only:
            candidate_tasks = [t for t in TASKS if t in STRESS_TASKS]
        else:
            candidate_tasks = TASKS.copy()

        baseline = read_temp_csv(sub_path / "Baseline" / "TEMP.csv")
        baseline_mean = float(np.mean(baseline))
        baseline_std = float(np.std(baseline)) + 1e-8

        sub_mean, sub_std = compute_subject_stats(
            sub_path,
            use_baseline_as_non_stress=use_baseline_as_non_stress,
            use_stress_tasks_only=use_stress_tasks_only,
        )

        for task in candidate_tasks:
            if task == "Baseline" and not use_baseline_as_non_stress:
                continue

            raw = read_temp_csv(sub_path / task / "TEMP.csv")
            if normalization_mode == "subject_zscore":
                norm = (raw - sub_mean) / sub_std
            elif normalization_mode == "baseline_zscore":
                norm = (raw - baseline_mean) / baseline_std
            elif normalization_mode == "none":
                norm = raw
            else:
                raise ValueError(f"Unknown normalization_mode: {normalization_mode}")

            windows = sliding_windows(norm, window_size=window_size, stride=stride)
            if len(windows) == 0:
                continue

            label = 1 if task in STRESS_TASKS else 0
            labels = np.full((len(windows),), label, dtype=np.int64)
            x_chunks.append(windows)
            y_chunks.append(labels)

    if not x_chunks:
        raise ValueError("No samples generated. Check data files or window settings.")

    x = np.concatenate(x_chunks, axis=0)[:, np.newaxis, :]
    y = np.concatenate(y_chunks, axis=0)
    return x.astype(np.float32), y.astype(np.int64)


def build_loso_folds(subjects: List[str], hp: HyperParameters) -> List[Dict[str, List[str]]]:
    folds: List[Dict[str, List[str]]] = []
    for fold_idx, test_subject in enumerate(subjects):
        remaining = [s for s in subjects if s != test_subject]

        val_count = int(round(len(remaining) * hp.val_ratio))
        val_count = max(hp.min_val_subjects, val_count)
        val_count = min(hp.max_val_subjects, val_count)
        val_count = min(val_count, len(remaining) - 1)

        rng = np.random.default_rng(hp.random_seed + fold_idx)
        shuffled = remaining.copy()
        rng.shuffle(shuffled)

        val_subjects = sorted(shuffled[:val_count], key=lambda x: int(x[3:]))
        train_subjects = sorted(shuffled[val_count:], key=lambda x: int(x[3:]))

        folds.append({
            "train": train_subjects,
            "val": val_subjects,
            "test": [test_subject],
        })

    return folds


class Temp1DCNNTransformer(nn.Module):
    def __init__(self, hp: HyperParameters):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv1d(1, 32, kernel_size=5, padding=2),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(2),
            nn.Conv1d(32, 64, kernel_size=5, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(2),
            nn.Conv1d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
        )

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=128,
            nhead=hp.transformer_heads,
            dim_feedforward=hp.transformer_ff_dim,
            dropout=hp.transformer_dropout,
            batch_first=True,
            activation="gelu",
        )
        self.transformer = nn.TransformerEncoder(
            encoder_layer,
            num_layers=hp.transformer_layers,
        )

        self.max_len = max(16, hp.window_size)
        self.pos_embedding = nn.Parameter(torch.zeros(1, self.max_len, 128))

        self.classifier = nn.Sequential(
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(hp.dropout_rate),
            nn.Linear(64, 1),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.cnn(x)
        x = x.transpose(1, 2)  # [B, L, C]

        seq_len = x.size(1)
        if seq_len > self.pos_embedding.size(1):
            pos = nn.functional.interpolate(
                self.pos_embedding.transpose(1, 2),
                size=seq_len,
                mode="linear",
                align_corners=False,
            ).transpose(1, 2)
        else:
            pos = self.pos_embedding[:, :seq_len, :]

        x = x + pos
        x = self.transformer(x)
        x = x.mean(dim=1)
        return self.classifier(x).squeeze(1)


class BinaryFocalLossWithLogits(nn.Module):
    def __init__(self, gamma: float = 2.0, alpha: Optional[float] = None, pos_weight: Optional[torch.Tensor] = None):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha
        if pos_weight is not None:
            self.register_buffer("pos_weight", pos_weight)
        else:
            self.pos_weight = None

    def forward(self, logits: torch.Tensor, targets: torch.Tensor) -> torch.Tensor:
        targets = targets.float()
        bce = F.binary_cross_entropy_with_logits(
            logits,
            targets,
            reduction="none",
            pos_weight=self.pos_weight,
        )
        probs = torch.sigmoid(logits)
        pt = probs * targets + (1.0 - probs) * (1.0 - targets)
        focal_factor = (1.0 - pt).pow(self.gamma)

        if self.alpha is not None:
            alpha_t = self.alpha * targets + (1.0 - self.alpha) * (1.0 - targets)
            loss = alpha_t * focal_factor * bce
        else:
            loss = focal_factor * bce

        return loss.mean()


def compute_pos_weight(y: np.ndarray) -> torch.Tensor:
    pos = float(np.sum(y == 1))
    neg = float(np.sum(y == 0))
    if pos == 0:
        return torch.tensor([1.0], dtype=torch.float32)
    return torch.tensor([neg / pos], dtype=torch.float32)


def make_criterion(y_train: np.ndarray, hp: HyperParameters, device: torch.device) -> Tuple[nn.Module, Dict[str, object]]:
    pos_weight = compute_pos_weight(y_train).to(device)

    if hp.loss_name == "weighted_bce":
        return nn.BCEWithLogitsLoss(pos_weight=pos_weight), {
            "loss_name": "weighted_bce",
            "pos_weight": float(pos_weight.item()),
            "focal_gamma": 0.0,
            "focal_alpha": 0.0,
        }

    if hp.loss_name == "focal":
        pos = float(np.sum(y_train == 1))
        neg = float(np.sum(y_train == 0))
        alpha = hp.focal_alpha
        if alpha is None:
            alpha = neg / max(pos + neg, 1.0)

        criterion = BinaryFocalLossWithLogits(
            gamma=hp.focal_gamma,
            alpha=float(alpha),
            pos_weight=None,
        )
        return criterion, {
            "loss_name": "focal",
            "pos_weight": 1.0,
            "focal_gamma": float(hp.focal_gamma),
            "focal_alpha": float(alpha),
            "weighting_note": "Focal uses alpha only to avoid duplicate class weighting",
        }

    raise ValueError(f"Unknown loss_name: {hp.loss_name}")


def make_loader(x: np.ndarray, y: np.ndarray, batch_size: int, shuffle: bool) -> DataLoader:
    ds = TensorDataset(torch.from_numpy(x), torch.from_numpy(y).float())
    return DataLoader(ds, batch_size=batch_size, shuffle=shuffle)


@torch.no_grad()
def evaluate(model: nn.Module, loader: DataLoader, criterion: nn.Module, device: torch.device) -> Dict[str, float]:
    model.eval()
    total_loss = 0.0
    total = 0
    tp = tn = fp = fn = 0

    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)
        logits = model(xb)
        loss = criterion(logits, yb)

        total_loss += float(loss.item()) * xb.size(0)
        total += xb.size(0)

        preds = (torch.sigmoid(logits) >= 0.5).long()
        y_int = yb.long()

        tp += int(((preds == 1) & (y_int == 1)).sum().item())
        tn += int(((preds == 0) & (y_int == 0)).sum().item())
        fp += int(((preds == 1) & (y_int == 0)).sum().item())
        fn += int(((preds == 0) & (y_int == 1)).sum().item())

    acc = (tp + tn) / max(total, 1)
    precision = tp / max(tp + fp, 1)
    recall = tp / max(tp + fn, 1)
    f1 = 2 * precision * recall / max(precision + recall, 1e-8)

    return {
        "loss": total_loss / max(total, 1),
        "accuracy": acc,
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "tn": float(tn),
        "fp": float(fp),
        "fn": float(fn),
        "tp": float(tp),
    }


def train_one_epoch(
    model: nn.Module,
    loader: DataLoader,
    optimizer: torch.optim.Optimizer,
    criterion: nn.Module,
    device: torch.device,
    clip_grad: float = 1.0,
) -> float:
    model.train()
    total_loss = 0.0
    total = 0

    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)

        optimizer.zero_grad(set_to_none=True)
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_grad)
        optimizer.step()

        total_loss += float(loss.item()) * xb.size(0)
        total += xb.size(0)

    return total_loss / max(total, 1)


def run_loso_training(
    model_name: str = "temp_1dcnn_transformer_loso_torch",
    hp: HyperParameters = HyperParameters(),
) -> Dict[str, object]:
    np.random.seed(hp.random_seed)
    torch.manual_seed(hp.random_seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(hp.random_seed)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    dataset_root = find_dataset_root()

    save_dir = Path("/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model")
    save_dir.mkdir(parents=True, exist_ok=True)

    subjects = discover_complete_subjects(dataset_root)
    folds = build_loso_folds(subjects, hp)
    if hp.max_folds is not None:
        folds = folds[: hp.max_folds]

    fold_results: List[Dict[str, object]] = []

    for fold_idx, split in enumerate(folds, start=1):
        test_subject = split["test"][0]
        print(f"\n=== Fold {fold_idx}/{len(folds)} | Test: {test_subject} ===")
        print(f"Train subjects: {len(split['train'])}, Val subjects: {len(split['val'])}, Test subjects: 1")

        x_train, y_train = build_split_arrays(
            dataset_root,
            split["train"],
            hp.window_size,
            hp.stride,
            normalization_mode=hp.normalization_mode,
        )
        x_val, y_val = build_split_arrays(
            dataset_root,
            split["val"],
            hp.window_size,
            hp.stride,
            normalization_mode=hp.normalization_mode,
        )
        x_test, y_test = build_split_arrays(
            dataset_root,
            split["test"],
            hp.window_size,
            hp.stride,
            normalization_mode=hp.normalization_mode,
        )

        train_loader = make_loader(x_train, y_train, hp.batch_size, shuffle=True)
        val_loader = make_loader(x_val, y_val, hp.batch_size, shuffle=False)
        test_loader = make_loader(x_test, y_test, hp.batch_size, shuffle=False)

        model = Temp1DCNNTransformer(hp=hp).to(device)
        criterion, loss_cfg = make_criterion(y_train, hp, device)
        optimizer = torch.optim.Adam(
            model.parameters(),
            lr=hp.learning_rate,
            weight_decay=hp.weight_decay,
        )
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode="min", factor=0.5, patience=4
        )

        best_val_loss = float("inf")
        best_epoch = -1
        wait = 0
        history_rows: List[Dict[str, float]] = []
        best_state_dict = None
        fold_tag = f"fold_{fold_idx:02d}_{test_subject}"
        best_model_path = save_dir / f"{model_name}_{fold_tag}_best.pt"
        final_model_path = save_dir / f"{model_name}_{fold_tag}.pt"

        for epoch in range(1, hp.epochs + 1):
            train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
            val_metrics = evaluate(model, val_loader, criterion, device)
            scheduler.step(val_metrics["loss"])
            history_rows.append({"epoch": float(epoch), "train_loss": float(train_loss), "val_loss": float(val_metrics["loss"]), "val_accuracy": float(val_metrics["accuracy"]), "val_f1": float(val_metrics["f1"]), "lr": float(optimizer.param_groups[0]["lr"])})

            if val_metrics["loss"] < best_val_loss:
                best_val_loss = val_metrics["loss"]
                best_epoch = epoch
                wait = 0
                best_state_dict = deepcopy(model.state_dict())
                if hp.save_model:
                    torch.save(
                        {
                            "model_state_dict": best_state_dict,
                            "hyperparameters": asdict(hp),
                            "model_name": model_name,
                            "fold_index": fold_idx,
                            "test_subject": test_subject,
                            "best_epoch": best_epoch,
                            "best_val_loss": best_val_loss,
                        },
                        best_model_path,
                    )
            else:
                wait += 1
                if wait >= hp.patience:
                    print(f"Early stopping at epoch {epoch} (best epoch: {best_epoch})")
                    break

        if best_state_dict is not None:
            model.load_state_dict(best_state_dict)

        test_metrics = evaluate(model, test_loader, criterion, device)

        if hp.save_model:
            torch.save(
                {
                    "model_state_dict": model.state_dict(),
                    "hyperparameters": asdict(hp),
                    "model_name": model_name,
                    "fold_index": fold_idx,
                    "test_subject": test_subject,
                    "best_epoch": best_epoch,
                    "best_val_loss": best_val_loss,
                    "test_metrics": {k: float(v) for k, v in test_metrics.items()},
                },
                final_model_path,
            )

        fold_result = {
            "fold_index": fold_idx,
            "test_subject": test_subject,
            "split": split,
            "sample_shapes": {
                "x_train": list(x_train.shape),
                "x_val": list(x_val.shape),
                "x_test": list(x_test.shape),
            },
            "class_distribution": {
                "train": {"non_stress": int(np.sum(y_train == 0)), "stress": int(np.sum(y_train == 1))},
                "val": {"non_stress": int(np.sum(y_val == 0)), "stress": int(np.sum(y_val == 1))},
                "test": {"non_stress": int(np.sum(y_test == 0)), "stress": int(np.sum(y_test == 1))},
            },
            "best_epoch": int(best_epoch),
            "best_val_loss": float(best_val_loss),
            "test_metrics": {k: float(v) for k, v in test_metrics.items()},
            "normalization_mode": hp.normalization_mode,
            "loss_config": loss_cfg,
            "history": history_rows,
            "model_saved": bool(hp.save_model),
            "model_files": {
                "best_model": str(best_model_path) if hp.save_model else None,
                "final_model": str(final_model_path) if hp.save_model else None,
            },
        }
        fold_results.append(fold_result)

        print(
            "Fold test metrics:",
            {
                "accuracy": round(float(test_metrics["accuracy"]), 4),
                "f1": round(float(test_metrics["f1"]), 4),
                "loss": round(float(test_metrics["loss"]), 4),
            },
        )

    summary_df = pd.DataFrame([
        {
            "fold_index": fr["fold_index"],
            "test_subject": fr["test_subject"],
            "accuracy": fr["test_metrics"]["accuracy"],
            "precision": fr["test_metrics"]["precision"],
            "recall": fr["test_metrics"]["recall"],
            "f1": fr["test_metrics"]["f1"],
            "loss": fr["test_metrics"]["loss"],
        }
        for fr in fold_results
    ])

    metric_cols = ["accuracy", "precision", "recall", "f1", "loss"]
    agg_mean = summary_df[metric_cols].mean().to_dict() if len(summary_df) else {}
    agg_std = summary_df[metric_cols].std(ddof=0).to_dict() if len(summary_df) else {}

    metadata = {
        "created_at": datetime.now().isoformat(),
        "model_name": model_name,
        "model_type": "1D CNN + Transformer (PyTorch, LOSO)",
        "dataset_root": str(dataset_root),
        "label_definition": {
            "non_stress": ["Baseline"],
            "stress": ["Logic", "Nback", "Stroop", "Sudoku"],
        },
        "split_rule": "LOSO: 1 test subject + ~10% of remaining (4~5) for validation",
        "total_complete_subjects": len(subjects),
        "num_folds_run": len(fold_results),
        "hyperparameters": asdict(hp),
        "aggregate_metrics": {
            "mean": {k: float(v) for k, v in agg_mean.items()},
            "std": {k: float(v) for k, v in agg_std.items()},
        },
        "fold_results": fold_results,
        "device": str(device),
    }

    metadata_path = save_dir / f"{model_name}_hyperparameters.json"
    with metadata_path.open("w", encoding="utf-8") as f:
        json.dump(metadata, f, ensure_ascii=False, indent=2)

    print("\n=== LOSO Training Complete ===")
    print(f"Saved metadata (hyperparameters + metrics): {metadata_path}")
    if hp.save_model:
        print("Saved per-fold best/final checkpoints under LOSO save_dir")
    if agg_mean:
        print("Aggregate mean metrics:", {k: round(float(v), 4) for k, v in agg_mean.items()})
        print("Aggregate std metrics:", {k: round(float(v), 4) for k, v in agg_std.items()})

    return metadata


# ===== 실행 파트 =====
hp = HyperParameters(
    random_seed=42,
    val_ratio=0.1,
    min_val_subjects=4,
    max_val_subjects=5,
    window_size=240,
    stride=40,
    batch_size=64,
    epochs=50,
    learning_rate=1e-3,
    dropout_rate=0.3,
    weight_decay=1e-4,
    patience=8,
    transformer_heads=8,
    transformer_layers=2,
    transformer_ff_dim=256,
    transformer_dropout=0.1,
    normalization_mode="subject_zscore",
    loss_name="focal",
    focal_gamma=2.0,
    focal_alpha=None,
    save_model=True,
    max_folds=None,  # 빠른 테스트 시 정수로 제한 가능 (예: 3)
)

result_loso = run_loso_training(model_name="temp_1dcnn_transformer_loso_torch", hp=hp)
result_loso
# Out:
# === Fold 1/50 | Test: Sub1 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 25 (best epoch: 17)
# Fold test metrics: {'accuracy': 0.7231, 'f1': 0.8269, 'loss': 0.1078}
#
# === Fold 2/50 | Test: Sub2 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 25 (best epoch: 17)
# Fold test metrics: {'accuracy': 0.6462, 'f1': 0.7579, 'loss': 0.0667}
#
# === Fold 3/50 | Test: Sub3 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.5692, 'f1': 0.7255, 'loss': 0.0755}
#
# === Fold 4/50 | Test: Sub4 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 17 (best epoch: 9)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0134}
#
# === Fold 5/50 | Test: Sub5 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 30 (best epoch: 22)
# Fold test metrics: {'accuracy': 0.4308, 'f1': 0.6022, 'loss': 0.094}
#
# === Fold 6/50 | Test: Sub6 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 27 (best epoch: 19)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0238}
#
# === Fold 7/50 | Test: Sub7 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 24 (best epoch: 16)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0107}
#
# === Fold 8/50 | Test: Sub8 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 33 (best epoch: 25)
# Fold test metrics: {'accuracy': 0.9846, 'f1': 0.9903, 'loss': 0.0108}
#
# === Fold 9/50 | Test: Sub9 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.9538, 'f1': 0.972, 'loss': 0.0325}
#
# === Fold 10/50 | Test: Sub10 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 20 (best epoch: 12)
# Fold test metrics: {'accuracy': 0.9385, 'f1': 0.96, 'loss': 0.0206}
#
# === Fold 11/50 | Test: Sub11 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 24 (best epoch: 16)
# Fold test metrics: {'accuracy': 0.9692, 'f1': 0.9804, 'loss': 0.0256}
#
# === Fold 12/50 | Test: Sub12 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0237}
#
# === Fold 13/50 | Test: Sub13 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.9538, 'f1': 0.9703, 'loss': 0.0192}
#
# === Fold 14/50 | Test: Sub14 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 24 (best epoch: 16)
# Fold test metrics: {'accuracy': 0.8462, 'f1': 0.898, 'loss': 0.0478}
#
# === Fold 15/50 | Test: Sub15 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.4615, 'f1': 0.5977, 'loss': 0.0669}
#
# === Fold 16/50 | Test: Sub16 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 32 (best epoch: 24)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.887, 'loss': 0.0546}
#
# === Fold 17/50 | Test: Sub17 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 26 (best epoch: 18)
# Fold test metrics: {'accuracy': 0.7538, 'f1': 0.8596, 'loss': 0.0793}
#
# === Fold 18/50 | Test: Sub18 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 21 (best epoch: 13)
# Fold test metrics: {'accuracy': 0.6154, 'f1': 0.7619, 'loss': 0.1028}
#
# === Fold 19/50 | Test: Sub20 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 21 (best epoch: 13)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0086}
#
# === Fold 20/50 | Test: Sub21 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.7385, 'f1': 0.8211, 'loss': 0.0496}
#
# === Fold 21/50 | Test: Sub22 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.9846, 'f1': 0.9905, 'loss': 0.0317}
#
# === Fold 22/50 | Test: Sub23 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 17 (best epoch: 9)
# Fold test metrics: {'accuracy': 0.9231, 'f1': 0.9495, 'loss': 0.0199}
#
# === Fold 23/50 | Test: Sub24 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 28 (best epoch: 20)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0102}
#
# === Fold 24/50 | Test: Sub26 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 19 (best epoch: 11)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0173}
#
# === Fold 25/50 | Test: Sub27 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.7231, 'f1': 0.7907, 'loss': 0.0401}
#
# === Fold 26/50 | Test: Sub28 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.8923, 'f1': 0.9358, 'loss': 0.044}
#
# === Fold 27/50 | Test: Sub29 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.015}
#
# === Fold 28/50 | Test: Sub30 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 28 (best epoch: 20)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8966, 'loss': 0.0565}
#
# === Fold 29/50 | Test: Sub31 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.6923, 'f1': 0.7959, 'loss': 0.066}
#
# === Fold 30/50 | Test: Sub32 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 17 (best epoch: 9)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8966, 'loss': 0.0641}
#
# === Fold 31/50 | Test: Sub33 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 18 (best epoch: 10)
# Fold test metrics: {'accuracy': 0.9077, 'f1': 0.9423, 'loss': 0.0326}
#
# === Fold 32/50 | Test: Sub34 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 40 (best epoch: 32)
# Fold test metrics: {'accuracy': 0.5385, 'f1': 0.6939, 'loss': 0.1185}
#
# === Fold 33/50 | Test: Sub35 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 39 (best epoch: 31)
# Fold test metrics: {'accuracy': 0.2769, 'f1': 0.3733, 'loss': 0.1306}
#
# === Fold 34/50 | Test: Sub36 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 32 (best epoch: 24)
# Fold test metrics: {'accuracy': 0.9846, 'f1': 0.9903, 'loss': 0.013}
#
# === Fold 35/50 | Test: Sub37 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.4769, 'f1': 0.6458, 'loss': 0.0847}
#
# === Fold 36/50 | Test: Sub38 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 45 (best epoch: 37)
# Fold test metrics: {'accuracy': 0.9692, 'f1': 0.9804, 'loss': 0.0145}
#
# === Fold 37/50 | Test: Sub40 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 20 (best epoch: 12)
# Fold test metrics: {'accuracy': 0.6462, 'f1': 0.7723, 'loss': 0.0582}
#
# === Fold 38/50 | Test: Sub41 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 19 (best epoch: 11)
# Fold test metrics: {'accuracy': 0.7692, 'f1': 0.8315, 'loss': 0.0464}
#
# === Fold 39/50 | Test: Sub42 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.6923, 'f1': 0.7674, 'loss': 0.0495}
#
# === Fold 40/50 | Test: Sub43 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 23 (best epoch: 15)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0123}
#
# === Fold 41/50 | Test: Sub44 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 36 (best epoch: 28)
# Fold test metrics: {'accuracy': 0.9077, 'f1': 0.94, 'loss': 0.0274}
#
# === Fold 42/50 | Test: Sub45 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.8923, 'f1': 0.9278, 'loss': 0.0261}
#
# === Fold 43/50 | Test: Sub46 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 23 (best epoch: 15)
# Fold test metrics: {'accuracy': 0.9231, 'f1': 0.9541, 'loss': 0.0297}
#
# === Fold 44/50 | Test: Sub47 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.7692, 'f1': 0.8387, 'loss': 0.0407}
#
# === Fold 45/50 | Test: Sub48 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 21 (best epoch: 13)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0135}
#
# === Fold 46/50 | Test: Sub49 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 50 (best epoch: 42)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.8762, 'loss': 0.0441}
#
# === Fold 47/50 | Test: Sub50 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 27 (best epoch: 19)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8966, 'loss': 0.0577}
#
# === Fold 48/50 | Test: Sub51 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.5231, 'f1': 0.6517, 'loss': 0.0622}
#
# === Fold 49/50 | Test: Sub52 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 20 (best epoch: 12)
# Fold test metrics: {'accuracy': 0.9846, 'f1': 0.9903, 'loss': 0.0292}
#
# === Fold 50/50 | Test: Sub53 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 24 (best epoch: 16)
# Fold test metrics: {'accuracy': 0.7231, 'f1': 0.8393, 'loss': 0.078}
#
# === LOSO Training Complete ===
# Saved metadata (hyperparameters + metrics): /home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_hyperparameters.json
# Saved per-fold best/final checkpoints under LOSO save_dir
# Aggregate mean metrics: {'accuracy': 0.8166, 'precision': 0.9039, 'recall': 0.86, 'f1': 0.8756, 'loss': 0.0454}
# Aggregate std metrics: {'accuracy': 0.1831, 'precision': 0.1094, 'recall': 0.1701, 'f1': 0.1356, 'loss': 0.0304}
# {'created_at': '2026-04-21T21:42:28.127164',
#  'model_name': 'temp_1dcnn_transformer_loso_torch',
#  'model_type': '1D CNN + Transformer (PyTorch, LOSO)',
#  'dataset_root': '/home/binghin2/Myproject/Dataset/CATSA',
#  'label_definition': {'non_stress': ['Baseline'],
#   'stress': ['Logic', 'Nback', 'Stroop', 'Sudoku']},
#  'split_rule': 'LOSO: 1 test subject + ~10% of remaining (4~5) for validation',
#  'total_complete_subjects': 50,
#  'num_folds_run': 50,
#  'hyperparameters': {'random_seed': 42,
#   'val_ratio': 0.1,
#   'min_val_subjects': 4,
#   'max_val_subjects': 5,
#   'window_size': 240,
#   'stride': 40,
#   'batch_size': 64,
#   'epochs': 50,
#   'learning_rate': 0.001,
#   'dropout_rate': 0.3,
#   'weight_decay': 0.0001,
#   'patience': 8,
#   'transformer_heads': 8,
#   'transformer_layers': 2,
#   'transformer_ff_dim': 256,
#   'transformer_dropout': 0.1,
#   'normalization_mode': 'subject_zscore',
#   'loss_name': 'focal',
#   'focal_gamma': 2.0,
#   'focal_alpha': None,
#   'save_model': True,
#   'max_folds': None},
#  'aggregate_metrics': {'mean': {'accuracy': 0.8166153846153845,
#    'precision': 0.903870442369311,
#    'recall': 0.86,
#    'f1': 0.8755597652267363,
#    'loss': 0.04535188309522345},
#   'std': {'accuracy': 0.18314387915890823,
#    'precision': 0.10941794734242158,
#    'recall': 0.17010438841658343,
#    'f1': 0.13557085409160377,
#    'loss': 0.030416601755851654}},
#  'fold_results': [{'fold_index': 1,
#    'test_subject': 'Sub1',
#    'split': {'train': ['Sub2',
#      'Sub3',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub37',
#      'Sub38',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub7', 'Sub27', 'Sub36', 'Sub43', 'Sub51'],
#     'test': ['Sub1']},
#    'sample_shapes': {'x_train': [2860, 1, 240],
#     'x_val': [325, 1, 240],
#     'x_test': [65, 1, 240]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2288},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 17,
#    'best_val_loss': 0.02304798697049801,
#    'test_metrics': {'loss': 0.10783408036312232,
#     'accuracy': 0.7230769230769231,
#     'precision': 0.8269230769230769,
#     'recall': 0.8269230769230769,
#     'f1': 0.8269230769230769,
#     'tn': 4.0,
#     'fp': 9.0,
#     'fn': 9.0,
#     'tp': 43.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.2,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.04924089454791763,
#      'val_loss': 0.03109532559147248,
#      'val_accuracy': 0.8707692307692307,
#      'val_f1': 0.9153225806451614,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.046055508123619575,
#      'val_loss': 0.0344704709144739,
#      'val_accuracy': 0.8061538461538461,
#      'val_f1': 0.8662420382165605,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.046620506136775854,
#      'val_loss': 0.037628096267580985,
#      'val_accuracy': 0.8215384615384616,
#      'val_f1': 0.8821138211382114,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.0447202200083049,
#      'val_loss': 0.03627341071000466,
#      'val_accuracy': 0.76,
#      'val_f1': 0.8296943231441049,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.044180223934508704,
#      'val_loss': 0.034613541444906824,
#      'val_accuracy': 0.8615384615384616,
#      'val_f1': 0.909456740442656,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.04402894076038074,
#      'val_loss': 0.03483186531525392,
#      'val_accuracy': 0.7230769230769231,
#      'val_f1': 0.7963800904977376,
#      'lr': 0.0005},
#     {'epoch': 7.0,
#      'train_loss': 0.044006296215982704,
#      'val_loss': 0.035704588844225955,
#      'val_accuracy': 0.8523076923076923,
#      'val_f1': 0.9051383399209486,
#      'lr': 0.0005},
#     {'epoch': 8.0,
#      'train_loss': 0.041649548245685085,
#      'val_loss': 0.02807813097651188,
#      'val_accuracy': 0.9323076923076923,
#      'val_f1': 0.9576923076923077,
#      'lr': 0.0005},
#     {'epoch': 9.0,
#      'train_loss': 0.04045325456695123,
#      'val_loss': 0.031151636735751078,
#      'val_accuracy': 0.8984615384615384,
#      'val_f1': 0.9354207436399217,
#      'lr': 0.0005},
#     {'epoch': 10.0,
#      'train_loss': 0.04153303492006722,
#      'val_loss': 0.026405529397038312,
#      'val_accuracy': 0.8984615384615384,
#      'val_f1': 0.9346534653465347,
#      'lr': 0.0005},
#     {'epoch': 11.0,
#      'train_loss': 0.03967494541531676,
#      'val_loss': 0.026835380574831594,
#      'val_accuracy': 0.9015384615384615,
#      'val_f1': 0.9372549019607843,
#      'lr': 0.0005},
#     {'epoch': 12.0,
#      'train_loss': 0.038682772766251663,
#      'val_loss': 0.028203112706542015,
#      'val_accuracy': 0.9446153846153846,
#      'val_f1': 0.9664179104477613,
#      'lr': 0.0005},
#     {'epoch': 13.0,
#      'train_loss': 0.03763197455164436,
#      'val_loss': 0.027811452694810355,
#      'val_accuracy': 0.9415384615384615,
#      'val_f1': 0.9644859813084112,
#      'lr': 0.0005},
#     {'epoch': 14.0,
#      'train_loss': 0.03749985587815721,
#      'val_loss': 0.027455009502860218,
#      'val_accuracy': 0.96,
#      'val_f1': 0.975609756097561,
#      'lr': 0.0005},
#     {'epoch': 15.0,
#      'train_loss': 0.03796617173023157,
#      'val_loss': 0.029307810314572774,
#      'val_accuracy': 0.92,
#      'val_f1': 0.9503816793893131,
#      'lr': 0.00025},
#     {'epoch': 16.0,
#      'train_loss': 0.03629872418054334,
#      'val_loss': 0.02700395322763003,
#      'val_accuracy': 0.9538461538461539,
#      'val_f1': 0.9719626168224299,
#      'lr': 0.00025},
#     {'epoch': 17.0,
#      'train_loss': 0.03606698154830015,
#      'val_loss': 0.02304798697049801,
#      'val_accuracy': 0.9138461538461539,
#      'val_f1': 0.9448818897637796,
#      'lr': 0.00025},
#     {'epoch': 18.0,
#      'train_loss': 0.03697546350059809,
#      'val_loss': 0.02442217711645823,
#      'val_accuracy': 0.9230769230769231,
#      'val_f1': 0.9521988527724666,
#      'lr': 0.00025},
#     {'epoch': 19.0,
#      'train_loss': 0.03583478609790335,
#      'val_loss': 0.027813709859664623,
#      'val_accuracy': 0.9384615384615385,
#      'val_f1': 0.962406015037594,
#      'lr': 0.00025},
#     {'epoch': 20.0,
#      'train_loss': 0.03582192779733585,
#      'val_loss': 0.02319503041414114,
#      'val_accuracy': 0.9323076923076923,
#      'val_f1': 0.9573643410852712,
#      'lr': 0.00025},
#     {'epoch': 21.0,
#      'train_loss': 0.035764378632282046,
#      'val_loss': 0.025713757494321237,
#      'val_accuracy': 0.8984615384615384,
#      'val_f1': 0.935672514619883,
#      'lr': 0.00025},
#     {'epoch': 22.0,
#      'train_loss': 0.03468296411675173,
#      'val_loss': 0.023939110373075192,
#      'val_accuracy': 0.9384615384615385,
#      'val_f1': 0.962121212121212,
#      'lr': 0.000125},
#     {'epoch': 23.0,
#      'train_loss': 0.034934435852549295,
#      'val_loss': 0.02543548034933897,
#      'val_accuracy': 0.8953846153846153,
#      'val_f1': 0.9338521400778211,
#      'lr': 0.000125},
#     {'epoch': 24.0,
#      'train_loss': 0.03407916322715216,
#      'val_loss': 0.024636178529606416,
#      'val_accuracy': 0.9323076923076923,
#      'val_f1': 0.9581749049429658,
#      'lr': 0.000125},
#     {'epoch': 25.0,
#      'train_loss': 0.03528512884322163,
#      'val_loss': 0.023723004448872344,
#      'val_accuracy': 0.92,
#      'val_f1': 0.9490196078431372,
#      'lr': 0.000125}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_01_Sub1_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_01_Sub1.pt'}},
#   {'fold_index': 2,
#    'test_subject': 'Sub2',
#    'split': {'train': ['Sub1',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub38',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub51',
#      'Sub53'],
#     'val': ['Sub3', 'Sub7', 'Sub33', 'Sub45', 'Sub52'],
#     'test': ['Sub2']},
#    'sample_shapes': {'x_train': [2860, 1, 240],
#     'x_val': [325, 1, 240],
#     'x_test': [65, 1, 240]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2288},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 17,
#    'best_val_loss': 0.027400365557808143,
#    'test_metrics': {'loss': 0.06669598095692121,
#     'accuracy': 0.6461538461538462,
#     'precision': 0.8372093023255814,
#     'recall': 0.6923076923076923,
#     'f1': 0.7578947368421053,
#     'tn': 6.0,
#     'fp': 7.0,
#     'fn': 16.0,
#     'tp': 36.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.2,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.04851024319658746,
#      'val_loss': 0.029527701385892356,
#      'val_accuracy': 0.916923076923077,
#      'val_f1': 0.948176583493282,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.04581619919492648,
#      'val_loss': 0.03442238127956024,
#      'val_accuracy': 0.8523076923076923,
#      'val_f1': 0.9036144578313253,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.04648616746901632,
#      'val_loss': 0.03136782343571003,
#      'val_accuracy': 0.8553846153846154,
#      'val_f1': 0.9058116232464929,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.04392197669281826,
#      'val_loss': 0.03189907846542505,
#      'val_accuracy': 0.8646153846153846,
#      'val_f1': 0.9123505976095618,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.04311602619978098,
#      'val_loss': 0.030724921874128855,
#      'val_accuracy': 0.8676923076923077,
#      'val_f1': 0.9145129224652089,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.04229471136431594,
#      'val_loss': 0.032106172683147284,
#      'val_accuracy': 0.9107692307692308,
#      'val_f1': 0.9439071566731141,
#      'lr': 0.0005},
#     {'epoch': 7.0,
#      'train_loss': 0.03950978896313614,
#      'val_loss': 0.032832007499841546,
#      'val_accuracy': 0.8923076923076924,
#      'val_f1': 0.9315068493150686,
#      'lr': 0.0005},
#     {'epoch': 8.0,
#      'train_loss': 0.038361544203716555,
#      'val_loss': 0.029470010915627846,
#      'val_accuracy': 0.9076923076923077,
#      'val_f1': 0.9418604651162791,
#      'lr': 0.0005},
#     {'epoch': 9.0,
#      'train_loss': 0.0399736788201999,
#      'val_loss': 0.02796408746104974,
#      'val_accuracy': 0.88,
#      'val_f1': 0.9230769230769231,
#      'lr': 0.0005},
#     {'epoch': 10.0,
#      'train_loss': 0.0380696883542346,
#      'val_loss': 0.028590123917047794,
#      'val_accuracy': 0.9015384615384615,
#      'val_f1': 0.9377431906614787,
#      'lr': 0.0005},
#     {'epoch': 11.0,
#      'train_loss': 0.03857140416031951,
#      'val_loss': 0.03630726238282827,
#      'val_accuracy': 0.9353846153846154,
#      'val_f1': 0.960747663551402,
#      'lr': 0.0005},
#     {'epoch': 12.0,
#      'train_loss': 0.03852125135335055,
#      'val_loss': 0.028724989759234282,
#      'val_accuracy': 0.8707692307692307,
#      'val_f1': 0.9163346613545816,
#      'lr': 0.0005},
#     {'epoch': 13.0,
#      'train_loss': 0.03760150359435515,
#      'val_loss': 0.03371231234417512,
#      'val_accuracy': 0.9046153846153846,
#      'val_f1': 0.939571150097466,
#      'lr': 0.0005},
#     {'epoch': 14.0,
#      'train_loss': 0.038273995854221025,
#      'val_loss': 0.02794362473946351,
#      'val_accuracy': 0.8892307692307693,
#      'val_f1': 0.9294117647058824,
#      'lr': 0.0005},
#     {'epoch': 15.0,
#      'train_loss': 0.03670660917471339,
#      'val_loss': 0.028320404996092504,
#      'val_accuracy': 0.8861538461538462,
#      'val_f1': 0.9289827255278311,
#      'lr': 0.0005},
#     {'epoch': 16.0,
#      'train_loss': 0.03568600539404612,
#      'val_loss': 0.027895499861870822,
#      'val_accuracy': 0.9076923076923077,
#      'val_f1': 0.9418604651162791,
#      'lr': 0.0005},
#     {'epoch': 17.0,
#      'train_loss': 0.037185641539680375,
#      'val_loss': 0.027400365557808143,
#      'val_accuracy': 0.9107692307692308,
#      'val_f1': 0.9439071566731141,
#      'lr': 0.0005},
#     {'epoch': 18.0,
#      'train_loss': 0.036954974591523616,
#      'val_loss': 0.03253228616542541,
#      'val_accuracy': 0.8830769230769231,
#      'val_f1': 0.928030303030303,
#      'lr': 0.0005},
#     {'epoch': 19.0,
#      'train_loss': 0.03716327519891979,
#      'val_loss': 0.03027971436771063,
#      'val_accuracy': 0.9138461538461539,
#      'val_f1': 0.9467680608365019,
#      'lr': 0.0005},
#     {'epoch': 20.0,
#      'train_loss': 0.0363029743043276,
#      'val_loss': 0.03517390988767147,
#      'val_accuracy': 0.8769230769230769,
#      'val_f1': 0.9259259259259259,
#      'lr': 0.0005},
#     {'epoch': 21.0,
#      'train_loss': 0.036916641067791654,
#      'val_loss': 0.029215800578777606,
#      'val_accuracy': 0.9076923076923077,
#      'val_f1': 0.9418604651162791,
#      'lr': 0.0005},
#     {'epoch': 22.0,
#      'train_loss': 0.036243075049006854,
#      'val_loss': 0.032169069266663144,
#      'val_accuracy': 0.9046153846153846,
#      'val_f1': 0.9416195856873824,
#      'lr': 0.00025},
#     {'epoch': 23.0,
#      'train_loss': 0.034552099743297884,
#      'val_loss': 0.030836808738800195,
#      'val_accuracy': 0.88,
#      'val_f1': 0.9236790606653621,
#      'lr': 0.00025},
#     {'epoch': 24.0,
#      'train_loss': 0.034171926917938085,
#      'val_loss': 0.030684296199335503,
#      'val_accuracy': 0.9076923076923077,
#      'val_f1': 0.9427480916030533,
#      'lr': 0.00025},
#     {'epoch': 25.0,
#      'train_loss': 0.03447397950437519,
#      'val_loss': 0.029219802592236263,
#      'val_accuracy': 0.9076923076923077,
#      'val_f1': 0.9433962264150944,
#      'lr': 0.00025}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_02_Sub2_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_02_Sub2.pt'}},
#   {'fold_index': 3,
#    'test_subject': 'Sub3',
#    'split': {'train': ['Sub2',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub7',
#      'Sub8',
#      'Sub9',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub38',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub45',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub51',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub1', 'Sub10', 'Sub31', 'Sub46', 'Sub50'],
#     'test': ['Sub3']},
#    'sample_shapes': {'x_train': [2860, 1, 240],
#     'x_val': [325, 1, 240],
#     'x_test': [65, 1, 240]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2288},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 2,
#    'best_val_loss': 0.04501402398141531,
#    'test_metrics': {'loss': 0.07545550740682162,
#     'accuracy': 0.5692307692307692,
#     'precision': 0.74,
#     'recall': 0.7115384615384616,
#     'f1': 0.7254901960784313,
#     'tn': 0.0,
#     'fp': 13.0,
#     'fn': 15.0,
#     'tp': 37.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.2,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.04486966776576909,
#      'val_loss': 0.0458927819190117,
#      'val_accuracy': 0.8215384615384616,
#      'val_f1': 0.8862745098039216,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.0450393259577401,
#      'val_loss': 0.04501402398141531,
#      'val_accuracy': 0.8,
#      'val_f1': 0.8717948717948718,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.04409176078397077,
#      'val_loss': 0.05314046176007161,
#      'val_accuracy': 0.7753846153846153,
#      'val_f1': 0.858252427184466,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.044123547586736145,
#      'val_loss': 0.04831822965580684,
#      'val_accuracy': 0.7753846153846153,
#      'val_f1': 0.856581532416503,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.041906502092634884,
#      'val_loss': 0.056800380629988816,
#      'val_accuracy': 0.8092307692307692,
#      'val_f1': 0.8821292775665398,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.042697742560526705,
#      'val_loss': 0.049791510285666356,
#      'val_accuracy': 0.7784615384615384,
#      'val_f1': 0.859375,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.04018201227788325,
#      'val_loss': 0.05377249709402139,
#      'val_accuracy': 0.8338461538461538,
#      'val_f1': 0.8992537313432836,
#      'lr': 0.0005},
#     {'epoch': 8.0,
#      'train_loss': 0.03818071972240101,
#      'val_loss': 0.05115996137834512,
#      'val_accuracy': 0.7846153846153846,
#      'val_f1': 0.86328125,
#      'lr': 0.0005},
#     {'epoch': 9.0,
#      'train_loss': 0.038249384679577565,
#      'val_loss': 0.05046597059529561,
#      'val_accuracy': 0.7938461538461539,
#      'val_f1': 0.8673267326732673,
#      'lr': 0.0005},
#     {'epoch': 10.0,
#      'train_loss': 0.03664721456076299,
#      'val_loss': 0.057676161980399716,
#      'val_accuracy': 0.8,
#      'val_f1': 0.8717948717948718,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_03_Sub3_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_03_Sub3.pt'}},
#   {'fold_index': 4,
#    'test_subject': 'Sub4',
#    'split': {'train': ['Sub1',
#      'Sub2',
#      'Sub3',
#      'Sub5',
#      'Sub6',
#      'Sub7',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub38',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub44',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub51',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub8', 'Sub14', 'Sub43', 'Sub45', 'Sub50'],
#     'test': ['Sub4']},
#    'sample_shapes': {'x_train': [2860, 1, 240],
#     'x_val': [325, 1, 240],
#     'x_test': [65, 1, 240]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2288},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 9,
#    'best_val_loss': 0.02543180498939294,
#    'test_metrics': {'loss': 0.013376533542759717,
#     'accuracy': 1.0,
#     'precision': 1.0,
#     'recall': 1.0,
#     'f1': 1.0,
#     'tn': 13.0,
#     'fp': 0.0,
#     'fn': 0.0,
#     'tp': 52.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.2,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.049780497361313215,
#      'val_loss': 0.03210776844563393,
#      'val_accuracy': 0.9415384615384615,
#      'val_f1': 0.9638095238095238,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.04722501013975043,
#      'val_loss': 0.03281511737750127,
#      'val_accuracy': 0.9415384615384615,
#      'val_f1': 0.9638095238095238,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.046482025743364457,
#      'val_loss': 0.02847688111834801,
#      'val_accuracy': 0.9107692307692308,
#      'val_f1': 0.9436893203883495,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.04491269910460585,
#      'val_loss': 0.03267038390040398,
#      'val_accuracy': 0.8861538461538462,
#      'val_f1': 0.9270216962524656,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.04488367860342239,
#      'val_loss': 0.03580177363867943,
#      'val_accuracy': 0.9292307692307692,
#      'val_f1': 0.9558541266794626,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.042684244776105544,
#      'val_loss': 0.03463979624211788,
#      'val_accuracy': 0.88,
#      'val_f1': 0.9227722772277227,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.041495295379545306,
#      'val_loss': 0.02659499977930234,
#      'val_accuracy': 0.9384615384615385,
#      'val_f1': 0.9618320610687022,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.041613731559339937,
#      'val_loss': 0.027514846238952416,
#      'val_accuracy': 0.8830769230769231,
#      'val_f1': 0.9249011857707511,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.039979272075257935,
#      'val_loss': 0.02543180498939294,
#      'val_accuracy': 0.9353846153846154,
#      'val_f1': 0.9603024574669187,
#      'lr': 0.001},
#     {'epoch': 10.0,
#      'train_loss': 0.040776622712195336,
#      'val_loss': 0.02851953080067268,
#      'val_accuracy': 0.9138461538461539,
#      'val_f1': 0.9473684210526316,
#      'lr': 0.001},
#     {'epoch': 11.0,
#      'train_loss': 0.04038477759886455,
#      'val_loss': 0.028898843051149294,
#      'val_accuracy': 0.9292307692307692,
#      'val_f1': 0.9558541266794626,
#      'lr': 0.001},
#     {'epoch': 12.0,
#      'train_loss': 0.039430240150931835,
#      'val_loss': 0.025963944809941145,
#      'val_accuracy': 0.9230769230769231,
#      'val_f1': 0.9523809523809524,
#      'lr': 0.001},
#     {'epoch': 13.0,
#      'train_loss': 0.037679314175685805,
#      'val_loss': 0.030713545725895807,
#      'val_accuracy': 0.9076923076923077,
#      'val_f1': 0.9433962264150944,
#      'lr': 0.001},
#     {'epoch': 14.0,
#      'train_loss': 0.0373369198005933,
#      'val_loss': 0.03050946245972927,
#      'val_accuracy': 0.916923076923077,
#      'val_f1': 0.9493433395872422,
#      'lr': 0.0005},
#     {'epoch': 15.0,
#      'train_loss': 0.03821834838473714,
#      'val_loss': 0.028168089223595767,
#      'val_accuracy': 0.9323076923076923,
#      'val_f1': 0.9583333333333333,
#      'lr': 0.0005},
#     {'epoch': 16.0,
#      'train_loss': 0.03593359552584328,
#      'val_loss': 0.028026809784082268,
#      'val_accuracy': 0.9230769230769231,
#      'val_f1': 0.9529190207156308,
#      'lr': 0.0005},
#     {'epoch': 17.0,
#      'train_loss': 0.03586888822850647,
#      'val_loss': 0.02609362049171558,
#      'val_accuracy': 0.92,
#      'val_f1': 0.9505703422053231,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_04_Sub4_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_04_Sub4.pt'}},
#   {'fold_index': 5,
#    'test_subject': 'Sub5',
#    'split': {'train': ['Sub1',
#      'Sub2',
#      'Sub3',
#      'Sub4',
#      'Sub6',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub14',
#      'Sub15',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub50',
#      'Sub51',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub7', 'Sub13', 'Sub16', 'Sub38', 'Sub49'],
#     'test': ['Sub5']},
#    'sample_shapes': {'x_train': [2860, 1, 240],
#     'x_val': [325, 1, 240],
#     'x_test': [65, 1, 240]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2288},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 22,
#    'best_val_loss': 0.025502240302471012,
#    'test_metrics': {'loss': 0.09399451558621456,
#     'accuracy': 0.4307692307692308,
#     'precision': 0.6829268292682927,
#     'recall': 0.5384615384615384,
#     'f1': 0.6021505376344086,
#     'tn': 0.0,
#     'fp': 13.0,
#     'fn': 24.0,
#     'tp': 28.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.2,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.04995920979580679,
#      'val_loss': 0.04115221098065376,
#      'val_accuracy': 0.8615384615384616,
#      'val_f1': 0.9075975359342916,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.045187255099311575,
#      'val_loss': 0.04516357228159904,
#      'val_accuracy': 0.8184615384615385,
#      'val_f1': 0.8858800773694391,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.04294016645713286,
#      'val_loss': 0.04705977976322174,
#      'val_accuracy': 0.41846153846153844,
#      'val_f1': 0.42900302114803623,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.04518808817321604,
#      'val_loss': 0.0318853848026349,
#      'val_accuracy': 0.8276923076923077,
#      'val_f1': 0.8793103448275863,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.044414825758317136,
#      'val_loss': 0.03424136881644909,
#      'val_accuracy': 0.8553846153846154,
#      'val_f1': 0.9010526315789473,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.04354428437935722,
#      'val_loss': 0.04450587586714671,
#      'val_accuracy': 0.8092307692307692,
#      'val_f1': 0.87890625,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.04299055802134367,
#      'val_loss': 0.03699739465346703,
#      'val_accuracy': 0.8584615384615385,
#      'val_f1': 0.9068825910931174,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.0447944236072627,
#      'val_loss': 0.040177787989377975,
#      'val_accuracy': 0.8,
#      'val_f1': 0.860215053763441,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.04196659611551078,
#      'val_loss': 0.05035600357330763,
#      'val_accuracy': 0.7907692307692308,
#      'val_f1': 0.8692307692307693,
#      'lr': 0.0005},
#     {'epoch': 10.0,
#      'train_loss': 0.04127092618312869,
#      'val_loss': 0.03294257136491629,
#      'val_accuracy': 0.8461538461538461,
#      'val_f1': 0.9003984063745021,
#      'lr': 0.0005},
#     {'epoch': 11.0,
#      'train_loss': 0.03846051580943428,
#      'val_loss': 0.035760643482208254,
#      'val_accuracy': 0.8584615384615385,
#      'val_f1': 0.9128787878787878,
#      'lr': 0.0005},
#     {'epoch': 12.0,
#      'train_loss': 0.03882405134764585,
#      'val_loss': 0.031078221110197216,
#      'val_accuracy': 0.88,
#      'val_f1': 0.9248554913294799,
#      'lr': 0.0005},
#     {'epoch': 13.0,
#      'train_loss': 0.03797556798045452,
#      'val_loss': 0.03592232817640671,
#      'val_accuracy': 0.8369230769230769,
#      'val_f1': 0.8970873786407768,
#      'lr': 0.0005},
#     {'epoch': 14.0,
#      'train_loss': 0.039551370590925214,
#      'val_loss': 0.030426191756358512,
#      'val_accuracy': 0.88,
#      'val_f1': 0.9227722772277227,
#      'lr': 0.0005},
#     {'epoch': 15.0,
#      'train_loss': 0.03740814297453507,
#      'val_loss': 0.043214794506247226,
#      'val_accuracy': 0.8215384615384616,
#      'val_f1': 0.8921933085501859,
#      'lr': 0.0005},
#     {'epoch': 16.0,
#      'train_loss': 0.037524544088156905,
#      'val_loss': 0.02970870383656942,
#      'val_accuracy': 0.8830769230769231,
#      'val_f1': 0.9251968503937008,
#      'lr': 0.0005},
#     {'epoch': 17.0,
#      'train_loss': 0.036611450515635365,
#      'val_loss': 0.030392098266344803,
#      'val_accuracy': 0.8769230769230769,
#      'val_f1': 0.9227799227799227,
#      'lr': 0.0005},
#     {'epoch': 18.0,
#      'train_loss': 0.03770869560800232,
#      'val_loss': 0.03525555265637544,
#      'val_accuracy': 0.8646153846153846,
#      'val_f1': 0.9153846153846154,
#      'lr': 0.0005},
#     {'epoch': 19.0,
#      'train_loss': 0.03706168491210971,
#      'val_loss': 0.0322276631456155,
#      'val_accuracy': 0.8615384615384616,
#      'val_f1': 0.9126213592233009,
#      'lr': 0.0005},
#     {'epoch': 20.0,
#      'train_loss': 0.0363113281297517,
#      'val_loss': 0.060441683794443424,
#      'val_accuracy': 0.8153846153846154,
#      'val_f1': 0.8867924528301887,
#      'lr': 0.0005},
#     {'epoch': 21.0,
#      'train_loss': 0.03801654277929476,
#      'val_loss': 0.03295652760909154,
#      'val_accuracy': 0.8584615384615385,
#      'val_f1': 0.9111969111969112,
#      'lr': 0.00025},
#     {'epoch': 22.0,
#      'train_loss': 0.036551022500945975,
#      'val_loss': 0.025502240302471012,
#      'val_accuracy': 0.8646153846153846,
#      'val_f1': 0.9126984126984127,
#      'lr': 0.00025},
#     {'epoch': 23.0,
#      'train_loss': 0.03629142303358425,
#      'val_loss': 0.027012041543538753,
#      'val_accuracy': 0.8676923076923077,
#      'val_f1': 0.9148514851485148,
#      'lr': 0.00025},
#     {'epoch': 24.0,
#      'train_loss': 0.03554353708258042,
#      'val_loss': 0.027536240552480405,
#      'val_accuracy': 0.8830769230769231,
#      'val_f1': 0.9260700389105059,
#      'lr': 0.00025},
#     {'epoch': 25.0,
#      'train_loss': 0.03511265611627719,
#      'val_loss': 0.03159575795898071,
#      'val_accuracy': 0.84,
#      'val_f1': 0.900383141762452,
#      'lr': 0.00025},
#     {'epoch': 26.0,
#      'train_loss': 0.03580581044087877,
#      'val_loss': 0.03441027800624187,
#      'val_accuracy': 0.8553846153846154,
#      'val_f1': 0.9108159392789373,
#      'lr': 0.00025},
#     {'epoch': 27.0,
#      'train_loss': 0.03576402723059788,
#      'val_loss': 0.030017697455791328,
#      'val_accuracy': 0.8461538461538461,
#      'val_f1': 0.9011857707509882,
#      'lr': 0.000125},
#     {'epoch': 28.0,
#      'train_loss': 0.03506573498040646,
#      'val_loss': 0.03205058550605407,
#      'val_accuracy': 0.8553846153846154,
#      'val_f1': 0.9090909090909091,
#      'lr': 0.000125},
#     {'epoch': 29.0,
#      'train_loss': 0.03507266803221269,
#      'val_loss': 0.029405919703153465,
#      'val_accuracy': 0.8184615384615385,
#      'val_f1': 0.8817635270541082,
#      'lr': 0.000125},
#     {'epoch': 30.0,
#      'train_loss': 0.034613479512346376,
#      'val_loss': 0.03426954341622499,
#      'val_accuracy': 0.796923076923077,
#      'val_f1': 0.8690476190476191,
#      'lr': 0.000125}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_05_Sub5_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_05_Sub5.pt'}},
#   {'fold_index': 6,
#    'test_subject': 'Sub6',
#    'split': {'train': ['Sub1',
#      'Sub3',
#      'Sub4',
#      'Sub5',
#      'Sub7',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub40',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub51',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub2', 'Sub8', 'Sub28', 'Sub38', 'Sub41'],
#     'test': ['Sub6']},
#    'sample_shapes': {'x_train': [2860, 1, 240],
#     'x_val': [325, 1, 240],
#     'x_test': [65, 1, 240]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2288},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 19,
#    'best_val_loss': 0.037860282029096894,
#    'test_metrics': {'loss': 0.023755911049934533,
#     'accuracy': 1.0,
#     'precision': 1.0,
#     'recall': 1.0,
#     'f1': 1.0,
#     'tn': 13.0,
#     'fp': 0.0,
#     'fn': 0.0,
#     'tp': 52.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.2,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.0479700971785542,
#      'val_loss': 0.04575079480042824,
#      'val_accuracy': 0.7415384615384616,
#      'val_f1': 0.8197424892703863,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.045559573298567656,
#      'val_loss': 0.04818178048500648,
#      'val_accuracy': 0.7353846153846154,
#      'val_f1': 0.8193277310924371,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.045574173852280304,
#      'val_loss': 0.053920502267204795,
#      'val_accuracy': 0.7753846153846153,
#      'val_f1': 0.8554455445544554,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.04492820649297087,
#      'val_loss': 0.04670991057386765,
#      'val_accuracy': 0.6923076923076923,
#      'val_f1': 0.7737556561085972,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.04345066522384857,
#      'val_loss': 0.05643995385330457,
#      'val_accuracy': 0.6984615384615385,
#      'val_f1': 0.7941176470588235,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.04304587193406545,
#      'val_loss': 0.050391922936989714,
#      'val_accuracy': 0.683076923076923,
#      'val_f1': 0.7664399092970521,
#      'lr': 0.0005},
#     {'epoch': 7.0,
#      'train_loss': 0.04325343762244378,
#      'val_loss': 0.048537257462739944,
#      'val_accuracy': 0.8307692307692308,
#      'val_f1': 0.8927875243664717,
#      'lr': 0.0005},
#     {'epoch': 8.0,
#      'train_loss': 0.04133446800125229,
#      'val_loss': 0.0436350714128751,
#      'val_accuracy': 0.8,
#      'val_f1': 0.8659793814432989,
#      'lr': 0.0005},
#     {'epoch': 9.0,
#      'train_loss': 0.040408608015183804,
#      'val_loss': 0.0412839514360978,
#      'val_accuracy': 0.803076923076923,
#      'val_f1': 0.868312757201646,
#      'lr': 0.0005},
#     {'epoch': 10.0,
#      'train_loss': 0.038599051576811115,
#      'val_loss': 0.042345273792743686,
#      'val_accuracy': 0.8369230769230769,
#      'val_f1': 0.8970873786407768,
#      'lr': 0.0005},
#     {'epoch': 11.0,
#      'train_loss': 0.04042177028901927,
#      'val_loss': 0.04344101382562748,
#      'val_accuracy': 0.8461538461538461,
#      'val_f1': 0.9027237354085603,
#      'lr': 0.0005},
#     {'epoch': 12.0,
#      'train_loss': 0.03777232458749851,
#      'val_loss': 0.04069789009598585,
#      'val_accuracy': 0.8153846153846154,
#      'val_f1': 0.8799999999999999,
#      'lr': 0.0005},
#     {'epoch': 13.0,
#      'train_loss': 0.03764676466792614,
#      'val_loss': 0.03988498778297351,
#      'val_accuracy': 0.8369230769230769,
#      'val_f1': 0.8974854932301741,
#      'lr': 0.0005},
#     {'epoch': 14.0,
#      'train_loss': 0.03740441911183037,
#      'val_loss': 0.04307444499662289,
#      'val_accuracy': 0.8369230769230769,
#      'val_f1': 0.8962818003913893,
#      'lr': 0.0005},
#     {'epoch': 15.0,
#      'train_loss': 0.03753249748395039,
#      'val_loss': 0.04033291365091617,
#      'val_accuracy': 0.8246153846153846,
#      'val_f1': 0.8862275449101795,
#      'lr': 0.0005},
#     {'epoch': 16.0,
#      'train_loss': 0.03682926679616208,
#      'val_loss': 0.041148432963169536,
#      'val_accuracy': 0.8492307692307692,
#      'val_f1': 0.9063097514340344,
#      'lr': 0.0005},
#     {'epoch': 17.0,
#      'train_loss': 0.037476406678870006,
#      'val_loss': 0.040821450215119584,
#      'val_accuracy': 0.8430769230769231,
#      'val_f1': 0.9005847953216374,
#      'lr': 0.0005},
#     {'epoch': 18.0,
#      'train_loss': 0.03726939983613841,
#      'val_loss': 0.04293954501358362,
#      'val_accuracy': 0.8276923076923077,
#      'val_f1': 0.8923076923076924,
#      'lr': 0.00025},
#     {'epoch': 19.0,
#      'train_loss': 0.03595289183142302,
#      'val_loss': 0.037860282029096894,
#      'val_accuracy': 0.8338461538461538,
#      'val_f1': 0.8928571428571428,
#      'lr': 0.00025},
#     {'epoch': 20.0,
#      'train_loss': 0.03556838137182322,
#      'val_loss': 0.04029683224283732,
#      'val_accuracy': 0.8461538461538461,
#      'val_f1': 0.9031007751937985,
#      'lr': 0.00025},
#     {'epoch': 21.0,
#      'train_loss': 0.03566906799699043,
#      'val_loss': 0.0398709067931542,
#      'val_accuracy': 0.8461538461538461,
#      'val_f1': 0.9027237354085603,
#      'lr': 0.00025},
#     {'epoch': 22.0,
#      'train_loss': 0.0352183972830539,
#      'val_loss': 0.041065128732186096,
#      'val_accuracy': 0.8307692307692308,
#      'val_f1': 0.8936170212765957,
#      'lr': 0.00025},
#     {'epoch': 23.0,
#      'train_loss': 0.034818502077897946,
#      'val_loss': 0.041576748920174746,
#      'val_accuracy': 0.8461538461538461,
#      'val_f1': 0.9031007751937985,
#      'lr': 0.00025},
#     {'epoch': 24.0,
# ...
#      'Sub41',
#      'Sub42',
#      'Sub44',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub1', 'Sub3', 'Sub35', 'Sub43', 'Sub45'],
#     'test': ['Sub51']},
#    'sample_shapes': {'x_train': [2860, 1, 240],
#     'x_val': [325, 1, 240],
#     'x_test': [65, 1, 240]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2288},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 4,
#    'best_val_loss': 0.04169353722379758,
#    'test_metrics': {'loss': 0.06219671001801124,
#     'accuracy': 0.5230769230769231,
#     'precision': 0.7837837837837838,
#     'recall': 0.5576923076923077,
#     'f1': 0.651685393258427,
#     'tn': 5.0,
#     'fp': 8.0,
#     'fn': 23.0,
#     'tp': 29.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.2,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.048856361095721904,
#      'val_loss': 0.04326658760698942,
#      'val_accuracy': 0.8307692307692308,
#      'val_f1': 0.8906560636182903,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.04544091290318882,
#      'val_loss': 0.049820713973962344,
#      'val_accuracy': 0.6461538461538462,
#      'val_f1': 0.7344110854503464,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.04688193657910907,
#      'val_loss': 0.043926880061626435,
#      'val_accuracy': 0.7353846153846154,
#      'val_f1': 0.8162393162393161,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.04428061704327176,
#      'val_loss': 0.04169353722379758,
#      'val_accuracy': 0.7507692307692307,
#      'val_f1': 0.8272921108742004,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.04311173296162298,
#      'val_loss': 0.06043806763795706,
#      'val_accuracy': 0.6861538461538461,
#      'val_f1': 0.7829787234042553,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.042174949025461726,
#      'val_loss': 0.062102165749439824,
#      'val_accuracy': 0.6923076923076923,
#      'val_f1': 0.7881355932203389,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.042949411090645755,
#      'val_loss': 0.042812202074206794,
#      'val_accuracy': 0.8123076923076923,
#      'val_f1': 0.8767676767676768,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.041523200408978896,
#      'val_loss': 0.05521202691472494,
#      'val_accuracy': 0.6553846153846153,
#      'val_f1': 0.7565217391304347,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.03866322399019361,
#      'val_loss': 0.046680774493859364,
#      'val_accuracy': 0.6492307692307693,
#      'val_f1': 0.7361111111111113,
#      'lr': 0.0005},
#     {'epoch': 10.0,
#      'train_loss': 0.038256771346697444,
#      'val_loss': 0.06325642322118466,
#      'val_accuracy': 0.6707692307692308,
#      'val_f1': 0.772823779193206,
#      'lr': 0.0005},
#     {'epoch': 11.0,
#      'train_loss': 0.03670334921224967,
#      'val_loss': 0.05948942399941958,
#      'val_accuracy': 0.64,
#      'val_f1': 0.7382550335570469,
#      'lr': 0.0005},
#     {'epoch': 12.0,
#      'train_loss': 0.034712214843480735,
#      'val_loss': 0.06699547205406886,
#      'val_accuracy': 0.6953846153846154,
#      'val_f1': 0.7898089171974523,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_48_Sub51_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_48_Sub51.pt'}},
#   {'fold_index': 49,
#    'test_subject': 'Sub52',
#    'split': {'train': ['Sub1',
#      'Sub2',
#      'Sub3',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub7',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub51'],
#     'val': ['Sub8', 'Sub38', 'Sub40', 'Sub41', 'Sub53'],
#     'test': ['Sub52']},
#    'sample_shapes': {'x_train': [2860, 1, 240],
#     'x_val': [325, 1, 240],
#     'x_test': [65, 1, 240]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2288},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 12,
#    'best_val_loss': 0.044377054526255684,
#    'test_metrics': {'loss': 0.029162065627483223,
#     'accuracy': 0.9846153846153847,
#     'precision': 1.0,
#     'recall': 0.9807692307692307,
#     'f1': 0.9902912621359222,
#     'tn': 13.0,
#     'fp': 0.0,
#     'fn': 1.0,
#     'tp': 51.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.2,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.04790704387363854,
#      'val_loss': 0.05323219918287717,
#      'val_accuracy': 0.7476923076923077,
#      'val_f1': 0.8298755186721991,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.044951282848011365,
#      'val_loss': 0.05061630251315924,
#      'val_accuracy': 0.7630769230769231,
#      'val_f1': 0.8469184890656064,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.04459751964240641,
#      'val_loss': 0.049925893407601576,
#      'val_accuracy': 0.7569230769230769,
#      'val_f1': 0.8343815513626833,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.04484387181334562,
#      'val_loss': 0.048941322886026824,
#      'val_accuracy': 0.7446153846153846,
#      'val_f1': 0.8252631578947369,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.043601170150966914,
#      'val_loss': 0.048086449137100806,
#      'val_accuracy': 0.7630769230769231,
#      'val_f1': 0.8405797101449275,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.04411001788465293,
#      'val_loss': 0.0487781495314378,
#      'val_accuracy': 0.7046153846153846,
#      'val_f1': 0.7876106194690266,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.04320075945420699,
#      'val_loss': 0.04703639015555382,
#      'val_accuracy': 0.7569230769230769,
#      'val_f1': 0.8384458077709611,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.04212286234735609,
#      'val_loss': 0.04814894827512595,
#      'val_accuracy': 0.7507692307692307,
#      'val_f1': 0.834355828220859,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.04007817593279418,
#      'val_loss': 0.05292779803276062,
#      'val_accuracy': 0.7846153846153846,
#      'val_f1': 0.862204724409449,
#      'lr': 0.001},
#     {'epoch': 10.0,
#      'train_loss': 0.039025206431433875,
#      'val_loss': 0.050025427295611456,
#      'val_accuracy': 0.7815384615384615,
#      'val_f1': 0.8652751423149905,
#      'lr': 0.001},
#     {'epoch': 11.0,
#      'train_loss': 0.03938127971820898,
#      'val_loss': 0.04596667881195362,
#      'val_accuracy': 0.796923076923077,
#      'val_f1': 0.8715953307392996,
#      'lr': 0.001},
#     {'epoch': 12.0,
#      'train_loss': 0.040385689096642544,
#      'val_loss': 0.044377054526255684,
#      'val_accuracy': 0.7938461538461539,
#      'val_f1': 0.8714011516314779,
#      'lr': 0.001},
#     {'epoch': 13.0,
#      'train_loss': 0.03734606881398004,
#      'val_loss': 0.046643236783834606,
#      'val_accuracy': 0.8338461538461538,
#      'val_f1': 0.900735294117647,
#      'lr': 0.001},
#     {'epoch': 14.0,
#      'train_loss': 0.036816693363072986,
#      'val_loss': 0.053982659578323364,
#      'val_accuracy': 0.7538461538461538,
#      'val_f1': 0.8319327731092437,
#      'lr': 0.001},
#     {'epoch': 15.0,
#      'train_loss': 0.037693339258015574,
#      'val_loss': 0.050273948174256546,
#      'val_accuracy': 0.803076923076923,
#      'val_f1': 0.879245283018868,
#      'lr': 0.001},
#     {'epoch': 16.0,
#      'train_loss': 0.0365062159049761,
#      'val_loss': 0.04762320527663598,
#      'val_accuracy': 0.6215384615384615,
#      'val_f1': 0.7132867132867132,
#      'lr': 0.001},
#     {'epoch': 17.0,
#      'train_loss': 0.036097853161863515,
#      'val_loss': 0.05012298428095304,
#      'val_accuracy': 0.8307692307692308,
#      'val_f1': 0.8998178506375227,
#      'lr': 0.0005},
#     {'epoch': 18.0,
#      'train_loss': 0.03544657260075316,
#      'val_loss': 0.05412986792050875,
#      'val_accuracy': 0.796923076923077,
#      'val_f1': 0.8725868725868725,
#      'lr': 0.0005},
#     {'epoch': 19.0,
#      'train_loss': 0.03383627563610777,
#      'val_loss': 0.04846756219863892,
#      'val_accuracy': 0.8153846153846154,
#      'val_f1': 0.8880597014925373,
#      'lr': 0.0005},
#     {'epoch': 20.0,
#      'train_loss': 0.03492820171730502,
#      'val_loss': 0.05199330985546112,
#      'val_accuracy': 0.8246153846153846,
#      'val_f1': 0.8946395563770795,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_49_Sub52_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_49_Sub52.pt'}},
#   {'fold_index': 50,
#    'test_subject': 'Sub53',
#    'split': {'train': ['Sub1',
#      'Sub2',
#      'Sub3',
#      'Sub4',
#      'Sub6',
#      'Sub7',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub40',
#      'Sub42',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub51',
#      'Sub52'],
#     'val': ['Sub5', 'Sub26', 'Sub38', 'Sub41', 'Sub43'],
#     'test': ['Sub53']},
#    'sample_shapes': {'x_train': [2860, 1, 240],
#     'x_val': [325, 1, 240],
#     'x_test': [65, 1, 240]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2288},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 16,
#    'best_val_loss': 0.03427369732982837,
#    'test_metrics': {'loss': 0.07803303186710064,
#     'accuracy': 0.7230769230769231,
#     'precision': 0.7833333333333333,
#     'recall': 0.9038461538461539,
#     'f1': 0.8392857142857143,
#     'tn': 0.0,
#     'fp': 13.0,
#     'fn': 5.0,
#     'tp': 47.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.2,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.04739552490361087,
#      'val_loss': 0.04455238459775081,
#      'val_accuracy': 0.8123076923076923,
#      'val_f1': 0.8792079207920792,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.043116477355882005,
#      'val_loss': 0.04682375660309425,
#      'val_accuracy': 0.7230769230769231,
#      'val_f1': 0.8060344827586207,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.045097742636095395,
#      'val_loss': 0.04926257882553797,
#      'val_accuracy': 0.7630769230769231,
#      'val_f1': 0.8385744234800839,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.045179882426778756,
#      'val_loss': 0.04316332168304003,
#      'val_accuracy': 0.8,
#      'val_f1': 0.8681541582150101,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.042607062351661965,
#      'val_loss': 0.04284249988886026,
#      'val_accuracy': 0.7784615384615384,
#      'val_f1': 0.8506224066390041,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.04121607406051842,
#      'val_loss': 0.04318214746048817,
#      'val_accuracy': 0.8,
#      'val_f1': 0.87279843444227,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.04153657921335914,
#      'val_loss': 0.040881157838381255,
#      'val_accuracy': 0.8153846153846154,
#      'val_f1': 0.880952380952381,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.03946717377309199,
#      'val_loss': 0.04242412275419785,
#      'val_accuracy': 0.76,
#      'val_f1': 0.8333333333333334,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.03853790485983962,
#      'val_loss': 0.04086061652463216,
#      'val_accuracy': 0.7876923076923077,
#      'val_f1': 0.8588957055214725,
#      'lr': 0.001},
#     {'epoch': 10.0,
#      'train_loss': 0.038848066006923886,
#      'val_loss': 0.04112795011355327,
#      'val_accuracy': 0.8,
#      'val_f1': 0.8654244306418221,
#      'lr': 0.001},
#     {'epoch': 11.0,
#      'train_loss': 0.03838103780900682,
#      'val_loss': 0.03730560048841513,
#      'val_accuracy': 0.8430769230769231,
#      'val_f1': 0.903954802259887,
#      'lr': 0.001},
#     {'epoch': 12.0,
#      'train_loss': 0.03908441110507592,
#      'val_loss': 0.040217723611455695,
#      'val_accuracy': 0.7846153846153846,
#      'val_f1': 0.8571428571428572,
#      'lr': 0.001},
#     {'epoch': 13.0,
#      'train_loss': 0.03681079834908039,
#      'val_loss': 0.03895744177656105,
#      'val_accuracy': 0.8,
#      'val_f1': 0.8707753479125248,
#      'lr': 0.001},
#     {'epoch': 14.0,
#      'train_loss': 0.03760512661371198,
#      'val_loss': 0.038072956084058834,
#      'val_accuracy': 0.8061538461538461,
#      'val_f1': 0.8742514970059879,
#      'lr': 0.001},
#     {'epoch': 15.0,
#      'train_loss': 0.03508511163763233,
#      'val_loss': 0.03526999156062419,
#      'val_accuracy': 0.8584615384615385,
#      'val_f1': 0.9125475285171102,
#      'lr': 0.001},
#     {'epoch': 16.0,
#      'train_loss': 0.03544107573432522,
#      'val_loss': 0.03427369732982837,
#      'val_accuracy': 0.8584615384615385,
#      'val_f1': 0.9118773946360154,
#      'lr': 0.001},
#     {'epoch': 17.0,
#      'train_loss': 0.034355692867632515,
#      'val_loss': 0.03896700005548505,
#      'val_accuracy': 0.7846153846153846,
#      'val_f1': 0.8553719008264463,
#      'lr': 0.001},
#     {'epoch': 18.0,
#      'train_loss': 0.03514129287608853,
#      'val_loss': 0.04113592125188846,
#      'val_accuracy': 0.7538461538461538,
#      'val_f1': 0.829059829059829,
#      'lr': 0.001},
#     {'epoch': 19.0,
#      'train_loss': 0.034902617569778346,
#      'val_loss': 0.04305592859719092,
#      'val_accuracy': 0.8061538461538461,
#      'val_f1': 0.8767123287671232,
#      'lr': 0.001},
#     {'epoch': 20.0,
#      'train_loss': 0.03428125877480407,
#      'val_loss': 0.047372490622174857,
#      'val_accuracy': 0.8,
#      'val_f1': 0.8732943469785575,
#      'lr': 0.001},
#     {'epoch': 21.0,
#      'train_loss': 0.033078986062453346,
#      'val_loss': 0.040616365029261664,
#      'val_accuracy': 0.7784615384615384,
#      'val_f1': 0.8506224066390041,
#      'lr': 0.0005},
#     {'epoch': 22.0,
#      'train_loss': 0.03278838383046897,
#      'val_loss': 0.03990236727950665,
#      'val_accuracy': 0.7876923076923077,
#      'val_f1': 0.8594704684317719,
#      'lr': 0.0005},
#     {'epoch': 23.0,
#      'train_loss': 0.03179023005068302,
#      'val_loss': 0.04093546153726772,
#      'val_accuracy': 0.8584615384615385,
#      'val_f1': 0.9125475285171102,
#      'lr': 0.0005},
#     {'epoch': 24.0,
#      'train_loss': 0.031863507573733796,
#      'val_loss': 0.03755419118831364,
#      'val_accuracy': 0.8553846153846154,
#      'val_f1': 0.9104761904761905,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_50_Sub53_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/Temp/Save_model/temp_1dcnn_transformer_loso_torch_fold_50_Sub53.pt'}}],
#  'device': 'cuda'}

# %%
# LOSO 결과 시각화: Accuracy/F1, Confusion Matrix, Train/Val Loss curves
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

if "result_loso" not in globals():
    raise RuntimeError("먼저 1번 셀을 실행해 result_loso를 생성해 주세요.")

fold_results = result_loso.get("fold_results", [])
if len(fold_results) == 0:
    raise RuntimeError("fold_results가 비어 있습니다. 1번 셀 학습 결과를 확인해 주세요.")

# 1) Fold metric 요약
metrics_df = pd.DataFrame([
    {
        "fold_index": fr["fold_index"],
        "test_subject": fr["test_subject"],
        "accuracy": fr["test_metrics"]["accuracy"],
        "f1": fr["test_metrics"]["f1"],
        "tn": fr["test_metrics"]["tn"],
        "fp": fr["test_metrics"]["fp"],
        "fn": fr["test_metrics"]["fn"],
        "tp": fr["test_metrics"]["tp"],
    }
    for fr in fold_results
])

acc_mean = float(metrics_df["accuracy"].mean())
f1_mean = float(metrics_df["f1"].mean())
acc_std = float(metrics_df["accuracy"].std(ddof=0))
f1_std = float(metrics_df["f1"].std(ddof=0))

print("=== LOSO Aggregate Metrics ===")
print(f"Accuracy mean±std: {acc_mean:.4f} ± {acc_std:.4f}")
print(f"F1-score mean±std: {f1_mean:.4f} ± {f1_std:.4f}")

plt.figure(figsize=(6, 4))
bars = plt.bar(["Accuracy", "F1-score"], [acc_mean, f1_mean], color=["#4e79a7", "#f28e2b"], edgecolor="black")
plt.ylim(0, 1.0)
plt.title("LOSO Mean Metrics")
plt.ylabel("Score")
plt.grid(axis="y", linestyle="--", alpha=0.4)
for b, v in zip(bars, [acc_mean, f1_mean]):
    plt.text(b.get_x() + b.get_width() / 2, v + 0.02, f"{v:.4f}", ha="center", va="bottom")
plt.tight_layout()
plt.show()

# 2) Confusion Matrix (fold 합산 후 row-normalized)
tn = float(metrics_df["tn"].sum())
fp = float(metrics_df["fp"].sum())
fn = float(metrics_df["fn"].sum())
tp = float(metrics_df["tp"].sum())
conf_counts = np.array([[tn, fp], [fn, tp]], dtype=np.float64)
row_sums = conf_counts.sum(axis=1, keepdims=True)
conf_ratio = np.divide(conf_counts, np.maximum(row_sums, 1.0))

print("Confusion Matrix Count [[TN, FP], [FN, TP]]:")
print(conf_counts.astype(int))
print("Confusion Matrix Row Ratio [[TN, FP], [FN, TP]]:")
print(np.round(conf_ratio, 4))

fig, ax = plt.subplots(figsize=(5, 4))
im = ax.imshow(conf_ratio, cmap="Blues", vmin=0.0, vmax=1.0)
ax.set_title("LOSO Confusion Matrix (Row-normalized)")
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")
ax.set_xticks([0, 1])
ax.set_yticks([0, 1])
ax.set_xticklabels(["Non-stress", "Stress"])
ax.set_yticklabels(["Non-stress", "Stress"])
for i in range(conf_ratio.shape[0]):
    for j in range(conf_ratio.shape[1]):
        ax.text(j, i, f"{conf_ratio[i, j]:.3f}", ha="center", va="center", color="black", fontsize=12, fontweight="bold")
fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
plt.tight_layout()
plt.show()

# 3) Train/Val Loss 곡선 (fold 평균)
history_frames = []
for fr in fold_results:
    history_rows = fr.get("history", [])
    if len(history_rows) == 0:
        continue

    h = pd.DataFrame(history_rows)
    if "epoch" in h.columns and "train_loss" in h.columns and "val_loss" in h.columns:
        h["fold_index"] = fr["fold_index"]
        history_frames.append(h[["fold_index", "epoch", "train_loss", "val_loss"]])

if len(history_frames) == 0:
    print("history가 없어 Train/Val loss 곡선을 그릴 수 없습니다. 1번 셀을 다시 실행해 주세요.")
else:
    hist_all = pd.concat(history_frames, ignore_index=True)
    hist_mean = hist_all.groupby("epoch", as_index=False)[["train_loss", "val_loss"]].mean()

    plt.figure(figsize=(7, 4))
    plt.plot(hist_mean["epoch"], hist_mean["train_loss"], label="Train Loss", linewidth=2)
    plt.plot(hist_mean["epoch"], hist_mean["val_loss"], label="Val Loss", linewidth=2)
    plt.title("LOSO Mean Train/Val Loss Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.grid(alpha=0.3, linestyle="--")
    plt.legend()
    plt.tight_layout()
    plt.show()

{
    "accuracy_mean": acc_mean,
    "f1_mean": f1_mean,
    "confusion_matrix_count": conf_counts.astype(int).tolist(),
    "confusion_matrix_row_ratio": conf_ratio.tolist(),
}
# Out:
# === LOSO Aggregate Metrics ===
# Accuracy mean±std: 0.8166 ± 0.1831
# F1-score mean±std: 0.8756 ± 0.1356
# Confusion Matrix Count [[TN, FP], [FN, TP]]:
# [[ 418  232]
#  [ 364 2236]]
# Confusion Matrix Row Ratio [[TN, FP], [FN, TP]]:
# [[0.6431 0.3569]
#  [0.14   0.86  ]]
# {'accuracy_mean': 0.8166153846153845,
#  'f1_mean': 0.8755597652267363,
#  'confusion_matrix_count': [[418, 232], [364, 2236]],
#  'confusion_matrix_row_ratio': [[0.6430769230769231, 0.3569230769230769],
#   [0.14, 0.86]]}

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# 1. result 변수에 의존하지 않고, 노트북에 있는 find_dataset_root() 함수를 직접 사용합니다.
dataset_root = find_dataset_root()
all_subjects = discover_complete_subjects(dataset_root)

# 2. 50명 전체 데이터에 대해 '피험자별 Z-score 정규화' 적용하여 로드
print(f"총 {len(all_subjects)}명의 데이터를 로드하여 PCA를 수행합니다... (시간이 조금 걸릴 수 있습니다)")
x_all, y_all = build_split_arrays(
    dataset_root, 
    all_subjects, 
    window_size=240,      # hp.window_size 대신 고정값 사용
    stride=40,           # hp.stride 대신 고정값 사용
    normalization_mode="subject_zscore" # Z-score 정규화 명시
)

# 3. 데이터 차원 축소: (전체 샘플 수, 1, 60) -> (전체 샘플 수, 60)으로 평탄화(Flatten)
x_all_2d = x_all.reshape(x_all.shape[0], -1)

# 4. PCA 모델 생성 및 학습 (60차원 -> 2차원으로 압축)
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_all_2d)

# 5. 시각화 (Scatter Plot)
plt.figure(figsize=(10, 7))

# 전체 샘플 수가 매우 많으므로 투명도(alpha)를 0.2 정도로 낮추어 밀집도를 확인합니다.
plt.scatter(x_pca[y_all == 0, 0], x_pca[y_all == 0, 1], 
            color='#4e79a7', alpha=0.5, label='Non-stress (0)', edgecolors='none', s=20)

plt.scatter(x_pca[y_all == 1, 0], x_pca[y_all == 1, 1], 
            color='#f28e2b', alpha=0.5, label='Stress (1)', edgecolors='none', s=20)

# 그래프 꾸미기
plt.title(f'2D PCA of HR Time-Series (All {len(all_subjects)} Subjects, Subject Z-Score)', fontsize=15, fontweight='bold')
plt.xlabel(f'Principal Component 1 ({pca.explained_variance_ratio_[0]*100:.1f}%)', fontsize=12)
plt.ylabel(f'Principal Component 2 ({pca.explained_variance_ratio_[1]*100:.1f}%)', fontsize=12)

# 범례 마커는 투명하지 않고 진하게 보이도록 조정
leg = plt.legend(fontsize=12, markerscale=2)
for lh in leg.legend_handles: 
    lh.set_alpha(1)

plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# 총 50명의 데이터를 로드하여 PCA를 수행합니다... (시간이 조금 걸릴 수 있습니다)
