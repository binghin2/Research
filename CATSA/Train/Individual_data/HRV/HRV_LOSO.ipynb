# %%
from copy import deepcopy
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Dict, List, Optional, Tuple

import json
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset


TASKS = ["Baseline", "Logic", "Nback", "Stroop", "Sudoku"]
STRESS_TASKS = {"Logic", "Nback", "Stroop", "Sudoku"}


@dataclass
class HyperParameters:
    random_seed: int = 42
    val_ratio: float = 0.1
    min_val_subjects: int = 4
    max_val_subjects: int = 5

    window_size: int = 60
    stride: int = 10
    hrv_window: int = 30
    batch_size: int = 64
    epochs: int = 50
    learning_rate: float = 1e-3
    dropout_rate: float = 0.3
    weight_decay: float = 1e-4
    patience: int = 8

    transformer_heads: int = 8
    transformer_layers: int = 2
    transformer_ff_dim: int = 256
    transformer_dropout: float = 0.1

    # subject-wise zscore | baseline zscore | none
    normalization_mode: str = "subject_zscore"

    # focal | weighted_bce
    loss_name: str = "focal"
    focal_gamma: float = 2.0
    focal_alpha: Optional[float] = None
    save_model: bool = True

    # 개발/디버깅용: None이면 전체 LOSO fold 수행
    max_folds: Optional[int] = None


def find_dataset_root() -> Path:
    cwd = Path.cwd().resolve()
    for base in [cwd, *cwd.parents]:
        candidate = base / "Dataset" / "CATSA"
        if candidate.exists():
            return candidate

    fallback = Path("/home/binghin2/Myproject/Dataset/CATSA")
    if fallback.exists():
        return fallback

    raise FileNotFoundError("Could not find Dataset/CATSA. Please set dataset_root manually.")


def discover_complete_subjects(dataset_root: Path) -> List[str]:
    subjects: List[str] = []
    for subject_dir in sorted(dataset_root.glob("Sub*"), key=lambda p: int(p.name[3:])):
        if not subject_dir.is_dir():
            continue
        # HRV raw 파일이 없으므로 HR.csv 존재 여부로 완전 피험자 판단
        has_all = all((subject_dir / task / "HR.csv").exists() for task in TASKS)
        if has_all:
            subjects.append(subject_dir.name)
    return subjects


def read_hr_csv(file_path: Path) -> np.ndarray:
    df = pd.read_csv(file_path)
    numeric_cols = [c for c in df.columns if pd.api.types.is_numeric_dtype(df[c])]
    if numeric_cols:
        values = df[numeric_cols[0]].to_numpy(dtype=np.float32)
    else:
        values = pd.to_numeric(df.iloc[:, 0], errors="coerce").to_numpy(dtype=np.float32)
    values = values[~np.isnan(values)]
    if len(values) == 0:
        raise ValueError(f"No valid HR values in {file_path}")
    return values


def detect_hrv_from_hr(hr: np.ndarray, hrv_window: int = 30) -> np.ndarray:
    """HR 신호에서 로컬 RMSSD/SDNN 기반 HRV 유사 시계열을 생성한다."""
    hr = np.asarray(hr, dtype=np.float32)
    hr = np.clip(hr, 30.0, 220.0)

    rr_ms = 60000.0 / hr
    drr = np.diff(rr_ms, prepend=rr_ms[0])

    w = max(3, int(hrv_window))
    kernel = np.ones(w, dtype=np.float32) / float(w)

    rmssd_local = np.sqrt(np.convolve(drr * drr, kernel, mode="same") + 1e-8)

    rr_mean = np.convolve(rr_ms, kernel, mode="same")
    rr_sq_mean = np.convolve(rr_ms * rr_ms, kernel, mode="same")
    sdnn_local = np.sqrt(np.maximum(rr_sq_mean - rr_mean * rr_mean, 0.0) + 1e-8)

    hrv_signal = 0.5 * rmssd_local + 0.5 * sdnn_local
    return hrv_signal.astype(np.float32)


def sliding_windows(signal: np.ndarray, window_size: int, stride: int) -> np.ndarray:
    if len(signal) < window_size:
        return np.empty((0, window_size), dtype=np.float32)
    windows = [signal[i:i + window_size] for i in range(0, len(signal) - window_size + 1, stride)]
    return np.asarray(windows, dtype=np.float32)


def compute_subject_stats(
    sub_path: Path,
    hrv_window: int,
    use_baseline_as_non_stress: bool,
    use_stress_tasks_only: bool,
) -> Tuple[float, float]:
    if use_stress_tasks_only:
        candidate_tasks = [t for t in TASKS if t in STRESS_TASKS]
    else:
        candidate_tasks = TASKS.copy()

    values_list: List[np.ndarray] = []
    for task in candidate_tasks:
        if task == "Baseline" and not use_baseline_as_non_stress:
            continue
        hr_raw = read_hr_csv(sub_path / task / "HR.csv")
        hrv_raw = detect_hrv_from_hr(hr_raw, hrv_window=hrv_window)
        values_list.append(hrv_raw)

    all_values = np.concatenate(values_list, axis=0)
    sub_mean = float(np.mean(all_values))
    sub_std = float(np.std(all_values)) + 1e-8
    return sub_mean, sub_std


def build_split_arrays(
    dataset_root: Path,
    subject_list: List[str],
    window_size: int,
    stride: int,
    hrv_window: int,
    normalization_mode: str = "subject_zscore",
    use_baseline_as_non_stress: bool = True,
    use_stress_tasks_only: bool = False,
) -> Tuple[np.ndarray, np.ndarray]:
    x_chunks: List[np.ndarray] = []
    y_chunks: List[np.ndarray] = []

    for sub in subject_list:
        sub_path = dataset_root / sub

        if use_stress_tasks_only:
            candidate_tasks = [t for t in TASKS if t in STRESS_TASKS]
        else:
            candidate_tasks = TASKS.copy()

        baseline_hr = read_hr_csv(sub_path / "Baseline" / "HR.csv")
        baseline_hrv = detect_hrv_from_hr(baseline_hr, hrv_window=hrv_window)
        baseline_mean = float(np.mean(baseline_hrv))
        baseline_std = float(np.std(baseline_hrv)) + 1e-8

        sub_mean, sub_std = compute_subject_stats(
            sub_path,
            hrv_window=hrv_window,
            use_baseline_as_non_stress=use_baseline_as_non_stress,
            use_stress_tasks_only=use_stress_tasks_only,
        )

        for task in candidate_tasks:
            if task == "Baseline" and not use_baseline_as_non_stress:
                continue

            hr_raw = read_hr_csv(sub_path / task / "HR.csv")
            raw = detect_hrv_from_hr(hr_raw, hrv_window=hrv_window)
            if normalization_mode == "subject_zscore":
                norm = (raw - sub_mean) / sub_std
            elif normalization_mode == "baseline_zscore":
                norm = (raw - baseline_mean) / baseline_std
            elif normalization_mode == "none":
                norm = raw
            else:
                raise ValueError(f"Unknown normalization_mode: {normalization_mode}")

            windows = sliding_windows(norm, window_size=window_size, stride=stride)
            if len(windows) == 0:
                continue

            label = 1 if task in STRESS_TASKS else 0
            labels = np.full((len(windows),), label, dtype=np.int64)
            x_chunks.append(windows)
            y_chunks.append(labels)

    if not x_chunks:
        raise ValueError("No samples generated. Check data files or window settings.")

    x = np.concatenate(x_chunks, axis=0)[:, np.newaxis, :]
    y = np.concatenate(y_chunks, axis=0)
    return x.astype(np.float32), y.astype(np.int64)


def build_loso_folds(subjects: List[str], hp: HyperParameters) -> List[Dict[str, List[str]]]:
    folds: List[Dict[str, List[str]]] = []
    for fold_idx, test_subject in enumerate(subjects):
        remaining = [s for s in subjects if s != test_subject]

        val_count = int(round(len(remaining) * hp.val_ratio))
        val_count = max(hp.min_val_subjects, val_count)
        val_count = min(hp.max_val_subjects, val_count)
        val_count = min(val_count, len(remaining) - 1)

        rng = np.random.default_rng(hp.random_seed + fold_idx)
        shuffled = remaining.copy()
        rng.shuffle(shuffled)

        val_subjects = sorted(shuffled[:val_count], key=lambda x: int(x[3:]))
        train_subjects = sorted(shuffled[val_count:], key=lambda x: int(x[3:]))

        folds.append({
            "train": train_subjects,
            "val": val_subjects,
            "test": [test_subject],
        })

    return folds


class Hrv1DCNNTransformer(nn.Module):
    def __init__(self, hp: HyperParameters):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv1d(1, 32, kernel_size=5, padding=2),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(2),
            nn.Conv1d(32, 64, kernel_size=5, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(2),
            nn.Conv1d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
        )

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=128,
            nhead=hp.transformer_heads,
            dim_feedforward=hp.transformer_ff_dim,
            dropout=hp.transformer_dropout,
            batch_first=True,
            activation="gelu",
        )
        self.transformer = nn.TransformerEncoder(
            encoder_layer,
            num_layers=hp.transformer_layers,
        )

        self.max_len = max(16, hp.window_size)
        self.pos_embedding = nn.Parameter(torch.zeros(1, self.max_len, 128))

        self.classifier = nn.Sequential(
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(hp.dropout_rate),
            nn.Linear(64, 1),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.cnn(x)
        x = x.transpose(1, 2)  # [B, L, C]

        seq_len = x.size(1)
        if seq_len > self.pos_embedding.size(1):
            pos = nn.functional.interpolate(
                self.pos_embedding.transpose(1, 2),
                size=seq_len,
                mode="linear",
                align_corners=False,
            ).transpose(1, 2)
        else:
            pos = self.pos_embedding[:, :seq_len, :]

        x = x + pos
        x = self.transformer(x)
        x = x.mean(dim=1)
        return self.classifier(x).squeeze(1)


class BinaryFocalLossWithLogits(nn.Module):
    def __init__(self, gamma: float = 2.0, alpha: Optional[float] = None, pos_weight: Optional[torch.Tensor] = None):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha
        if pos_weight is not None:
            self.register_buffer("pos_weight", pos_weight)
        else:
            self.pos_weight = None

    def forward(self, logits: torch.Tensor, targets: torch.Tensor) -> torch.Tensor:
        targets = targets.float()
        bce = F.binary_cross_entropy_with_logits(
            logits,
            targets,
            reduction="none",
            pos_weight=self.pos_weight,
        )
        probs = torch.sigmoid(logits)
        pt = probs * targets + (1.0 - probs) * (1.0 - targets)
        focal_factor = (1.0 - pt).pow(self.gamma)

        if self.alpha is not None:
            alpha_t = self.alpha * targets + (1.0 - self.alpha) * (1.0 - targets)
            loss = alpha_t * focal_factor * bce
        else:
            loss = focal_factor * bce

        return loss.mean()


def compute_pos_weight(y: np.ndarray) -> torch.Tensor:
    pos = float(np.sum(y == 1))
    neg = float(np.sum(y == 0))
    if pos == 0:
        return torch.tensor([1.0], dtype=torch.float32)
    return torch.tensor([neg / pos], dtype=torch.float32)


def make_criterion(y_train: np.ndarray, hp: HyperParameters, device: torch.device) -> Tuple[nn.Module, Dict[str, object]]:
    pos_weight = compute_pos_weight(y_train).to(device)

    if hp.loss_name == "weighted_bce":
        return nn.BCEWithLogitsLoss(pos_weight=pos_weight), {
            "loss_name": "weighted_bce",
            "pos_weight": float(pos_weight.item()),
            "focal_gamma": 0.0,
            "focal_alpha": 0.0,
        }

    if hp.loss_name == "focal":
        pos = float(np.sum(y_train == 1))
        neg = float(np.sum(y_train == 0))
        alpha = hp.focal_alpha
        if alpha is None:
            alpha = neg / max(pos + neg, 1.0)

        criterion = BinaryFocalLossWithLogits(
            gamma=hp.focal_gamma,
            alpha=float(alpha),
            pos_weight=None,
        )
        return criterion, {
            "loss_name": "focal",
            "pos_weight": 1.0,
            "focal_gamma": float(hp.focal_gamma),
            "focal_alpha": float(alpha),
            "weighting_note": "Focal uses alpha only to avoid duplicate class weighting",
        }

    raise ValueError(f"Unknown loss_name: {hp.loss_name}")


def make_loader(x: np.ndarray, y: np.ndarray, batch_size: int, shuffle: bool) -> DataLoader:
    ds = TensorDataset(torch.from_numpy(x), torch.from_numpy(y).float())
    return DataLoader(ds, batch_size=batch_size, shuffle=shuffle)


@torch.no_grad()
def evaluate(model: nn.Module, loader: DataLoader, criterion: nn.Module, device: torch.device) -> Dict[str, float]:
    model.eval()
    total_loss = 0.0
    total = 0
    tp = tn = fp = fn = 0

    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)
        logits = model(xb)
        loss = criterion(logits, yb)

        total_loss += float(loss.item()) * xb.size(0)
        total += xb.size(0)

        preds = (torch.sigmoid(logits) >= 0.5).long()
        y_int = yb.long()

        tp += int(((preds == 1) & (y_int == 1)).sum().item())
        tn += int(((preds == 0) & (y_int == 0)).sum().item())
        fp += int(((preds == 1) & (y_int == 0)).sum().item())
        fn += int(((preds == 0) & (y_int == 1)).sum().item())

    acc = (tp + tn) / max(total, 1)
    precision = tp / max(tp + fp, 1)
    recall = tp / max(tp + fn, 1)
    f1 = 2 * precision * recall / max(precision + recall, 1e-8)

    return {
        "loss": total_loss / max(total, 1),
        "accuracy": acc,
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "tn": float(tn),
        "fp": float(fp),
        "fn": float(fn),
        "tp": float(tp),
    }


def train_one_epoch(
    model: nn.Module,
    loader: DataLoader,
    optimizer: torch.optim.Optimizer,
    criterion: nn.Module,
    device: torch.device,
    clip_grad: float = 1.0,
) -> float:
    model.train()
    total_loss = 0.0
    total = 0

    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)

        optimizer.zero_grad(set_to_none=True)
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_grad)
        optimizer.step()

        total_loss += float(loss.item()) * xb.size(0)
        total += xb.size(0)

    return total_loss / max(total, 1)


def run_loso_training(
    model_name: str = "hrv_1dcnn_transformer_loso_torch",
    hp: HyperParameters = HyperParameters(),
) -> Dict[str, object]:
    np.random.seed(hp.random_seed)
    torch.manual_seed(hp.random_seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(hp.random_seed)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    dataset_root = find_dataset_root()

    save_dir = Path("/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model")
    save_dir.mkdir(parents=True, exist_ok=True)

    subjects = discover_complete_subjects(dataset_root)
    folds = build_loso_folds(subjects, hp)
    if hp.max_folds is not None:
        folds = folds[: hp.max_folds]

    fold_results: List[Dict[str, object]] = []

    for fold_idx, split in enumerate(folds, start=1):
        test_subject = split["test"][0]
        print(f"\n=== Fold {fold_idx}/{len(folds)} | Test: {test_subject} ===")
        print(f"Train subjects: {len(split['train'])}, Val subjects: {len(split['val'])}, Test subjects: 1")

        x_train, y_train = build_split_arrays(
            dataset_root,
            split["train"],
            hp.window_size,
            hp.stride,
            hp.hrv_window,
            normalization_mode=hp.normalization_mode,
        )
        x_val, y_val = build_split_arrays(
            dataset_root,
            split["val"],
            hp.window_size,
            hp.stride,
            hp.hrv_window,
            normalization_mode=hp.normalization_mode,
        )
        x_test, y_test = build_split_arrays(
            dataset_root,
            split["test"],
            hp.window_size,
            hp.stride,
            hp.hrv_window,
            normalization_mode=hp.normalization_mode,
        )

        train_loader = make_loader(x_train, y_train, hp.batch_size, shuffle=True)
        val_loader = make_loader(x_val, y_val, hp.batch_size, shuffle=False)
        test_loader = make_loader(x_test, y_test, hp.batch_size, shuffle=False)

        model = Hrv1DCNNTransformer(hp=hp).to(device)
        criterion, loss_cfg = make_criterion(y_train, hp, device)
        optimizer = torch.optim.Adam(
            model.parameters(),
            lr=hp.learning_rate,
            weight_decay=hp.weight_decay,
        )
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode="min", factor=0.5, patience=4
        )

        best_val_loss = float("inf")
        best_epoch = -1
        wait = 0
        history_rows: List[Dict[str, float]] = []
        best_state_dict = None
        fold_tag = f"fold_{fold_idx:02d}_{test_subject}"
        best_model_path = save_dir / f"{model_name}_{fold_tag}_best.pt"
        final_model_path = save_dir / f"{model_name}_{fold_tag}.pt"

        for epoch in range(1, hp.epochs + 1):
            train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
            val_metrics = evaluate(model, val_loader, criterion, device)
            scheduler.step(val_metrics["loss"])
            history_rows.append({"epoch": float(epoch), "train_loss": float(train_loss), "val_loss": float(val_metrics["loss"]), "val_accuracy": float(val_metrics["accuracy"]), "val_f1": float(val_metrics["f1"]), "lr": float(optimizer.param_groups[0]["lr"])})

            if val_metrics["loss"] < best_val_loss:
                best_val_loss = val_metrics["loss"]
                best_epoch = epoch
                wait = 0
                best_state_dict = deepcopy(model.state_dict())
                if hp.save_model:
                    torch.save(
                        {
                            "model_state_dict": best_state_dict,
                            "hyperparameters": asdict(hp),
                            "model_name": model_name,
                            "fold_index": fold_idx,
                            "test_subject": test_subject,
                            "best_epoch": best_epoch,
                            "best_val_loss": best_val_loss,
                        },
                        best_model_path,
                    )
            else:
                wait += 1
                if wait >= hp.patience:
                    print(f"Early stopping at epoch {epoch} (best epoch: {best_epoch})")
                    break

        if best_state_dict is not None:
            model.load_state_dict(best_state_dict)

        test_metrics = evaluate(model, test_loader, criterion, device)

        if hp.save_model:
            torch.save(
                {
                    "model_state_dict": model.state_dict(),
                    "hyperparameters": asdict(hp),
                    "model_name": model_name,
                    "fold_index": fold_idx,
                    "test_subject": test_subject,
                    "best_epoch": best_epoch,
                    "best_val_loss": best_val_loss,
                    "test_metrics": {k: float(v) for k, v in test_metrics.items()},
                },
                final_model_path,
            )

        fold_result = {
            "fold_index": fold_idx,
            "test_subject": test_subject,
            "split": split,
            "sample_shapes": {
                "x_train": list(x_train.shape),
                "x_val": list(x_val.shape),
                "x_test": list(x_test.shape),
            },
            "class_distribution": {
                "train": {"non_stress": int(np.sum(y_train == 0)), "stress": int(np.sum(y_train == 1))},
                "val": {"non_stress": int(np.sum(y_val == 0)), "stress": int(np.sum(y_val == 1))},
                "test": {"non_stress": int(np.sum(y_test == 0)), "stress": int(np.sum(y_test == 1))},
            },
            "best_epoch": int(best_epoch),
            "best_val_loss": float(best_val_loss),
            "test_metrics": {k: float(v) for k, v in test_metrics.items()},
            "normalization_mode": hp.normalization_mode,
            "loss_config": loss_cfg,
            "history": history_rows,
            "model_saved": bool(hp.save_model),
            "model_files": {
                "best_model": str(best_model_path) if hp.save_model else None,
                "final_model": str(final_model_path) if hp.save_model else None,
            },
        }
        fold_results.append(fold_result)

        print(
            "Fold test metrics:",
            {
                "accuracy": round(float(test_metrics["accuracy"]), 4),
                "f1": round(float(test_metrics["f1"]), 4),
                "loss": round(float(test_metrics["loss"]), 4),
            },
        )

    summary_df = pd.DataFrame([
        {
            "fold_index": fr["fold_index"],
            "test_subject": fr["test_subject"],
            "accuracy": fr["test_metrics"]["accuracy"],
            "precision": fr["test_metrics"]["precision"],
            "recall": fr["test_metrics"]["recall"],
            "f1": fr["test_metrics"]["f1"],
            "loss": fr["test_metrics"]["loss"],
        }
        for fr in fold_results
    ])

    metric_cols = ["accuracy", "precision", "recall", "f1", "loss"]
    agg_mean = summary_df[metric_cols].mean().to_dict() if len(summary_df) else {}
    agg_std = summary_df[metric_cols].std(ddof=0).to_dict() if len(summary_df) else {}

    metadata = {
        "created_at": datetime.now().isoformat(),
        "model_name": model_name,
        "model_type": "1D CNN + Transformer (PyTorch, LOSO)",
        "dataset_root": str(dataset_root),
        "signal_type": "HRV",
        "source_signal": "HR.csv (derived)",
        "label_definition": {
            "non_stress": ["Baseline"],
            "stress": ["Logic", "Nback", "Stroop", "Sudoku"],
        },
        "split_rule": "LOSO: 1 test subject + ~10% of remaining (4~5) for validation",
        "total_complete_subjects": len(subjects),
        "num_folds_run": len(fold_results),
        "hyperparameters": asdict(hp),
        "aggregate_metrics": {
            "mean": {k: float(v) for k, v in agg_mean.items()},
            "std": {k: float(v) for k, v in agg_std.items()},
        },
        "fold_results": fold_results,
        "device": str(device),
    }

    metadata_path = save_dir / f"{model_name}_hyperparameters.json"
    with metadata_path.open("w", encoding="utf-8") as f:
        json.dump(metadata, f, ensure_ascii=False, indent=2)

    print("\n=== LOSO Training Complete ===")
    print(f"Saved metadata (hyperparameters + metrics): {metadata_path}")
    if hp.save_model:
        print("Saved per-fold best/final checkpoints under LOSO save_dir")
    if agg_mean:
        print("Aggregate mean metrics:", {k: round(float(v), 4) for k, v in agg_mean.items()})
        print("Aggregate std metrics:", {k: round(float(v), 4) for k, v in agg_std.items()})

    return metadata


# ===== 실행 파트 =====
hp = HyperParameters(
    random_seed=42,
    val_ratio=0.1,
    min_val_subjects=4,
    max_val_subjects=5,
    window_size=60,
    stride=10,
    hrv_window=30,
    batch_size=64,
    epochs=50,
    learning_rate=1e-3,
    dropout_rate=0.3,
    weight_decay=1e-4,
    patience=8,
    transformer_heads=8,
    transformer_layers=2,
    transformer_ff_dim=256,
    transformer_dropout=0.1,
    normalization_mode="subject_zscore",
    loss_name="focal",
    focal_gamma=2.0,
    focal_alpha=None,
    save_model=True,
    max_folds=None,  # 빠른 테스트 시 정수로 제한 가능 (예: 3)
)

result_loso = run_loso_training(model_name="hrv_1dcnn_transformer_loso_torch", hp=hp)
result_loso
# Out:
# === Fold 1/50 | Test: Sub1 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Fold test metrics: {'accuracy': 0.5156, 'f1': 0.5867, 'loss': 0.0545}
#
# === Fold 2/50 | Test: Sub2 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Fold test metrics: {'accuracy': 0.8308, 'f1': 0.8889, 'loss': 0.0419}
#
# === Fold 3/50 | Test: Sub3 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.5538, 'f1': 0.6742, 'loss': 0.0548}
#
# === Fold 4/50 | Test: Sub4 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.5385, 'f1': 0.6429, 'loss': 0.0567}
#
# === Fold 5/50 | Test: Sub5 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.2923, 'f1': 0.3784, 'loss': 0.0614}
#
# === Fold 6/50 | Test: Sub6 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.7385, 'f1': 0.8247, 'loss': 0.0536}
#
# === Fold 7/50 | Test: Sub7 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.8462, 'f1': 0.8936, 'loss': 0.0473}
#
# === Fold 8/50 | Test: Sub8 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.5231, 'f1': 0.6265, 'loss': 0.0558}
#
# === Fold 9/50 | Test: Sub9 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 39 (best epoch: 31)
# Fold test metrics: {'accuracy': 0.4615, 'f1': 0.6237, 'loss': 0.0606}
#
# === Fold 10/50 | Test: Sub10 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.8923, 'f1': 0.9333, 'loss': 0.0528}
#
# === Fold 11/50 | Test: Sub11 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 46 (best epoch: 38)
# Fold test metrics: {'accuracy': 0.6923, 'f1': 0.8113, 'loss': 0.0576}
#
# === Fold 12/50 | Test: Sub12 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.4308, 'f1': 0.5542, 'loss': 0.0591}
#
# === Fold 13/50 | Test: Sub13 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.5, 'f1': 0.5429, 'loss': 0.0521}
#
# === Fold 14/50 | Test: Sub14 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.6, 'f1': 0.75, 'loss': 0.0583}
#
# === Fold 15/50 | Test: Sub15 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 22 (best epoch: 14)
# Fold test metrics: {'accuracy': 0.3846, 'f1': 0.4872, 'loss': 0.0615}
#
# === Fold 16/50 | Test: Sub16 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.625, 'f1': 0.7692, 'loss': 0.0597}
#
# === Fold 17/50 | Test: Sub17 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.7692, 'f1': 0.8315, 'loss': 0.0514}
#
# === Fold 18/50 | Test: Sub18 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.7231, 'f1': 0.8364, 'loss': 0.0554}
#
# === Fold 19/50 | Test: Sub20 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Fold test metrics: {'accuracy': 0.7692, 'f1': 0.8352, 'loss': 0.049}
#
# === Fold 20/50 | Test: Sub21 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.7538, 'f1': 0.8367, 'loss': 0.0515}
#
# === Fold 21/50 | Test: Sub22 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 39 (best epoch: 31)
# Fold test metrics: {'accuracy': 0.6154, 'f1': 0.6988, 'loss': 0.0485}
#
# === Fold 22/50 | Test: Sub23 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.6406, 'f1': 0.7473, 'loss': 0.0555}
#
# === Fold 23/50 | Test: Sub24 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.7969, 'f1': 0.8713, 'loss': 0.053}
#
# === Fold 24/50 | Test: Sub26 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.5385, 'f1': 0.6429, 'loss': 0.0539}
#
# === Fold 25/50 | Test: Sub27 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.5692, 'f1': 0.6957, 'loss': 0.0563}
#
# === Fold 26/50 | Test: Sub28 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 20 (best epoch: 12)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.875, 'loss': 0.0482}
#
# === Fold 27/50 | Test: Sub29 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 29 (best epoch: 21)
# Fold test metrics: {'accuracy': 0.5538, 'f1': 0.6813, 'loss': 0.0557}
#
# === Fold 28/50 | Test: Sub30 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Fold test metrics: {'accuracy': 0.2923, 'f1': 0.2069, 'loss': 0.0556}
#
# === Fold 29/50 | Test: Sub31 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 22 (best epoch: 14)
# Fold test metrics: {'accuracy': 0.7692, 'f1': 0.8352, 'loss': 0.048}
#
# === Fold 30/50 | Test: Sub32 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.1692, 'f1': 0.0, 'loss': 0.0584}
#
# === Fold 31/50 | Test: Sub33 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.2923, 'f1': 0.3235, 'loss': 0.0581}
#
# === Fold 32/50 | Test: Sub34 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.6769, 'f1': 0.7586, 'loss': 0.049}
#
# === Fold 33/50 | Test: Sub35 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.9231, 'f1': 0.9495, 'loss': 0.0449}
#
# === Fold 34/50 | Test: Sub36 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.9219, 'f1': 0.9533, 'loss': 0.0509}
#
# === Fold 35/50 | Test: Sub37 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 31 (best epoch: 23)
# Fold test metrics: {'accuracy': 0.6154, 'f1': 0.7312, 'loss': 0.056}
#
# === Fold 36/50 | Test: Sub38 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Fold test metrics: {'accuracy': 0.4154, 'f1': 0.587, 'loss': 0.0673}
#
# === Fold 37/50 | Test: Sub40 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.4308, 'f1': 0.5542, 'loss': 0.057}
#
# === Fold 38/50 | Test: Sub41 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.2769, 'f1': 0.4198, 'loss': 0.0621}
#
# === Fold 39/50 | Test: Sub42 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.6462, 'f1': 0.7229, 'loss': 0.0515}
#
# === Fold 40/50 | Test: Sub43 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 19 (best epoch: 11)
# Fold test metrics: {'accuracy': 0.7077, 'f1': 0.7957, 'loss': 0.0484}
#
# === Fold 41/50 | Test: Sub44 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 36 (best epoch: 28)
# Fold test metrics: {'accuracy': 0.5231, 'f1': 0.6737, 'loss': 0.0641}
#
# === Fold 42/50 | Test: Sub45 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 19 (best epoch: 11)
# Fold test metrics: {'accuracy': 0.4462, 'f1': 0.561, 'loss': 0.056}
#
# === Fold 43/50 | Test: Sub46 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.5846, 'f1': 0.6494, 'loss': 0.0483}
#
# === Fold 44/50 | Test: Sub47 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 17 (best epoch: 9)
# Fold test metrics: {'accuracy': 0.5846, 'f1': 0.6824, 'loss': 0.0533}
#
# === Fold 45/50 | Test: Sub48 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 19 (best epoch: 11)
# Fold test metrics: {'accuracy': 0.9077, 'f1': 0.9444, 'loss': 0.0474}
#
# === Fold 46/50 | Test: Sub49 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.5692, 'f1': 0.6744, 'loss': 0.0559}
#
# === Fold 47/50 | Test: Sub50 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 21 (best epoch: 13)
# Fold test metrics: {'accuracy': 0.2, 'f1': 0.0, 'loss': 0.058}
#
# === Fold 48/50 | Test: Sub51 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Fold test metrics: {'accuracy': 0.5077, 'f1': 0.6522, 'loss': 0.0595}
#
# === Fold 49/50 | Test: Sub52 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.5538, 'f1': 0.6329, 'loss': 0.0548}
#
# === Fold 50/50 | Test: Sub53 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.8762, 'loss': 0.0527}
#
# === LOSO Training Complete ===
# Saved metadata (hyperparameters + metrics): /home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_hyperparameters.json
# Saved per-fold best/final checkpoints under LOSO save_dir
# Aggregate mean metrics: {'accuracy': 0.5957, 'precision': 0.8182, 'recall': 0.5981, 'f1': 0.6745, 'loss': 0.0545}
# Aggregate std metrics: {'accuracy': 0.1881, 'precision': 0.1965, 'recall': 0.2323, 'f1': 0.2121, 'loss': 0.0051}
# {'created_at': '2026-04-22T00:24:43.204556',
#  'model_name': 'hrv_1dcnn_transformer_loso_torch',
#  'model_type': '1D CNN + Transformer (PyTorch, LOSO)',
#  'dataset_root': '/home/binghin2/Myproject/Dataset/CATSA',
#  'signal_type': 'HRV',
#  'source_signal': 'HR.csv (derived)',
#  'label_definition': {'non_stress': ['Baseline'],
#   'stress': ['Logic', 'Nback', 'Stroop', 'Sudoku']},
#  'split_rule': 'LOSO: 1 test subject + ~10% of remaining (4~5) for validation',
#  'total_complete_subjects': 50,
#  'num_folds_run': 50,
#  'hyperparameters': {'random_seed': 42,
#   'val_ratio': 0.1,
#   'min_val_subjects': 4,
#   'max_val_subjects': 5,
#   'window_size': 60,
#   'stride': 10,
#   'hrv_window': 30,
#   'batch_size': 64,
#   'epochs': 50,
#   'learning_rate': 0.001,
#   'dropout_rate': 0.3,
#   'weight_decay': 0.0001,
#   'patience': 8,
#   'transformer_heads': 8,
#   'transformer_layers': 2,
#   'transformer_ff_dim': 256,
#   'transformer_dropout': 0.1,
#   'normalization_mode': 'subject_zscore',
#   'loss_name': 'focal',
#   'focal_gamma': 2.0,
#   'focal_alpha': None,
#   'save_model': True,
#   'max_folds': None},
#  'aggregate_metrics': {'mean': {'accuracy': 0.5956923076923077,
#    'precision': 0.8181901939035262,
#    'recall': 0.5981221719457013,
#    'f1': 0.6744734865278429,
#    'loss': 0.0544646225829537},
#   'std': {'accuracy': 0.18811436478420696,
#    'precision': 0.19651405273691175,
#    'recall': 0.2323256508539217,
#    'f1': 0.2120839335030486,
#    'loss': 0.005055065570235279}},
#  'fold_results': [{'fold_index': 1,
#    'test_subject': 'Sub1',
#    'split': {'train': ['Sub2',
#      'Sub3',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub37',
#      'Sub38',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub7', 'Sub27', 'Sub36', 'Sub43', 'Sub51'],
#     'test': ['Sub1']},
#    'sample_shapes': {'x_train': [2856, 1, 60],
#     'x_val': [324, 1, 60],
#     'x_test': [64, 1, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2284},
#     'val': {'non_stress': 65, 'stress': 259},
#     'test': {'non_stress': 13, 'stress': 51}},
#    'best_epoch': 43,
#    'best_val_loss': 0.049605105762128475,
#    'test_metrics': {'loss': 0.054473161697387695,
#     'accuracy': 0.515625,
#     'precision': 0.9166666666666666,
#     'recall': 0.43137254901960786,
#     'f1': 0.5866666666666666,
#     'tn': 11.0,
#     'fp': 2.0,
#     'fn': 29.0,
#     'tp': 22.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20028011204481794,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.05721535315575386,
#      'val_loss': 0.05394734193881353,
#      'val_accuracy': 0.4104938271604938,
#      'val_f1': 0.4431486880466473,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.05540849740097837,
#      'val_loss': 0.05429007112979889,
#      'val_accuracy': 0.7746913580246914,
#      'val_f1': 0.8640595903165734,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.05505734263640158,
#      'val_loss': 0.05324770422813333,
#      'val_accuracy': 0.5339506172839507,
#      'val_f1': 0.6234413965087281,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.05497836025238705,
#      'val_loss': 0.05405552643868658,
#      'val_accuracy': 0.7716049382716049,
#      'val_f1': 0.8576923076923076,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.054907155919726156,
#      'val_loss': 0.05313413875338472,
#      'val_accuracy': 0.7777777777777778,
#      'val_f1': 0.8651685393258427,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.05500350628538626,
#      'val_loss': 0.05322166394304346,
#      'val_accuracy': 0.7222222222222222,
#      'val_f1': 0.8155737704918034,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.05461801518620897,
#      'val_loss': 0.05342063675692052,
#      'val_accuracy': 0.4876543209876543,
#      'val_f1': 0.5585106382978724,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.054842347691373,
#      'val_loss': 0.0544018543060915,
#      'val_accuracy': 0.4166666666666667,
#      'val_f1': 0.45217391304347826,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.054738800565735636,
#      'val_loss': 0.052764328909508974,
#      'val_accuracy': 0.5308641975308642,
#      'val_f1': 0.6122448979591837,
#      'lr': 0.001},
#     {'epoch': 10.0,
#      'train_loss': 0.05460910287265684,
#      'val_loss': 0.05269112511549467,
#      'val_accuracy': 0.5493827160493827,
#      'val_f1': 0.635,
#      'lr': 0.001},
#     {'epoch': 11.0,
#      'train_loss': 0.054621219301090186,
#      'val_loss': 0.0533257786322523,
#      'val_accuracy': 0.595679012345679,
#      'val_f1': 0.6932084309133489,
#      'lr': 0.001},
#     {'epoch': 12.0,
#      'train_loss': 0.05475226497533275,
#      'val_loss': 0.05392547200123469,
#      'val_accuracy': 0.7870370370370371,
#      'val_f1': 0.8710280373831776,
#      'lr': 0.001},
#     {'epoch': 13.0,
#      'train_loss': 0.054705757126003424,
#      'val_loss': 0.05336408307890833,
#      'val_accuracy': 0.49074074074074076,
#      'val_f1': 0.5599999999999999,
#      'lr': 0.001},
#     {'epoch': 14.0,
#      'train_loss': 0.054733297393685966,
#      'val_loss': 0.05313366026054194,
#      'val_accuracy': 0.5864197530864198,
#      'val_f1': 0.6854460093896714,
#      'lr': 0.001},
#     {'epoch': 15.0,
#      'train_loss': 0.054485608925338554,
#      'val_loss': 0.05315062688824571,
#      'val_accuracy': 0.7901234567901234,
#      'val_f1': 0.8731343283582089,
#      'lr': 0.0005},
#     {'epoch': 16.0,
#      'train_loss': 0.05431717336803925,
#      'val_loss': 0.052446494315877376,
#      'val_accuracy': 0.6666666666666666,
#      'val_f1': 0.7692307692307694,
#      'lr': 0.0005},
#     {'epoch': 17.0,
#      'train_loss': 0.05430897354495292,
#      'val_loss': 0.05240858318629088,
#      'val_accuracy': 0.7839506172839507,
#      'val_f1': 0.8674242424242423,
#      'lr': 0.0005},
#     {'epoch': 18.0,
#      'train_loss': 0.05430450269571539,
#      'val_loss': 0.05216849632101295,
#      'val_accuracy': 0.6388888888888888,
#      'val_f1': 0.7450980392156862,
#      'lr': 0.0005},
#     {'epoch': 19.0,
#      'train_loss': 0.05410586363252472,
#      'val_loss': 0.05299925383318354,
#      'val_accuracy': 0.7654320987654321,
#      'val_f1': 0.8527131782945736,
#      'lr': 0.0005},
#     {'epoch': 20.0,
#      'train_loss': 0.054162729531526566,
#      'val_loss': 0.05219082249167525,
#      'val_accuracy': 0.5987654320987654,
#      'val_f1': 0.7018348623853211,
#      'lr': 0.0005},
#     {'epoch': 21.0,
#      'train_loss': 0.05416745041348353,
#      'val_loss': 0.052365755593335186,
#      'val_accuracy': 0.6388888888888888,
#      'val_f1': 0.7334851936218679,
#      'lr': 0.0005},
#     {'epoch': 22.0,
#      'train_loss': 0.0541386242215039,
#      'val_loss': 0.05201360587904483,
#      'val_accuracy': 0.5679012345679012,
#      'val_f1': 0.6568627450980391,
#      'lr': 0.0005},
#     {'epoch': 23.0,
#      'train_loss': 0.054120930052604994,
#      'val_loss': 0.05343311240919578,
#      'val_accuracy': 0.7160493827160493,
#      'val_f1': 0.8114754098360656,
#      'lr': 0.0005},
#     {'epoch': 24.0,
#      'train_loss': 0.05361689847348785,
#      'val_loss': 0.0529728079283679,
#      'val_accuracy': 0.5740740740740741,
#      'val_f1': 0.6666666666666667,
#      'lr': 0.0005},
#     {'epoch': 25.0,
#      'train_loss': 0.05371250003492799,
#      'val_loss': 0.052725216580761805,
#      'val_accuracy': 0.7067901234567902,
#      'val_f1': 0.8065173116089613,
#      'lr': 0.0005},
#     {'epoch': 26.0,
#      'train_loss': 0.053799343303221614,
#      'val_loss': 0.05239643736018075,
#      'val_accuracy': 0.5493827160493827,
#      'val_f1': 0.6368159203980099,
#      'lr': 0.0005},
#     {'epoch': 27.0,
#      'train_loss': 0.053449260733541656,
#      'val_loss': 0.053498863231068776,
#      'val_accuracy': 0.7067901234567902,
#      'val_f1': 0.8088531187122736,
#      'lr': 0.00025},
#     {'epoch': 28.0,
#      'train_loss': 0.053437744723815545,
#      'val_loss': 0.05212674271545292,
#      'val_accuracy': 0.6882716049382716,
#      'val_f1': 0.7882599580712789,
#      'lr': 0.00025},
#     {'epoch': 29.0,
#      'train_loss': 0.0533581740256785,
#      'val_loss': 0.051439867435414115,
#      'val_accuracy': 0.5864197530864198,
#      'val_f1': 0.6778846153846154,
#      'lr': 0.00025},
#     {'epoch': 30.0,
#      'train_loss': 0.05343131410057137,
#      'val_loss': 0.0514462883181778,
#      'val_accuracy': 0.5895061728395061,
#      'val_f1': 0.6825775656324582,
#      'lr': 0.00025},
#     {'epoch': 31.0,
#      'train_loss': 0.05310157687515438,
#      'val_loss': 0.05112083109072697,
#      'val_accuracy': 0.6419753086419753,
#      'val_f1': 0.7444933920704847,
#      'lr': 0.00025},
#     {'epoch': 32.0,
#      'train_loss': 0.05328950688702052,
#      'val_loss': 0.0513253940936224,
#      'val_accuracy': 0.6882716049382716,
#      'val_f1': 0.7864693446088795,
#      'lr': 0.00025},
#     {'epoch': 33.0,
#      'train_loss': 0.05325952557330372,
#      'val_loss': 0.05087827914106993,
#      'val_accuracy': 0.5833333333333334,
#      'val_f1': 0.6746987951807228,
#      'lr': 0.00025},
#     {'epoch': 34.0,
#      'train_loss': 0.05324732049965725,
#      'val_loss': 0.051460157757923924,
#      'val_accuracy': 0.6759259259259259,
#      'val_f1': 0.7770700636942675,
#      'lr': 0.00025},
#     {'epoch': 35.0,
#      'train_loss': 0.0527696293630019,
#      'val_loss': 0.05141502135881671,
#      'val_accuracy': 0.6327160493827161,
#      'val_f1': 0.7361419068736141,
#      'lr': 0.00025},
#     {'epoch': 36.0,
#      'train_loss': 0.0530139921593065,
#      'val_loss': 0.052174211422234405,
#      'val_accuracy': 0.7283950617283951,
#      'val_f1': 0.8253968253968252,
#      'lr': 0.00025},
#     {'epoch': 37.0,
#      'train_loss': 0.05272280710751937,
#      'val_loss': 0.051652331871015054,
#      'val_accuracy': 0.6141975308641975,
#      'val_f1': 0.7191011235955056,
#      'lr': 0.00025},
#     {'epoch': 38.0,
#      'train_loss': 0.05243273487403279,
#      'val_loss': 0.05066900056453399,
#      'val_accuracy': 0.5679012345679012,
#      'val_f1': 0.6568627450980391,
#      'lr': 0.00025},
#     {'epoch': 39.0,
#      'train_loss': 0.05271157221633847,
#      'val_loss': 0.050813043743004035,
#      'val_accuracy': 0.6327160493827161,
#      'val_f1': 0.7226107226107227,
#      'lr': 0.00025},
#     {'epoch': 40.0,
#      'train_loss': 0.052631751819401565,
#      'val_loss': 0.05042102381035134,
#      'val_accuracy': 0.6759259259259259,
#      'val_f1': 0.7770700636942675,
#      'lr': 0.00025},
#     {'epoch': 41.0,
#      'train_loss': 0.0523901395708406,
#      'val_loss': 0.05077096861269739,
#      'val_accuracy': 0.6327160493827161,
#      'val_f1': 0.7337807606263982,
#      'lr': 0.00025},
#     {'epoch': 42.0,
#      'train_loss': 0.052458291899423304,
#      'val_loss': 0.05086859927317242,
#      'val_accuracy': 0.7253086419753086,
#      'val_f1': 0.8194726166328601,
#      'lr': 0.00025},
#     {'epoch': 43.0,
#      'train_loss': 0.05238684601768726,
#      'val_loss': 0.049605105762128475,
#      'val_accuracy': 0.6296296296296297,
#      'val_f1': 0.7196261682242991,
#      'lr': 0.00025},
#     {'epoch': 44.0,
#      'train_loss': 0.05271613548825435,
#      'val_loss': 0.05096733022803142,
#      'val_accuracy': 0.49382716049382713,
#      'val_f1': 0.5567567567567567,
#      'lr': 0.00025},
#     {'epoch': 45.0,
#      'train_loss': 0.052437118278080674,
#      'val_loss': 0.050874578364101454,
#      'val_accuracy': 0.7037037037037037,
#      'val_f1': 0.8016528925619834,
#      'lr': 0.00025},
#     {'epoch': 46.0,
#      'train_loss': 0.05240597013457149,
#      'val_loss': 0.050399879890459555,
#      'val_accuracy': 0.6388888888888888,
#      'val_f1': 0.738255033557047,
#      'lr': 0.00025},
#     {'epoch': 47.0,
#      'train_loss': 0.05240139105365056,
#      'val_loss': 0.05013513109750218,
#      'val_accuracy': 0.6604938271604939,
#      'val_f1': 0.761904761904762,
#      'lr': 0.00025},
#     {'epoch': 48.0,
#      'train_loss': 0.05246117083924491,
#      'val_loss': 0.05012611377938294,
#      'val_accuracy': 0.5864197530864198,
#      'val_f1': 0.6763285024154589,
#      'lr': 0.000125},
#     {'epoch': 49.0,
#      'train_loss': 0.05194434129139956,
#      'val_loss': 0.05012533671142143,
#      'val_accuracy': 0.6759259259259259,
#      'val_f1': 0.7761194029850748,
#      'lr': 0.000125},
#     {'epoch': 50.0,
#      'train_loss': 0.051843897311710845,
#      'val_loss': 0.05021740500757724,
#      'val_accuracy': 0.691358024691358,
#      'val_f1': 0.7899159663865546,
#      'lr': 0.000125}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_01_Sub1_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_01_Sub1.pt'}},
#   {'fold_index': 2,
#    'test_subject': 'Sub2',
#    'split': {'train': ['Sub1',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub38',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub51',
#      'Sub53'],
#     'val': ['Sub3', 'Sub7', 'Sub33', 'Sub45', 'Sub52'],
#     'test': ['Sub2']},
#    'sample_shapes': {'x_train': [2854, 1, 60],
#     'x_val': [325, 1, 60],
#     'x_test': [65, 1, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2282},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 50,
#    'best_val_loss': 0.05241961911893808,
#    'test_metrics': {'loss': 0.04191098525547064,
#     'accuracy': 0.8307692307692308,
#     'precision': 0.9361702127659575,
#     'recall': 0.8461538461538461,
#     'f1': 0.8888888888888888,
#     'tn': 10.0,
#     'fp': 3.0,
#     'fn': 8.0,
#     'tp': 44.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20042046250875964,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.05664404748711205,
#      'val_loss': 0.054860458637659364,
#      'val_accuracy': 0.563076923076923,
#      'val_f1': 0.6757990867579908,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.0551847726466903,
#      'val_loss': 0.05456340197187204,
#      'val_accuracy': 0.563076923076923,
#      'val_f1': 0.6743119266055045,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.05510700693759955,
#      'val_loss': 0.05487031487318186,
#      'val_accuracy': 0.7384615384615385,
#      'val_f1': 0.8399246704331451,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.05491265061963415,
#      'val_loss': 0.05440496273911916,
#      'val_accuracy': 0.5538461538461539,
#      'val_f1': 0.6681922196796338,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.054681603750442405,
#      'val_loss': 0.054153250799729276,
#      'val_accuracy': 0.5261538461538462,
#      'val_f1': 0.622549019607843,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.05473259860452607,
#      'val_loss': 0.054478354213329465,
#      'val_accuracy': 0.556923076923077,
#      'val_f1': 0.6697247706422019,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.054441507824793844,
#      'val_loss': 0.054973361125359166,
#      'val_accuracy': 0.6461538461538462,
#      'val_f1': 0.760914760914761,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.05485204850292824,
#      'val_loss': 0.05421942018545591,
#      'val_accuracy': 0.5138461538461538,
#      'val_f1': 0.5948717948717949,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.054965656295095026,
#      'val_loss': 0.05384653300046921,
#      'val_accuracy': 0.5476923076923077,
#      'val_f1': 0.6541176470588236,
#      'lr': 0.001},
#     {'epoch': 10.0,
#      'train_loss': 0.05463327688557248,
#      'val_loss': 0.05445779498953086,
#      'val_accuracy': 0.6615384615384615,
#      'val_f1': 0.7727272727272728,
#      'lr': 0.001},
#     {'epoch': 11.0,
#      'train_loss': 0.054573002542201335,
#      'val_loss': 0.054267809379559294,
#      'val_accuracy': 0.6,
#      'val_f1': 0.7136563876651982,
#      'lr': 0.001},
#     {'epoch': 12.0,
#      'train_loss': 0.05435718670121924,
#      'val_loss': 0.05379337361225715,
#      'val_accuracy': 0.5692307692307692,
#      'val_f1': 0.6803652968036529,
#      'lr': 0.001},
#     {'epoch': 13.0,
#      'train_loss': 0.05430016687796428,
#      'val_loss': 0.054286752624007374,
#      'val_accuracy': 0.6923076923076923,
#      'val_f1': 0.7991967871485943,
#      'lr': 0.001},
#     {'epoch': 14.0,
#      'train_loss': 0.05436495416644326,
#      'val_loss': 0.05414387461084586,
#      'val_accuracy': 0.556923076923077,
#      'val_f1': 0.6697247706422019,
#      'lr': 0.001},
#     {'epoch': 15.0,
#      'train_loss': 0.05475485109487195,
#      'val_loss': 0.05424687281250953,
#      'val_accuracy': 0.7015384615384616,
#      'val_f1': 0.8056112224448899,
#      'lr': 0.001},
#     {'epoch': 16.0,
#      'train_loss': 0.05440203838974509,
#      'val_loss': 0.05383556578021783,
#      'val_accuracy': 0.5907692307692308,
#      'val_f1': 0.7064017660044151,
#      'lr': 0.001},
#     {'epoch': 17.0,
#      'train_loss': 0.054522645542921515,
#      'val_loss': 0.054036598813075286,
#      'val_accuracy': 0.6523076923076923,
#      'val_f1': 0.7631027253668763,
#      'lr': 0.0005},
#     {'epoch': 18.0,
#      'train_loss': 0.054220571229005914,
#      'val_loss': 0.053634983026064356,
#      'val_accuracy': 0.6461538461538462,
#      'val_f1': 0.7589098532494759,
#      'lr': 0.0005},
#     {'epoch': 19.0,
#      'train_loss': 0.05391494410286103,
#      'val_loss': 0.054440155814473444,
#      'val_accuracy': 0.7107692307692308,
#      'val_f1': 0.8164062500000001,
#      'lr': 0.0005},
#     {'epoch': 20.0,
#      'train_loss': 0.0541321763686559,
#      'val_loss': 0.05366021330539997,
#      'val_accuracy': 0.5138461538461538,
#      'val_f1': 0.598984771573604,
#      'lr': 0.0005},
#     {'epoch': 21.0,
#      'train_loss': 0.054282957809365706,
#      'val_loss': 0.05338131201954988,
#      'val_accuracy': 0.5907692307692308,
#      'val_f1': 0.7024608501118569,
#      'lr': 0.0005},
#     {'epoch': 22.0,
#      'train_loss': 0.054069892626670835,
#      'val_loss': 0.053759604709652756,
#      'val_accuracy': 0.7261538461538461,
#      'val_f1': 0.8271844660194175,
#      'lr': 0.0005},
#     {'epoch': 23.0,
#      'train_loss': 0.0540634498349962,
#      'val_loss': 0.05365806613404017,
#      'val_accuracy': 0.6461538461538462,
#      'val_f1': 0.7578947368421053,
#      'lr': 0.0005},
#     {'epoch': 24.0,
#      'train_loss': 0.05395045677577188,
#      'val_loss': 0.053477380195489296,
#      'val_accuracy': 0.5876923076923077,
#      'val_f1': 0.7035398230088495,
#      'lr': 0.0005},
#     {'epoch': 25.0,
#      'train_loss': 0.054148925179857095,
#      'val_loss': 0.053539648692195234,
#      'val_accuracy': 0.683076923076923,
#      'val_f1': 0.7935871743486974,
#      'lr': 0.0005},
#     {'epoch': 26.0,
#      'train_loss': 0.0539664852745523,
#      'val_loss': 0.053719450607895854,
#      'val_accuracy': 0.556923076923077,
#      'val_f1': 0.6651162790697676,
#      'lr': 0.00025},
#     {'epoch': 27.0,
#      'train_loss': 0.05357275731710178,
#      'val_loss': 0.053487801511700336,
#      'val_accuracy': 0.6646153846153846,
#      'val_f1': 0.7761806981519507,
#      'lr': 0.00025},
#     {'epoch': 28.0,
#      'train_loss': 0.05368524453046026,
#      'val_loss': 0.05319359697401524,
#      'val_accuracy': 0.6523076923076923,
#      'val_f1': 0.7621052631578947,
#      'lr': 0.00025},
#     {'epoch': 29.0,
#      'train_loss': 0.05338290629264936,
#      'val_loss': 0.05407244910414402,
#      'val_accuracy': 0.7107692307692308,
#      'val_f1': 0.8164062500000001,
#      'lr': 0.00025},
#     {'epoch': 30.0,
#      'train_loss': 0.05350183800238784,
#      'val_loss': 0.05327098864202316,
#      'val_accuracy': 0.6492307692307693,
#      'val_f1': 0.7594936708860759,
#      'lr': 0.00025},
#     {'epoch': 31.0,
#      'train_loss': 0.05330144817345027,
#      'val_loss': 0.05323082010333355,
#      'val_accuracy': 0.5353846153846153,
#      'val_f1': 0.6308068459657702,
#      'lr': 0.00025},
#     {'epoch': 32.0,
#      'train_loss': 0.05331273442989225,
#      'val_loss': 0.05334157477777738,
#      'val_accuracy': 0.6553846153846153,
#      'val_f1': 0.7666666666666666,
#      'lr': 0.00025},
#     {'epoch': 33.0,
#      'train_loss': 0.05327763928971094,
#      'val_loss': 0.05322788129059168,
#      'val_accuracy': 0.6338461538461538,
#      'val_f1': 0.7440860215053763,
#      'lr': 0.000125},
#     {'epoch': 34.0,
#      'train_loss': 0.05297485224709447,
#      'val_loss': 0.053401288974743624,
#      'val_accuracy': 0.683076923076923,
#      'val_f1': 0.7919191919191919,
#      'lr': 0.000125},
#     {'epoch': 35.0,
#      'train_loss': 0.05280899226707266,
#      'val_loss': 0.05332375015203769,
#      'val_accuracy': 0.6738461538461539,
#      'val_f1': 0.7845528455284553,
#      'lr': 0.000125},
#     {'epoch': 36.0,
#      'train_loss': 0.05288441433521025,
#      'val_loss': 0.05292551367328717,
#      'val_accuracy': 0.6923076923076923,
#      'val_f1': 0.7975708502024291,
#      'lr': 0.000125},
#     {'epoch': 37.0,
#      'train_loss': 0.0529253980107005,
#      'val_loss': 0.05278645910895788,
#      'val_accuracy': 0.5784615384615385,
#      'val_f1': 0.6821345707656612,
#      'lr': 0.000125},
#     {'epoch': 38.0,
#      'train_loss': 0.0529223945286822,
#      'val_loss': 0.052564986491432555,
#      'val_accuracy': 0.6061538461538462,
#      'val_f1': 0.7117117117117115,
#      'lr': 0.000125},
#     {'epoch': 39.0,
#      'train_loss': 0.05277339752290996,
#      'val_loss': 0.05262212067842484,
#      'val_accuracy': 0.5907692307692308,
#      'val_f1': 0.6956521739130435,
#      'lr': 0.000125},
#     {'epoch': 40.0,
#      'train_loss': 0.05271327665523373,
#      'val_loss': 0.052866743086622314,
#      'val_accuracy': 0.6892307692307692,
#      'val_f1': 0.7926078028747433,
#      'lr': 0.000125},
#     {'epoch': 41.0,
#      'train_loss': 0.052691372102302694,
#      'val_loss': 0.052643344081365145,
#      'val_accuracy': 0.6523076923076923,
#      'val_f1': 0.7600849256900212,
#      'lr': 0.000125},
#     {'epoch': 42.0,
#      'train_loss': 0.052333422302782075,
#      'val_loss': 0.05317656832818802,
#      'val_accuracy': 0.7015384615384616,
#      'val_f1': 0.8063872255489022,
#      'lr': 0.000125},
#     {'epoch': 43.0,
#      'train_loss': 0.052293433650503145,
#      'val_loss': 0.05254667585858932,
#      'val_accuracy': 0.6,
#      'val_f1': 0.7058823529411764,
#      'lr': 0.000125},
#     {'epoch': 44.0,
#      'train_loss': 0.052341702461409755,
#      'val_loss': 0.05258099153637886,
#      'val_accuracy': 0.64,
#      'val_f1': 0.7462039045553145,
#      'lr': 0.000125},
#     {'epoch': 45.0,
#      'train_loss': 0.05244787423476608,
#      'val_loss': 0.05277977604705554,
#      'val_accuracy': 0.6923076923076923,
#      'val_f1': 0.794238683127572,
#      'lr': 0.000125},
#     {'epoch': 46.0,
#      'train_loss': 0.05227199405661478,
#      'val_loss': 0.05248933823635945,
#      'val_accuracy': 0.6738461538461539,
#      'val_f1': 0.7791666666666667,
#      'lr': 0.000125},
#     {'epoch': 47.0,
#      'train_loss': 0.05251954481287611,
#      'val_loss': 0.052949733877411254,
#      'val_accuracy': 0.6984615384615385,
#      'val_f1': 0.8008130081300813,
#      'lr': 0.000125},
#     {'epoch': 48.0,
#      'train_loss': 0.052397432125525285,
#      'val_loss': 0.052606624187185216,
#      'val_accuracy': 0.6553846153846153,
#      'val_f1': 0.7596566523605149,
#      'lr': 0.000125},
#     {'epoch': 49.0,
#      'train_loss': 0.05256858468838897,
#      'val_loss': 0.052670756589907865,
#      'val_accuracy': 0.5446153846153846,
#      'val_f1': 0.6390243902439025,
#      'lr': 0.000125},
#     {'epoch': 50.0,
#      'train_loss': 0.05222041431368024,
#      'val_loss': 0.05241961911893808,
#      'val_accuracy': 0.6646153846153846,
#      'val_f1': 0.7685774946921444,
#      'lr': 0.000125}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_02_Sub2_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_02_Sub2.pt'}},
#   {'fold_index': 3,
#    'test_subject': 'Sub3',
#    'split': {'train': ['Sub2',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub7',
#      'Sub8',
#      'Sub9',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub38',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub45',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub51',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub1', 'Sub10', 'Sub31', 'Sub46', 'Sub50'],
#     'test': ['Sub3']},
#    'sample_shapes': {'x_train': [2855, 1, 60],
#     'x_val': [324, 1, 60],
#     'x_test': [65, 1, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2283},
#     'val': {'non_stress': 65, 'stress': 259},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 5,
#    'best_val_loss': 0.051727872939757356,
#    'test_metrics': {'loss': 0.05482470473417869,
#     'accuracy': 0.5538461538461539,
#     'precision': 0.8108108108108109,
#     'recall': 0.5769230769230769,
#     'f1': 0.6741573033707865,
#     'tn': 6.0,
#     'fp': 7.0,
#     'fn': 22.0,
#     'tp': 30.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20035026269702277,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.05699474333333677,
#      'val_loss': 0.05496063074212015,
#      'val_accuracy': 0.7685185185185185,
#      'val_f1': 0.864376130198915,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.055270892874893916,
#      'val_loss': 0.0540262617998653,
#      'val_accuracy': 0.7438271604938271,
#      'val_f1': 0.8369351669941061,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.055707676040625195,
#      'val_loss': 0.05311798515879078,
#      'val_accuracy': 0.6512345679012346,
#      'val_f1': 0.7437641723356009,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.05520568355108936,
#      'val_loss': 0.053679880766588965,
#      'val_accuracy': 0.5092592592592593,
#      'val_f1': 0.5737265415549597,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.055035624281224355,
#      'val_loss': 0.051727872939757356,
#      'val_accuracy': 0.5679012345679012,
#      'val_f1': 0.6551724137931034,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.05502785608407286,
#      'val_loss': 0.05415553217868746,
#      'val_accuracy': 0.5493827160493827,
#      'val_f1': 0.6313131313131313,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.05495767788847357,
#      'val_loss': 0.05181569532479769,
#      'val_accuracy': 0.6080246913580247,
#      'val_f1': 0.6997635933806146,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.054888249367423314,
#      'val_loss': 0.05225172372143946,
#      'val_accuracy': 0.7037037037037037,
#      'val_f1': 0.8016528925619834,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.05502624919478196,
#      'val_loss': 0.0531296363491335,
#      'val_accuracy': 0.5709876543209876,
#      'val_f1': 0.6481012658227847,
#      'lr': 0.001},
#     {'epoch': 10.0,
#      'train_loss': 0.05465953145469759,
#      'val_loss': 0.052160818957620196,
#      'val_accuracy': 0.6172839506172839,
#      'val_f1': 0.7075471698113208,
#      'lr': 0.0005},
#     {'epoch': 11.0,
#      'train_loss': 0.05449509937740249,
#      'val_loss': 0.05193804553997369,
#      'val_accuracy': 0.6018518518518519,
#      'val_f1': 0.6964705882352941,
#      'lr': 0.0005},
#     {'epoch': 12.0,
#      'train_loss': 0.05464660163753505,
#      'val_loss': 0.051993002816114894,
#      'val_accuracy': 0.5740740740740741,
#      'val_f1': 0.6497461928934011,
#      'lr': 0.0005},
#     {'epoch': 13.0,
#      'train_loss': 0.05460984087606236,
#      'val_loss': 0.05220764093560937,
#      'val_accuracy': 0.5987654320987654,
#      'val_f1': 0.6813725490196079,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_03_Sub3_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_03_Sub3.pt'}},
#   {'fold_index': 4,
#    'test_subject': 'Sub4',
#    'split': {'train': ['Sub1',
#      'Sub2',
#      'Sub3',
#      'Sub5',
#      'Sub6',
#      'Sub7',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub38',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub44',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub51',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub8', 'Sub14', 'Sub43', 'Sub45', 'Sub50'],
#     'test': ['Sub4']},
#    'sample_shapes': {'x_train': [2854, 1, 60],
#     'x_val': [325, 1, 60],
#     'x_test': [65, 1, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2282},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 6,
#    'best_val_loss': 0.05513899201383957,
#    'test_metrics': {'loss': 0.056734284185446224,
#     'accuracy': 0.5384615384615384,
#     'precision': 0.84375,
#     'recall': 0.5192307692307693,
#     'f1': 0.6428571428571429,
#     'tn': 8.0,
#     'fp': 5.0,
#     'fn': 25.0,
#     'tp': 27.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20042046250875964,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.05749661335232129,
#      'val_loss': 0.056079994554703055,
#      'val_accuracy': 0.2,
#      'val_f1': 0.0,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.05527907332696527,
#      'val_loss': 0.0561254878112903,
#      'val_accuracy': 0.38153846153846155,
#      'val_f1': 0.4105571847507331,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.054734109336354975,
#      'val_loss': 0.05773992659953924,
#      'val_accuracy': 0.2,
#      'val_f1': 0.0,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.05473967134096277,
#      'val_loss': 0.055761409745766564,
#      'val_accuracy': 0.5876923076923077,
#      'val_f1': 0.7074235807860262,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.05471314448072264,
#      'val_loss': 0.056993328974797176,
#      'val_accuracy': 0.3292307692307692,
#      'val_f1': 0.3353658536585366,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.05477467806358478,
#      'val_loss': 0.05513899201383957,
#      'val_accuracy': 0.47384615384615386,
#      'val_f1': 0.5692695214105794,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.054833226031202824,
#      'val_loss': 0.05572386053892282,
#      'val_accuracy': 0.46153846153846156,
#      'val_f1': 0.5406824146981627,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.054311399437492344,
#      'val_loss': 0.05623933722193424,
#      'val_accuracy': 0.4707692307692308,
#      'val_f1': 0.5634517766497461,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.05411442987145706,
#      'val_loss': 0.05566452533006668,
#      'val_accuracy': 0.49230769230769234,
#      'val_f1': 0.5945945945945947,
#      'lr': 0.001},
#     {'epoch': 10.0,
#      'train_loss': 0.05403679647674156,
#      'val_loss': 0.05590387602265064,
#      'val_accuracy': 0.48307692307692307,
#      'val_f1': 0.5882352941176471,
#      'lr': 0.001},
#     {'epoch': 11.0,
#      'train_loss': 0.054138366010277605,
#      'val_loss': 0.05528631212619635,
#      'val_accuracy': 0.49230769230769234,
#      'val_f1': 0.5945945945945947,
#      'lr': 0.0005},
#     {'epoch': 12.0,
#      'train_loss': 0.053884341083232055,
#      'val_loss': 0.05562859892845154,
#      'val_accuracy': 0.48,
#      'val_f1': 0.5721518987341773,
#      'lr': 0.0005},
#     {'epoch': 13.0,
#      'train_loss': 0.0537359074656163,
#      'val_loss': 0.055680792813117684,
#      'val_accuracy': 0.47692307692307695,
#      'val_f1': 0.5728643216080402,
#      'lr': 0.0005},
#     {'epoch': 14.0,
#      'train_loss': 0.05385482614075461,
#      'val_loss': 0.05572326096204611,
#      'val_accuracy': 0.4553846153846154,
#      'val_f1': 0.5354330708661417,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_04_Sub4_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_04_Sub4.pt'}},
#   {'fold_index': 5,
#    'test_subject': 'Sub5',
#    'split': {'train': ['Sub1',
#      'Sub2',
#      'Sub3',
#      'Sub4',
#      'Sub6',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub14',
#      'Sub15',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub40',
#      'Sub41',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub50',
#      'Sub51',
#      'Sub52',
#      'Sub53'],
#     'val': ['Sub7', 'Sub13', 'Sub16', 'Sub38', 'Sub49'],
#     'test': ['Sub5']},
#    'sample_shapes': {'x_train': [2856, 1, 60],
#     'x_val': [323, 1, 60],
#     'x_test': [65, 1, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2284},
#     'val': {'non_stress': 65, 'stress': 258},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 1,
#    'best_val_loss': 0.05631882016872843,
#    'test_metrics': {'loss': 0.061397839796084624,
#     'accuracy': 0.2923076923076923,
#     'precision': 0.6363636363636364,
#     'recall': 0.2692307692307692,
#     'f1': 0.37837837837837834,
#     'tn': 5.0,
#     'fp': 8.0,
#     'fn': 38.0,
#     'tp': 14.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20028011204481794,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.05593146190715103,
#      'val_loss': 0.05631882016872843,
#      'val_accuracy': 0.42724458204334365,
#      'val_f1': 0.49591280653950953,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.05465344714225173,
#      'val_loss': 0.0583735301214106,
#      'val_accuracy': 0.6501547987616099,
#      'val_f1': 0.7735470941883767,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.05456732459762851,
#      'val_loss': 0.05694535400014913,
#      'val_accuracy': 0.5170278637770898,
#      'val_f1': 0.6338028169014085,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.05414092093080032,
#      'val_loss': 0.056526145583520364,
#      'val_accuracy': 0.5696594427244582,
#      'val_f1': 0.6789838337182449,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.05416788175409915,
#      'val_loss': 0.056323246367206516,
#      'val_accuracy': 0.4674922600619195,
#      'val_f1': 0.5473684210526316,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.054140185692063234,
#      'val_loss': 0.05959348211024568,
#      'val_accuracy': 0.6749226006191951,
#      'val_f1': 0.7976878612716762,
#      'lr': 0.0005},
#     {'epoch': 7.0,
#      'train_loss': 0.054011969287104965,
#      'val_loss': 0.05698819924434272,
#      'val_accuracy': 0.5758513931888545,
#      'val_f1': 0.7002188183807438,
#      'lr': 0.0005},
#     {'epoch': 8.0,
#      'train_loss': 0.05367617431182821,
#      'val_loss': 0.0580587687184198,
#      'val_accuracy': 0.6191950464396285,
#      'val_f1': 0.7463917525773195,
#      'lr': 0.0005},
#     {'epoch': 9.0,
#      'train_loss': 0.05385623559230516,
#      'val_loss': 0.05773984117220061,
#      'val_accuracy': 0.6470588235294118,
#      'val_f1': 0.7701612903225807,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_05_Sub5_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_05_Sub5.pt'}},
#   {'fold_index': 6,
#    'test_subject': 'Sub6',
#    'split': {'train': ['Sub1',
#      'Sub3',
#      'Sub4',
#      'Sub5',
#      'Sub7',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
# ...
#      'val_loss': 0.05172042861396884,
#      'val_accuracy': 0.6080246913580247,
#      'val_f1': 0.6954436450839327,
#      'lr': 0.001},
#     {'epoch': 16.0,
#      'train_loss': 0.054642346180362164,
#      'val_loss': 0.053183878070594354,
#      'val_accuracy': 0.6728395061728395,
#      'val_f1': 0.774468085106383,
#      'lr': 0.001},
#     {'epoch': 17.0,
#      'train_loss': 0.05436982911621627,
#      'val_loss': 0.05216595498316082,
#      'val_accuracy': 0.6574074074074074,
#      'val_f1': 0.7612903225806451,
#      'lr': 0.001},
#     {'epoch': 18.0,
#      'train_loss': 0.05441813960071203,
#      'val_loss': 0.05239911538399296,
#      'val_accuracy': 0.7222222222222222,
#      'val_f1': 0.8163265306122449,
#      'lr': 0.001},
#     {'epoch': 19.0,
#      'train_loss': 0.05429812605295415,
#      'val_loss': 0.052157068993022415,
#      'val_accuracy': 0.7438271604938271,
#      'val_f1': 0.8329979879275654,
#      'lr': 0.001},
#     {'epoch': 20.0,
#      'train_loss': 0.05402028802162503,
#      'val_loss': 0.05500972988428893,
#      'val_accuracy': 0.6882716049382716,
#      'val_f1': 0.802348336594912,
#      'lr': 0.0005},
#     {'epoch': 21.0,
#      'train_loss': 0.05411925859971138,
#      'val_loss': 0.05198491277334131,
#      'val_accuracy': 0.6820987654320988,
#      'val_f1': 0.7831578947368422,
#      'lr': 0.0005},
#     {'epoch': 22.0,
#      'train_loss': 0.05366788757818175,
#      'val_loss': 0.051582314212013175,
#      'val_accuracy': 0.6234567901234568,
#      'val_f1': 0.7214611872146119,
#      'lr': 0.0005},
#     {'epoch': 23.0,
#      'train_loss': 0.053535892318562324,
#      'val_loss': 0.0517103685365047,
#      'val_accuracy': 0.5679012345679012,
#      'val_f1': 0.669811320754717,
#      'lr': 0.0005},
#     {'epoch': 24.0,
#      'train_loss': 0.0534198721267296,
#      'val_loss': 0.05138825478009236,
#      'val_accuracy': 0.6759259259259259,
#      'val_f1': 0.7761194029850748,
#      'lr': 0.0005},
#     {'epoch': 25.0,
#      'train_loss': 0.053774365961499475,
#      'val_loss': 0.05119248148467806,
#      'val_accuracy': 0.6666666666666666,
#      'val_f1': 0.7662337662337662,
#      'lr': 0.0005},
#     {'epoch': 26.0,
#      'train_loss': 0.05325545038108024,
#      'val_loss': 0.051195013992212435,
#      'val_accuracy': 0.654320987654321,
#      'val_f1': 0.7565217391304349,
#      'lr': 0.0005},
#     {'epoch': 27.0,
#      'train_loss': 0.053187253203523556,
#      'val_loss': 0.052147706441673235,
#      'val_accuracy': 0.6327160493827161,
#      'val_f1': 0.7373068432671082,
#      'lr': 0.0005},
#     {'epoch': 28.0,
#      'train_loss': 0.05349952743344674,
#      'val_loss': 0.05282303178108033,
#      'val_accuracy': 0.7067901234567902,
#      'val_f1': 0.8033126293995858,
#      'lr': 0.0005},
#     {'epoch': 29.0,
#      'train_loss': 0.05347696082134798,
#      'val_loss': 0.05122627308707178,
#      'val_accuracy': 0.6666666666666666,
#      'val_f1': 0.7692307692307694,
#      'lr': 0.0005},
#     {'epoch': 30.0,
#      'train_loss': 0.053455296986052954,
#      'val_loss': 0.05110198687072153,
#      'val_accuracy': 0.6697530864197531,
#      'val_f1': 0.7718550106609808,
#      'lr': 0.0005},
#     {'epoch': 31.0,
#      'train_loss': 0.05346037426314296,
#      'val_loss': 0.051208269586901604,
#      'val_accuracy': 0.7222222222222222,
#      'val_f1': 0.8155737704918034,
#      'lr': 0.0005},
#     {'epoch': 32.0,
#      'train_loss': 0.05313738376919944,
#      'val_loss': 0.051067595496589756,
#      'val_accuracy': 0.6419753086419753,
#      'val_f1': 0.7422222222222221,
#      'lr': 0.0005},
#     {'epoch': 33.0,
#      'train_loss': 0.05330747984702032,
#      'val_loss': 0.051486397024106095,
#      'val_accuracy': 0.691358024691358,
#      'val_f1': 0.7890295358649788,
#      'lr': 0.0005},
#     {'epoch': 34.0,
#      'train_loss': 0.05303202493935041,
#      'val_loss': 0.05084692146399139,
#      'val_accuracy': 0.6358024691358025,
#      'val_f1': 0.7366071428571429,
#      'lr': 0.0005},
#     {'epoch': 35.0,
#      'train_loss': 0.053087822989855885,
#      'val_loss': 0.05130908744018755,
#      'val_accuracy': 0.6820987654320988,
#      'val_f1': 0.781316348195329,
#      'lr': 0.0005},
#     {'epoch': 36.0,
#      'train_loss': 0.05306884357787264,
#      'val_loss': 0.05212861368501628,
#      'val_accuracy': 0.6574074074074074,
#      'val_f1': 0.7592190889370932,
#      'lr': 0.0005},
#     {'epoch': 37.0,
#      'train_loss': 0.053310244232938085,
#      'val_loss': 0.05148258451142429,
#      'val_accuracy': 0.6141975308641975,
#      'val_f1': 0.7191011235955056,
#      'lr': 0.0005},
#     {'epoch': 38.0,
#      'train_loss': 0.053161515646504856,
#      'val_loss': 0.05103702863885297,
#      'val_accuracy': 0.6975308641975309,
#      'val_f1': 0.7932489451476793,
#      'lr': 0.0005},
#     {'epoch': 39.0,
#      'train_loss': 0.053106757088999826,
#      'val_loss': 0.050864549123762565,
#      'val_accuracy': 0.6851851851851852,
#      'val_f1': 0.7829787234042553,
#      'lr': 0.00025},
#     {'epoch': 40.0,
#      'train_loss': 0.05315565252758158,
#      'val_loss': 0.05086873021022773,
#      'val_accuracy': 0.6635802469135802,
#      'val_f1': 0.7645788336933045,
#      'lr': 0.00025},
#     {'epoch': 41.0,
#      'train_loss': 0.05269152358330904,
#      'val_loss': 0.05060953016818306,
#      'val_accuracy': 0.6697530864197531,
#      'val_f1': 0.7698924731182795,
#      'lr': 0.00025},
#     {'epoch': 42.0,
#      'train_loss': 0.05251812725711203,
#      'val_loss': 0.05080318901641869,
#      'val_accuracy': 0.6419753086419753,
#      'val_f1': 0.7422222222222221,
#      'lr': 0.00025},
#     {'epoch': 43.0,
#      'train_loss': 0.05261841753788044,
#      'val_loss': 0.050619185614733046,
#      'val_accuracy': 0.7067901234567902,
#      'val_f1': 0.80083857442348,
#      'lr': 0.00025},
#     {'epoch': 44.0,
#      'train_loss': 0.05287090190629199,
#      'val_loss': 0.050538729715310496,
#      'val_accuracy': 0.6388888888888888,
#      'val_f1': 0.7417218543046358,
#      'lr': 0.00025},
#     {'epoch': 45.0,
#      'train_loss': 0.052657694588766,
#      'val_loss': 0.050385926079786855,
#      'val_accuracy': 0.7037037037037037,
#      'val_f1': 0.799163179916318,
#      'lr': 0.00025},
#     {'epoch': 46.0,
#      'train_loss': 0.05255383279716071,
#      'val_loss': 0.05057551507136704,
#      'val_accuracy': 0.6635802469135802,
#      'val_f1': 0.7645788336933045,
#      'lr': 0.00025},
#     {'epoch': 47.0,
#      'train_loss': 0.05253111296406769,
#      'val_loss': 0.05042719873197285,
#      'val_accuracy': 0.7253086419753086,
#      'val_f1': 0.8164948453608247,
#      'lr': 0.00025},
#     {'epoch': 48.0,
#      'train_loss': 0.05263873476097964,
#      'val_loss': 0.05073044883708159,
#      'val_accuracy': 0.7407407407407407,
#      'val_f1': 0.8292682926829268,
#      'lr': 0.00025},
#     {'epoch': 49.0,
#      'train_loss': 0.05233058629854339,
#      'val_loss': 0.050354844948023926,
#      'val_accuracy': 0.6790123456790124,
#      'val_f1': 0.7758620689655172,
#      'lr': 0.00025},
#     {'epoch': 50.0,
#      'train_loss': 0.05256379676653291,
#      'val_loss': 0.05062603966597422,
#      'val_accuracy': 0.7283950617283951,
#      'val_f1': 0.8181818181818181,
#      'lr': 0.00025}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_48_Sub51_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_48_Sub51.pt'}},
#   {'fold_index': 49,
#    'test_subject': 'Sub52',
#    'split': {'train': ['Sub1',
#      'Sub2',
#      'Sub3',
#      'Sub4',
#      'Sub5',
#      'Sub6',
#      'Sub7',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub26',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub42',
#      'Sub43',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub51'],
#     'val': ['Sub8', 'Sub38', 'Sub40', 'Sub41', 'Sub53'],
#     'test': ['Sub52']},
#    'sample_shapes': {'x_train': [2854, 1, 60],
#     'x_val': [325, 1, 60],
#     'x_test': [65, 1, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2282},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 8,
#    'best_val_loss': 0.05740703221697074,
#    'test_metrics': {'loss': 0.054767339791242896,
#     'accuracy': 0.5538461538461539,
#     'precision': 0.9259259259259259,
#     'recall': 0.4807692307692308,
#     'f1': 0.6329113924050633,
#     'tn': 11.0,
#     'fp': 2.0,
#     'fn': 27.0,
#     'tp': 25.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20042046250875964,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.055813240502147136,
#      'val_loss': 0.05943090621095437,
#      'val_accuracy': 0.23076923076923078,
#      'val_f1': 0.14965986394557823,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.054614760130435,
#      'val_loss': 0.061968085399040806,
#      'val_accuracy': 0.21846153846153846,
#      'val_f1': 0.1118881118881119,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.05447705794901136,
#      'val_loss': 0.05862277905528362,
#      'val_accuracy': 0.24615384615384617,
#      'val_f1': 0.21725239616613418,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.054045233264638566,
#      'val_loss': 0.058521324585263546,
#      'val_accuracy': 0.5476923076923077,
#      'val_f1': 0.6811279826464208,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.05409922762222447,
#      'val_loss': 0.058400300775582975,
#      'val_accuracy': 0.41846153846153844,
#      'val_f1': 0.5239294710327457,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.053985392866680984,
#      'val_loss': 0.06154806244831819,
#      'val_accuracy': 0.22153846153846155,
#      'val_f1': 0.1423728813559322,
#      'lr': 0.001},
#     {'epoch': 7.0,
#      'train_loss': 0.054031358782486556,
#      'val_loss': 0.06064306778403429,
#      'val_accuracy': 0.56,
#      'val_f1': 0.6976744186046512,
#      'lr': 0.001},
#     {'epoch': 8.0,
#      'train_loss': 0.053934941891928025,
#      'val_loss': 0.05740703221697074,
#      'val_accuracy': 0.39076923076923076,
#      'val_f1': 0.4974619289340101,
#      'lr': 0.001},
#     {'epoch': 9.0,
#      'train_loss': 0.05389888442337471,
#      'val_loss': 0.05866766546781246,
#      'val_accuracy': 0.40615384615384614,
#      'val_f1': 0.5187032418952617,
#      'lr': 0.001},
#     {'epoch': 10.0,
#      'train_loss': 0.053874461527211565,
#      'val_loss': 0.06026361879821007,
#      'val_accuracy': 0.6061538461538462,
#      'val_f1': 0.7408906882591094,
#      'lr': 0.001},
#     {'epoch': 11.0,
#      'train_loss': 0.053752900997324264,
#      'val_loss': 0.05964066303120209,
#      'val_accuracy': 0.6523076923076923,
#      'val_f1': 0.7805825242718447,
#      'lr': 0.001},
#     {'epoch': 12.0,
#      'train_loss': 0.05391978832730565,
#      'val_loss': 0.05938285661431459,
#      'val_accuracy': 0.3723076923076923,
#      'val_f1': 0.4659685863874346,
#      'lr': 0.001},
#     {'epoch': 13.0,
#      'train_loss': 0.053372833671566484,
#      'val_loss': 0.060628862380981446,
#      'val_accuracy': 0.5230769230769231,
#      'val_f1': 0.6593406593406593,
#      'lr': 0.0005},
#     {'epoch': 14.0,
#      'train_loss': 0.053703386814300216,
#      'val_loss': 0.05932435588194774,
#      'val_accuracy': 0.39384615384615385,
#      'val_f1': 0.4987277353689567,
#      'lr': 0.0005},
#     {'epoch': 15.0,
#      'train_loss': 0.05314378819435563,
#      'val_loss': 0.0597096509543749,
#      'val_accuracy': 0.39076923076923076,
#      'val_f1': 0.4999999999999999,
#      'lr': 0.0005},
#     {'epoch': 16.0,
#      'train_loss': 0.053336118001389016,
#      'val_loss': 0.05877494522012197,
#      'val_accuracy': 0.4492307692307692,
#      'val_f1': 0.5748218527315914,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_49_Sub52_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_49_Sub52.pt'}},
#   {'fold_index': 50,
#    'test_subject': 'Sub53',
#    'split': {'train': ['Sub1',
#      'Sub2',
#      'Sub3',
#      'Sub4',
#      'Sub6',
#      'Sub7',
#      'Sub8',
#      'Sub9',
#      'Sub10',
#      'Sub11',
#      'Sub12',
#      'Sub13',
#      'Sub14',
#      'Sub15',
#      'Sub16',
#      'Sub17',
#      'Sub18',
#      'Sub20',
#      'Sub21',
#      'Sub22',
#      'Sub23',
#      'Sub24',
#      'Sub27',
#      'Sub28',
#      'Sub29',
#      'Sub30',
#      'Sub31',
#      'Sub32',
#      'Sub33',
#      'Sub34',
#      'Sub35',
#      'Sub36',
#      'Sub37',
#      'Sub40',
#      'Sub42',
#      'Sub44',
#      'Sub45',
#      'Sub46',
#      'Sub47',
#      'Sub48',
#      'Sub49',
#      'Sub50',
#      'Sub51',
#      'Sub52'],
#     'val': ['Sub5', 'Sub26', 'Sub38', 'Sub41', 'Sub43'],
#     'test': ['Sub53']},
#    'sample_shapes': {'x_train': [2854, 1, 60],
#     'x_val': [325, 1, 60],
#     'x_test': [65, 1, 60]},
#    'class_distribution': {'train': {'non_stress': 572, 'stress': 2282},
#     'val': {'non_stress': 65, 'stress': 260},
#     'test': {'non_stress': 13, 'stress': 52}},
#    'best_epoch': 1,
#    'best_val_loss': 0.057826862977101254,
#    'test_metrics': {'loss': 0.05272807378608447,
#     'accuracy': 0.8,
#     'precision': 0.8679245283018868,
#     'recall': 0.8846153846153846,
#     'f1': 0.8761904761904762,
#     'tn': 6.0,
#     'fp': 7.0,
#     'fn': 6.0,
#     'tp': 46.0},
#    'normalization_mode': 'subject_zscore',
#    'loss_config': {'loss_name': 'focal',
#     'pos_weight': 1.0,
#     'focal_gamma': 2.0,
#     'focal_alpha': 0.20042046250875964,
#     'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#    'history': [{'epoch': 1.0,
#      'train_loss': 0.056417031160124385,
#      'val_loss': 0.057826862977101254,
#      'val_accuracy': 0.6615384615384615,
#      'val_f1': 0.7868217054263567,
#      'lr': 0.001},
#     {'epoch': 2.0,
#      'train_loss': 0.05475020709107535,
#      'val_loss': 0.058045002588858974,
#      'val_accuracy': 0.5661538461538461,
#      'val_f1': 0.7044025157232704,
#      'lr': 0.001},
#     {'epoch': 3.0,
#      'train_loss': 0.05451503432321231,
#      'val_loss': 0.059263206078456,
#      'val_accuracy': 0.5323076923076923,
#      'val_f1': 0.6695652173913044,
#      'lr': 0.001},
#     {'epoch': 4.0,
#      'train_loss': 0.05434759712263096,
#      'val_loss': 0.059548554775806575,
#      'val_accuracy': 0.5323076923076923,
#      'val_f1': 0.6724137931034482,
#      'lr': 0.001},
#     {'epoch': 5.0,
#      'train_loss': 0.054154758018551796,
#      'val_loss': 0.06124708633010204,
#      'val_accuracy': 0.44,
#      'val_f1': 0.553921568627451,
#      'lr': 0.001},
#     {'epoch': 6.0,
#      'train_loss': 0.05432707143095129,
#      'val_loss': 0.05897227215079161,
#      'val_accuracy': 0.3569230769230769,
#      'val_f1': 0.41782729805013924,
#      'lr': 0.0005},
#     {'epoch': 7.0,
#      'train_loss': 0.05415267707713434,
#      'val_loss': 0.058561430252515354,
#      'val_accuracy': 0.4584615384615385,
#      'val_f1': 0.5906976744186047,
#      'lr': 0.0005},
#     {'epoch': 8.0,
#      'train_loss': 0.053771428014631445,
#      'val_loss': 0.06064274803950236,
#      'val_accuracy': 0.48307692307692307,
#      'val_f1': 0.625,
#      'lr': 0.0005},
#     {'epoch': 9.0,
#      'train_loss': 0.05387695001068864,
#      'val_loss': 0.05936852404704461,
#      'val_accuracy': 0.47384615384615386,
#      'val_f1': 0.6139954853273139,
#      'lr': 0.0005}],
#    'model_saved': True,
#    'model_files': {'best_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_50_Sub53_best.pt',
#     'final_model': '/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/HRV/Save_model/hrv_1dcnn_transformer_loso_torch_fold_50_Sub53.pt'}}],
#  'device': 'cuda'}

# %%
# LOSO 결과 시각화: Accuracy/F1, Confusion Matrix, Train/Val Loss curves
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

if "result_loso" not in globals():
    raise RuntimeError("먼저 1번 셀을 실행해 result_loso를 생성해 주세요.")

fold_results = result_loso.get("fold_results", [])
if len(fold_results) == 0:
    raise RuntimeError("fold_results가 비어 있습니다. 1번 셀 학습 결과를 확인해 주세요.")

# 1) Fold metric 요약
metrics_df = pd.DataFrame([
    {
        "fold_index": fr["fold_index"],
        "test_subject": fr["test_subject"],
        "accuracy": fr["test_metrics"]["accuracy"],
        "f1": fr["test_metrics"]["f1"],
        "tn": fr["test_metrics"]["tn"],
        "fp": fr["test_metrics"]["fp"],
        "fn": fr["test_metrics"]["fn"],
        "tp": fr["test_metrics"]["tp"],
    }
    for fr in fold_results
])

acc_mean = float(metrics_df["accuracy"].mean())
f1_mean = float(metrics_df["f1"].mean())
acc_std = float(metrics_df["accuracy"].std(ddof=0))
f1_std = float(metrics_df["f1"].std(ddof=0))

print("=== LOSO Aggregate Metrics ===")
print(f"Accuracy mean±std: {acc_mean:.4f} ± {acc_std:.4f}")
print(f"F1-score mean±std: {f1_mean:.4f} ± {f1_std:.4f}")

plt.figure(figsize=(6, 4))
bars = plt.bar(["Accuracy", "F1-score"], [acc_mean, f1_mean], color=["#4e79a7", "#f28e2b"], edgecolor="black")
plt.ylim(0, 1.0)
plt.title("LOSO Mean Metrics")
plt.ylabel("Score")
plt.grid(axis="y", linestyle="--", alpha=0.4)
for b, v in zip(bars, [acc_mean, f1_mean]):
    plt.text(b.get_x() + b.get_width() / 2, v + 0.02, f"{v:.4f}", ha="center", va="bottom")
plt.tight_layout()
plt.show()

# 2) Confusion Matrix (fold 합산 후 row-normalized)
tn = float(metrics_df["tn"].sum())
fp = float(metrics_df["fp"].sum())
fn = float(metrics_df["fn"].sum())
tp = float(metrics_df["tp"].sum())
conf_counts = np.array([[tn, fp], [fn, tp]], dtype=np.float64)
row_sums = conf_counts.sum(axis=1, keepdims=True)
conf_ratio = np.divide(conf_counts, np.maximum(row_sums, 1.0))

print("Confusion Matrix Count [[TN, FP], [FN, TP]]:")
print(conf_counts.astype(int))
print("Confusion Matrix Row Ratio [[TN, FP], [FN, TP]]:")
print(np.round(conf_ratio, 4))

fig, ax = plt.subplots(figsize=(5, 4))
im = ax.imshow(conf_ratio, cmap="Blues", vmin=0.0, vmax=1.0)
ax.set_title("LOSO Confusion Matrix (Row-normalized)")
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")
ax.set_xticks([0, 1])
ax.set_yticks([0, 1])
ax.set_xticklabels(["Non-stress", "Stress"])
ax.set_yticklabels(["Non-stress", "Stress"])
for i in range(conf_ratio.shape[0]):
    for j in range(conf_ratio.shape[1]):
        ax.text(j, i, f"{conf_ratio[i, j]:.3f}", ha="center", va="center", color="black", fontsize=12, fontweight="bold")
fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
plt.tight_layout()
plt.show()

# 3) Train/Val Loss 곡선 (fold 평균)
history_frames = []
for fr in fold_results:
    history_rows = fr.get("history", [])
    if len(history_rows) == 0:
        continue

    h = pd.DataFrame(history_rows)
    if "epoch" in h.columns and "train_loss" in h.columns and "val_loss" in h.columns:
        h["fold_index"] = fr["fold_index"]
        history_frames.append(h[["fold_index", "epoch", "train_loss", "val_loss"]])

if len(history_frames) == 0:
    print("history가 없어 Train/Val loss 곡선을 그릴 수 없습니다. 1번 셀을 다시 실행해 주세요.")
else:
    hist_all = pd.concat(history_frames, ignore_index=True)
    hist_mean = hist_all.groupby("epoch", as_index=False)[["train_loss", "val_loss"]].mean()

    plt.figure(figsize=(7, 4))
    plt.plot(hist_mean["epoch"], hist_mean["train_loss"], label="Train Loss", linewidth=2)
    plt.plot(hist_mean["epoch"], hist_mean["val_loss"], label="Val Loss", linewidth=2)
    plt.title("LOSO Mean Train/Val Loss Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.grid(alpha=0.3, linestyle="--")
    plt.legend()
    plt.tight_layout()
    plt.show()

{
    "accuracy_mean": acc_mean,
    "f1_mean": f1_mean,
    "confusion_matrix_count": conf_counts.astype(int).tolist(),
    "confusion_matrix_row_ratio": conf_ratio.tolist(),
}
# Out:
# === LOSO Aggregate Metrics ===
# Accuracy mean±std: 0.5957 ± 0.1881
# F1-score mean±std: 0.6745 ± 0.2121
# Confusion Matrix Count [[TN, FP], [FN, TP]]:
# [[ 381  269]
#  [1043 1551]]
# Confusion Matrix Row Ratio [[TN, FP], [FN, TP]]:
# [[0.5862 0.4138]
#  [0.4021 0.5979]]
# {'accuracy_mean': 0.5956923076923077,
#  'f1_mean': 0.6744734865278429,
#  'confusion_matrix_count': [[381, 269], [1043, 1551]],
#  'confusion_matrix_row_ratio': [[0.5861538461538461, 0.41384615384615386],
#   [0.4020817270624518, 0.5979182729375482]]}

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# 1. result 변수에 의존하지 않고, 노트북에 있는 find_dataset_root() 함수를 직접 사용합니다.
dataset_root = find_dataset_root()
all_subjects = discover_complete_subjects(dataset_root)

# 2. 전체 데이터에 대해 피험자별 Z-score 정규화 적용하여 로드
print(f"총 {len(all_subjects)}명의 데이터를 로드하여 PCA를 수행합니다... (시간이 조금 걸릴 수 있습니다)")
x_all, y_all = build_split_arrays(
    dataset_root,
    all_subjects,
    window_size=60,
    stride=10,
    hrv_window=30,
    normalization_mode="subject_zscore",
)

# 3. (N, C, L) -> (N, C*L)로 평탄화
x_all_2d = x_all.reshape(x_all.shape[0], -1)

# 4. PCA 모델 생성 및 학습
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_all_2d)

# 5. 시각화
plt.figure(figsize=(10, 7))
plt.scatter(
    x_pca[y_all == 0, 0],
    x_pca[y_all == 0, 1],
    color="#4e79a7",
    alpha=0.5,
    label="Non-stress (0)",
    edgecolors="none",
    s=20,
)
plt.scatter(
    x_pca[y_all == 1, 0],
    x_pca[y_all == 1, 1],
    color="#f28e2b",
    alpha=0.5,
    label="Stress (1)",
    edgecolors="none",
    s=20,
)

plt.title(
    f"2D PCA of HRV Time-Series (All {len(all_subjects)} Subjects, Derived from HR)",
    fontsize=15,
    fontweight="bold",
)
plt.xlabel(f"Principal Component 1 ({pca.explained_variance_ratio_[0] * 100:.1f}%)", fontsize=12)
plt.ylabel(f"Principal Component 2 ({pca.explained_variance_ratio_[1] * 100:.1f}%)", fontsize=12)

leg = plt.legend(fontsize=12, markerscale=2)
for lh in leg.legend_handles:
    lh.set_alpha(1)

plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# 총 50명의 데이터를 로드하여 PCA를 수행합니다... (시간이 조금 걸릴 수 있습니다)
