# %% [markdown]
# # ACC Grand Final Production Training (45/5)
#
# 이 노트북은 `ACC_LOSO.ipynb`의 함수/클래스를 재사용하여,
# 50명 전체 피험자를 `Train 45 / Val 5`로 분할해 최종 통합 모델을 학습하고 저장합니다.
#
# - 샘플링레이트: `32Hz`
# - 기본 정규화: `subject_zscore`
# - 기본 손실함수: `focal`
# - 저장 경로: `/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/ACC/Save_model/ACC_Grand_Final_Production_Model.pt`

# %%
import argparse
import json
import random
from dataclasses import asdict
from pathlib import Path
from typing import Dict, List, Optional

import numpy as np
import torch


def import_symbols_from_notebook(nb_path: Path, symbols: List[str]) -> Dict[str, object]:
    with nb_path.open("r", encoding="utf-8") as f:
        raw_nb = json.load(f)
    code_cells = [c for c in raw_nb.get("cells", []) if c.get("cell_type") == "code"]
    if len(code_cells) == 0:
        raise RuntimeError(f"No code cells found in {nb_path}")

    namespace: Dict[str, object] = {}
    # ACC_LOSO의 핵심 정의는 1번 코드 셀에 있으므로 그대로 실행해 재사용한다.
    first_source = code_cells[0].get("source", [])
    if isinstance(first_source, list):
        first_source = "".join(first_source)
    exec(first_source, namespace)

    missing = [name for name in symbols if name not in namespace]
    if missing:
        raise RuntimeError(f"Missing symbols from {nb_path.name}: {missing}")

    return {name: namespace[name] for name in symbols}


def build_arg_parser() -> argparse.ArgumentParser:
    parser = argparse.ArgumentParser(description="Train final ACC production model with 45/5 subject split")
    parser.add_argument("--epochs", type=int, default=50)
    parser.add_argument("--batch_size", type=int, default=64)
    parser.add_argument("--lr", type=float, default=0.001)
    parser.add_argument("--norm_mode", type=str, default="subject_zscore", choices=["subject_zscore", "baseline_zscore", "none"])
    parser.add_argument("--loss_name", type=str, default="focal", choices=["focal", "weighted_bce"])
    parser.add_argument("--seed", type=int, default=42)
    return parser


def main(cli_args: Optional[List[str]] = None) -> Dict[str, object]:
    parser = build_arg_parser()
    if cli_args is None:
        args, _ = parser.parse_known_args()
    else:
        args = parser.parse_args(cli_args)

    notebook_dir = Path.cwd()
    loso_nb_path = notebook_dir / "ACC_LOSO.ipynb"
    if not loso_nb_path.exists():
        raise FileNotFoundError(f"Cannot find source notebook: {loso_nb_path}")

    symbols = import_symbols_from_notebook(
        loso_nb_path,
        symbols=[
            "HyperParameters",
            "find_dataset_root",
            "discover_complete_subjects",
            "build_split_arrays",
            "make_loader",
            "Acc1DCNNTransformer",
            "make_criterion",
            "train_one_epoch",
            "evaluate",
            "ACC_SAMPLING_RATE_HZ",
        ],
    )

    HyperParameters = symbols["HyperParameters"]
    find_dataset_root = symbols["find_dataset_root"]
    discover_complete_subjects = symbols["discover_complete_subjects"]
    build_split_arrays = symbols["build_split_arrays"]
    make_loader = symbols["make_loader"]
    Acc1DCNNTransformer = symbols["Acc1DCNNTransformer"]
    make_criterion = symbols["make_criterion"]
    train_one_epoch = symbols["train_one_epoch"]
    evaluate = symbols["evaluate"]
    ACC_SAMPLING_RATE_HZ = symbols["ACC_SAMPLING_RATE_HZ"]

    np.random.seed(args.seed)
    random.seed(args.seed)
    torch.manual_seed(args.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(args.seed)

    dataset_root = find_dataset_root()
    all_subjects = discover_complete_subjects(dataset_root)
    if len(all_subjects) < 50:
        raise ValueError(f"Need 50 complete subjects, found {len(all_subjects)}")

    # 요구사항: 전체 50명 기준으로 45/5 split
    all_subjects = sorted(all_subjects, key=lambda x: int(x[3:]))[:50]
    val_subjects = sorted(random.sample(all_subjects, 5), key=lambda x: int(x[3:]))
    train_subjects = sorted([s for s in all_subjects if s not in val_subjects], key=lambda x: int(x[3:]))

    window_seconds = 60
    stride_seconds = 10
    hp = HyperParameters(
        random_seed=args.seed,
        window_size=ACC_SAMPLING_RATE_HZ * window_seconds,
        stride=ACC_SAMPLING_RATE_HZ * stride_seconds,
        batch_size=args.batch_size,
        epochs=args.epochs,
        learning_rate=args.lr,
        dropout_rate=0.3,
        weight_decay=1e-4,
        patience=8,
        transformer_heads=8,
        transformer_layers=2,
        transformer_ff_dim=256,
        transformer_dropout=0.1,
        normalization_mode=args.norm_mode,
        loss_name=args.loss_name,
        focal_gamma=2.0,
        focal_alpha=None,
        save_model=False,
        max_folds=None,
    )

    print("=== Grand Final ACC Training (45/5) ===")
    print(f"Sampling rate: {ACC_SAMPLING_RATE_HZ}Hz")
    print(f"Window/Stride (seconds): {window_seconds}/{stride_seconds}")
    print(f"Window/Stride (samples): {hp.window_size}/{hp.stride}")
    print(f"Normalization: {hp.normalization_mode}")
    print(f"Loss: {hp.loss_name}")
    print(f"Train subjects ({len(train_subjects)}): {train_subjects}")
    print(f"Val subjects ({len(val_subjects)}): {val_subjects}")

    x_train, y_train = build_split_arrays(
        dataset_root,
        train_subjects,
        hp.window_size,
        hp.stride,
        normalization_mode=hp.normalization_mode,
    )
    x_val, y_val = build_split_arrays(
        dataset_root,
        val_subjects,
        hp.window_size,
        hp.stride,
        normalization_mode=hp.normalization_mode,
    )

    train_loader = make_loader(x_train, y_train, hp.batch_size, shuffle=True)
    val_loader = make_loader(x_val, y_val, hp.batch_size, shuffle=False)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = Acc1DCNNTransformer(hp=hp).to(device)
    criterion, loss_cfg = make_criterion(y_train, hp, device)
    optimizer = torch.optim.Adam(model.parameters(), lr=hp.learning_rate, weight_decay=hp.weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=4)

    best_val_loss = float("inf")
    best_epoch = -1
    wait = 0
    best_final_state = None
    history: List[Dict[str, float]] = []

    for epoch in range(1, hp.epochs + 1):
        train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
        val_metrics = evaluate(model, val_loader, criterion, device)
        scheduler.step(val_metrics["loss"])

        history.append(
            {
                "epoch": float(epoch),
                "train_loss": float(train_loss),
                "val_loss": float(val_metrics["loss"]),
                "val_accuracy": float(val_metrics["accuracy"]),
                "val_f1": float(val_metrics["f1"]),
                "lr": float(optimizer.param_groups[0]["lr"]),
            }
        )

        if val_metrics["loss"] < best_val_loss:
            best_val_loss = val_metrics["loss"]
            best_epoch = epoch
            wait = 0
            best_final_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            wait += 1
            if wait >= hp.patience:
                print(f"Early stopping at epoch {epoch} (best epoch: {best_epoch})")
                break

    if best_final_state is None:
        raise RuntimeError("best_final_state is None. Training did not produce a valid checkpoint.")

    save_dir = Path("/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/ACC/Save_model")
    final_model_path = save_dir / "ACC_Grand_Final_Production_Model.pt"
    final_model_path.parent.mkdir(parents=True, exist_ok=True)

    payload = {
        "model_state_dict": best_final_state,
        "model_name": "ACC_Grand_Final_Production_Model",
        "created_from": "ACC_LOSO.ipynb",
        "sampling_rate_hz": int(ACC_SAMPLING_RATE_HZ),
        "window_seconds": int(window_seconds),
        "stride_seconds": int(stride_seconds),
        "best_epoch": int(best_epoch),
        "best_val_loss": float(best_val_loss),
        "device_used_for_training": str(device),
        "hyperparameters": asdict(hp),
        "normalization_mode": hp.normalization_mode,
        "loss_config": loss_cfg,
        "subject_split": {"train": train_subjects, "val": val_subjects},
        "history": history,
    }

    torch.save(payload, final_model_path)

    print(f"Saved final production model to: {final_model_path}")
    return payload


# Notebook 실행 시 기본 인자 사용
final_result = main()
final_result
# Out:
# === Fold 1/50 | Test: Sub1 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.4769, 'f1': 0.6047, 'loss': 0.0982}
#
# === Fold 2/50 | Test: Sub2 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.6462, 'f1': 0.7723, 'loss': 0.0475}
#
# === Fold 3/50 | Test: Sub3 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.6615, 'f1': 0.7317, 'loss': 0.044}
#
# === Fold 4/50 | Test: Sub4 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.6308, 'f1': 0.75, 'loss': 0.0393}
#
# === Fold 5/50 | Test: Sub5 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.8889, 'loss': 0.0441}
#
# === Fold 6/50 | Test: Sub6 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.5846, 'f1': 0.7379, 'loss': 0.0505}
#
# === Fold 7/50 | Test: Sub7 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.6, 'f1': 0.6667, 'loss': 0.0416}
#
# === Fold 8/50 | Test: Sub8 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 24 (best epoch: 16)
# Fold test metrics: {'accuracy': 0.5538, 'f1': 0.6133, 'loss': 0.0562}
#
# === Fold 9/50 | Test: Sub9 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.7231, 'f1': 0.7907, 'loss': 0.0393}
#
# === Fold 10/50 | Test: Sub10 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.6308, 'f1': 0.7736, 'loss': 0.0526}
#
# === Fold 11/50 | Test: Sub11 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 38 (best epoch: 30)
# Fold test metrics: {'accuracy': 0.5846, 'f1': 0.7033, 'loss': 0.0571}
#
# === Fold 12/50 | Test: Sub12 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 17 (best epoch: 9)
# Fold test metrics: {'accuracy': 0.9385, 'f1': 0.963, 'loss': 0.0432}
#
# === Fold 13/50 | Test: Sub13 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 19 (best epoch: 11)
# Fold test metrics: {'accuracy': 0.5692, 'f1': 0.7255, 'loss': 0.0914}
#
# === Fold 14/50 | Test: Sub14 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.7385, 'f1': 0.809, 'loss': 0.0477}
#
# === Fold 15/50 | Test: Sub15 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 20 (best epoch: 12)
# Fold test metrics: {'accuracy': 0.3385, 'f1': 0.4557, 'loss': 0.088}
#
# === Fold 16/50 | Test: Sub16 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.8615, 'f1': 0.9053, 'loss': 0.0308}
#
# === Fold 17/50 | Test: Sub17 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.5231, 'f1': 0.6869, 'loss': 0.0646}
#
# === Fold 18/50 | Test: Sub18 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 25 (best epoch: 17)
# Fold test metrics: {'accuracy': 0.8769, 'f1': 0.9167, 'loss': 0.0305}
#
# === Fold 19/50 | Test: Sub20 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.5538, 'f1': 0.6133, 'loss': 0.0485}
#
# === Fold 20/50 | Test: Sub21 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.8889, 'loss': 0.052}
#
# === Fold 21/50 | Test: Sub22 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.7385, 'f1': 0.8046, 'loss': 0.0377}
#
# === Fold 22/50 | Test: Sub23 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.7385, 'f1': 0.8211, 'loss': 0.0455}
#
# === Fold 23/50 | Test: Sub24 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0253}
#
# === Fold 24/50 | Test: Sub26 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.4923, 'f1': 0.6598, 'loss': 0.0697}
#
# === Fold 25/50 | Test: Sub27 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.7846, 'f1': 0.8478, 'loss': 0.039}
#
# === Fold 26/50 | Test: Sub28 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.2154, 'f1': 0.3377, 'loss': 0.0824}
#
# === Fold 27/50 | Test: Sub29 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.3538, 'f1': 0.5227, 'loss': 0.1327}
#
# === Fold 28/50 | Test: Sub30 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 17 (best epoch: 9)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.8889, 'loss': 0.0556}
#
# === Fold 29/50 | Test: Sub31 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.4, 'f1': 0.4, 'loss': 0.0397}
#
# === Fold 30/50 | Test: Sub32 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.2, 'f1': 0.0, 'loss': 0.0542}
#
# === Fold 31/50 | Test: Sub33 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.6308, 'f1': 0.7209, 'loss': 0.0511}
#
# === Fold 32/50 | Test: Sub34 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.6769, 'f1': 0.7742, 'loss': 0.0415}
#
# === Fold 33/50 | Test: Sub35 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.6154, 'f1': 0.6835, 'loss': 0.0349}
#
# === Fold 34/50 | Test: Sub36 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.7077, 'f1': 0.7765, 'loss': 0.0391}
#
# === Fold 35/50 | Test: Sub37 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.5077, 'f1': 0.6735, 'loss': 0.3682}
#
# === Fold 36/50 | Test: Sub38 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.3846, 'f1': 0.5556, 'loss': 0.3121}
#
# === Fold 37/50 | Test: Sub40 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 24 (best epoch: 16)
# Fold test metrics: {'accuracy': 0.3231, 'f1': 0.4762, 'loss': 0.2828}
#
# === Fold 38/50 | Test: Sub41 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.6, 'f1': 0.7111, 'loss': 0.0482}
#
# === Fold 39/50 | Test: Sub42 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.6, 'f1': 0.6667, 'loss': 0.0388}
#
# === Fold 40/50 | Test: Sub43 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.6615, 'f1': 0.7381, 'loss': 0.0431}
#
# === Fold 41/50 | Test: Sub44 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.7231, 'f1': 0.7907, 'loss': 0.0425}
#
# === Fold 42/50 | Test: Sub45 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.5846, 'f1': 0.6494, 'loss': 0.0373}
#
# === Fold 43/50 | Test: Sub46 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.6, 'f1': 0.6667, 'loss': 0.062}
#
# === Fold 44/50 | Test: Sub47 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 31 (best epoch: 23)
# Fold test metrics: {'accuracy': 0.9692, 'f1': 0.9804, 'loss': 0.0253}
#
# === Fold 45/50 | Test: Sub48 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 19 (best epoch: 11)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.8889, 'loss': 0.1381}
#
# === Fold 46/50 | Test: Sub49 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.7692, 'f1': 0.8315, 'loss': 0.0406}
#
# === Fold 47/50 | Test: Sub50 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 19 (best epoch: 11)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.8889, 'loss': 0.0573}
#
# === Fold 48/50 | Test: Sub51 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.6, 'f1': 0.6667, 'loss': 0.0425}
#
# === Fold 49/50 | Test: Sub52 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.7385, 'f1': 0.8046, 'loss': 0.0348}
#
# === Fold 50/50 | Test: Sub53 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.7846, 'f1': 0.8444, 'loss': 0.041}
#
# === LOSO Training Complete ===
# Saved metadata (hyperparameters + metrics): /home/binghin2/Myproject/Research/CATSA/Train/Individual_data/ACC/Save_model/acc_1dcnn_transformer_loso_torch_hyperparameters.json
# Saved per-fold best/final checkpoints under LOSO save_dir
# Aggregate mean metrics: {'accuracy': 0.6378, 'precision': 0.8618, 'recall': 0.6473, 'f1': 0.7214, 'loss': 0.0686}
# Aggregate std metrics: {'accuracy': 0.1769, 'precision': 0.1806, 'recall': 0.2162, 'f1': 0.1757, 'loss': 0.0683}
# === Grand Final ACC Training (45/5) ===
# Sampling rate: 32Hz
# Window/Stride (seconds): 60/10
# Window/Stride (samples): 1920/320
# Normalization: subject_zscore
# Loss: focal
# Train subjects (45): ['Sub1', 'Sub3', 'Sub4', 'Sub5', 'Sub6', 'Sub7', 'Sub9', 'Sub10', 'Sub11', 'Sub12', 'Sub13', 'Sub14', 'Sub15', 'Sub16', 'Sub17', 'Sub20', 'Sub21', 'Sub22', 'Sub23', 'Sub24', 'Sub26', 'Sub27', 'Sub28', 'Sub29', 'Sub30', 'Sub31', 'Sub32', 'Sub33', 'Sub34', 'Sub35', 'Sub36', 'Sub37', 'Sub38', 'Sub40', 'Sub41', 'Sub42', 'Sub43', 'Sub45', 'Sub46', 'Sub47', 'Sub48', 'Sub49', 'Sub50', 'Sub52', 'Sub53']
# Val subjects (5): ['Sub2', 'Sub8', 'Sub18', 'Sub44', 'Sub51']
# Early stopping at epoch 16 (best epoch: 8)
# Saved final production model to: /home/binghin2/Myproject/Research/CATSA/Train/Individual_data/ACC/Save_model/ACC_Grand_Final_Production_Model.pt
# {'model_state_dict': {'pos_embedding': tensor([[[ 3.0271e-04,  1.3738e-03, -5.0820e-03,  ...,  1.9420e-03,
#              4.8708e-03, -6.4481e-03],
#            [ 3.5521e-03,  6.5776e-03,  3.5069e-03,  ..., -8.8254e-03,
#             -4.6818e-03, -1.4427e-02],
#            [ 1.8044e-03,  1.7501e-03, -3.3586e-06,  ..., -9.7030e-03,
#             -5.6015e-03, -9.5918e-03],
#            ...,
#            [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#              0.0000e+00,  0.0000e+00],
#            [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#              0.0000e+00,  0.0000e+00],
#            [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#              0.0000e+00,  0.0000e+00]]]),
#   'cnn.0.weight': tensor([[[ 0.1651,  0.1747, -0.0650,  0.1915, -0.0704],
#            [ 0.0498, -0.1246,  0.1464,  0.2176, -0.1862],
#            [ 0.2445,  0.0877,  0.2119,  0.0635,  0.1501]],
#
#           [[-0.0024,  0.2370,  0.0712, -0.0868,  0.1018],
#            [-0.1302, -0.0474, -0.1149,  0.1384, -0.2104],
#            [-0.0844, -0.0456, -0.1228,  0.0243, -0.2015]],
#
#           [[ 0.2239, -0.1985,  0.1954,  0.0445, -0.0736],
#            [ 0.1447,  0.0225,  0.1907,  0.0112, -0.0936],
#            [ 0.1027, -0.0493,  0.1377,  0.2458,  0.1687]],
#
#           [[-0.1176,  0.1307,  0.0361,  0.1133, -0.1595],
#            [-0.2760, -0.1330, -0.2139,  0.1810,  0.0494],
#            [ 0.1064,  0.0867,  0.0014,  0.2000, -0.1717]],
#
#           [[ 0.0228, -0.1742,  0.0719, -0.0835,  0.0783],
#            [-0.0074,  0.2467, -0.1082, -0.1134, -0.1200],
#            [ 0.2417,  0.0835,  0.2383, -0.2274, -0.2668]],
#
#           [[-0.1906, -0.1611,  0.1095,  0.0999,  0.2209],
#            [-0.1210, -0.1665,  0.1423, -0.0993,  0.1648],
#            [-0.0627,  0.1355, -0.2025, -0.1483,  0.0720]],
#
#           [[ 0.0820, -0.0347,  0.1780,  0.2016, -0.1584],
#            [-0.1530,  0.1902, -0.1160, -0.1228, -0.2656],
#            [-0.0889,  0.0841, -0.0067, -0.1398,  0.0278]],
#
#           [[-0.1345, -0.1692, -0.0981, -0.1777, -0.1169],
#            [ 0.2600,  0.0629,  0.0920, -0.2098, -0.1398],
#            [-0.0663,  0.0224, -0.1942, -0.1269, -0.1420]],
#
#           [[ 0.0004, -0.0864, -0.0134, -0.1675, -0.1664],
#            [-0.1148, -0.0572, -0.1741,  0.2439, -0.0193],
#            [ 0.2301,  0.0887, -0.2188,  0.1864, -0.0651]],
#
#           [[-0.0465, -0.1677, -0.2082,  0.1122, -0.0174],
#            [ 0.1283, -0.1796,  0.2217, -0.1573, -0.0182],
#            [ 0.0851,  0.1578,  0.2380,  0.2543, -0.1794]],
#
#           [[ 0.0572, -0.1171, -0.0301, -0.1958,  0.2275],
#            [-0.1815,  0.1434,  0.0937,  0.0873, -0.1316],
#            [ 0.2260,  0.0510,  0.0164, -0.2592,  0.1006]],
#
#           [[-0.0424, -0.1196,  0.2197,  0.0488, -0.1450],
#            [-0.1138, -0.0096,  0.1549, -0.0501, -0.1253],
#            [-0.0909, -0.1868,  0.0979,  0.1852, -0.2100]],
#
#           [[ 0.0832,  0.1390,  0.0653, -0.0533,  0.1346],
#            [ 0.1106,  0.0723, -0.0664, -0.0898,  0.0030],
#            [-0.0219, -0.0471,  0.1836,  0.2229,  0.0012]],
#
#           [[-0.0370,  0.0185, -0.0014,  0.0741,  0.0797],
#            [-0.2275, -0.0960,  0.2092,  0.0930, -0.0149],
#            [-0.1379, -0.1539, -0.1885, -0.0519,  0.0467]],
#
#           [[ 0.1594,  0.1208, -0.2176, -0.1503, -0.0328],
#            [ 0.2256,  0.0279, -0.0739,  0.0908, -0.1106],
#            [-0.1728,  0.1547, -0.1266, -0.0653, -0.2688]],
#
#           [[ 0.1833,  0.2198,  0.1156, -0.1567, -0.2295],
#            [-0.2007,  0.2130,  0.1357,  0.2297,  0.1489],
#            [ 0.0829,  0.0291, -0.1658, -0.1906, -0.2077]],
#
#           [[ 0.1190, -0.1012, -0.0235, -0.1168, -0.0235],
#            [-0.1900, -0.1779,  0.0670, -0.0837,  0.1435],
#            [-0.0750, -0.1664, -0.0543, -0.0863, -0.0565]],
#
#           [[-0.2402,  0.1460, -0.1806,  0.1311,  0.1177],
#            [ 0.1697, -0.2203,  0.1628, -0.1438,  0.0741],
#             0.0967,  0.0286, -0.0785, -0.0201, -0.0285, -0.0229,  0.0991, -0.0752,
#            -0.0753,  0.0923, -0.1018,  0.0675, -0.0599,  0.0490, -0.0157,  0.0221,
#            -0.0581, -0.0455, -0.0453, -0.0567, -0.0966,  0.0989,  0.0777, -0.0731,
#             0.0342, -0.1044, -0.0510, -0.0684,  0.0893,  0.0002,  0.0604, -0.0058,
#             0.0021,  0.0610, -0.0014, -0.0382, -0.0859, -0.0286,  0.0824, -0.0177,
#            -0.0059, -0.0760, -0.0376,  0.0059, -0.0551,  0.0075,  0.0060,  0.0467,
#            -0.0884,  0.0447, -0.0988, -0.0219,  0.0280,  0.0678,  0.1008, -0.0212]]),
#   'classifier.3.bias': tensor([0.0182])},
#  'model_name': 'ACC_Grand_Final_Production_Model',
#  'created_from': 'ACC_LOSO.ipynb',
#  'sampling_rate_hz': 32,
#  'window_seconds': 60,
#  'stride_seconds': 10,
#  'best_epoch': 8,
#  'best_val_loss': 0.043522098538949366,
#  'device_used_for_training': 'cuda',
#  'hyperparameters': {'random_seed': 42,
#   'val_ratio': 0.1,
#   'min_val_subjects': 4,
#   'max_val_subjects': 5,
#   'window_size': 1920,
#   'stride': 320,
#   'batch_size': 64,
#   'epochs': 50,
#   'learning_rate': 0.001,
#   'dropout_rate': 0.3,
#   'weight_decay': 0.0001,
#   'patience': 8,
#   'transformer_heads': 8,
#   'transformer_layers': 2,
#   'transformer_ff_dim': 256,
#   'transformer_dropout': 0.1,
#   'normalization_mode': 'subject_zscore',
#   'loss_name': 'focal',
#   'focal_gamma': 2.0,
#   'focal_alpha': None,
#   'save_model': False,
#   'max_folds': None},
#  'normalization_mode': 'subject_zscore',
#  'loss_config': {'loss_name': 'focal',
#   'pos_weight': 1.0,
#   'focal_gamma': 2.0,
#   'focal_alpha': 0.2,
#   'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#  'subject_split': {'train': ['Sub1',
#    'Sub3',
#    'Sub4',
#    'Sub5',
#    'Sub6',
#    'Sub7',
#    'Sub9',
#    'Sub10',
#    'Sub11',
#    'Sub12',
#    'Sub13',
#    'Sub14',
#    'Sub15',
#    'Sub16',
#    'Sub17',
#    'Sub20',
#    'Sub21',
#    'Sub22',
#    'Sub23',
#    'Sub24',
#    'Sub26',
#    'Sub27',
#    'Sub28',
#    'Sub29',
#    'Sub30',
#    'Sub31',
#    'Sub32',
#    'Sub33',
#    'Sub34',
#    'Sub35',
#    'Sub36',
#    'Sub37',
#    'Sub38',
#    'Sub40',
#    'Sub41',
#    'Sub42',
#    'Sub43',
#    'Sub45',
#    'Sub46',
#    'Sub47',
#    'Sub48',
#    'Sub49',
#    'Sub50',
#    'Sub52',
#    'Sub53'],
#   'val': ['Sub2', 'Sub8', 'Sub18', 'Sub44', 'Sub51']},
#  'history': [{'epoch': 1.0,
#    'train_loss': 0.05083922135014819,
#    'val_loss': 0.049033528537704395,
#    'val_accuracy': 0.72,
#    'val_f1': 0.8205128205128205,
#    'lr': 0.001},
#   {'epoch': 2.0,
#    'train_loss': 0.04684788738305752,
#    'val_loss': 0.04594635075728337,
#    'val_accuracy': 0.72,
#    'val_f1': 0.8,
#    'lr': 0.001},
#   {'epoch': 3.0,
#    'train_loss': 0.046485331874882053,
#    'val_loss': 0.05385032441574507,
#    'val_accuracy': 0.6584615384615384,
#    'val_f1': 0.7448275862068966,
#    'lr': 0.001},
#   {'epoch': 4.0,
#    'train_loss': 0.045922063045267365,
#    'val_loss': 0.050229310675595815,
#    'val_accuracy': 0.7107692307692308,
#    'val_f1': 0.7991452991452992,
#    'lr': 0.001},
#   {'epoch': 5.0,
#    'train_loss': 0.04497699647122978,
#    'val_loss': 0.0569746765994037,
#    'val_accuracy': 0.6984615384615385,
#    'val_f1': 0.7923728813559322,
#    'lr': 0.001},
#   {'epoch': 6.0,
#    'train_loss': 0.04228699967265129,
#    'val_loss': 0.07380479724558357,
#    'val_accuracy': 0.556923076923077,
#    'val_f1': 0.6417910447761195,
#    'lr': 0.001},
#   {'epoch': 7.0,
#    'train_loss': 0.04292264510041628,
#    'val_loss': 0.053838780336081984,
#    'val_accuracy': 0.6646153846153846,
#    'val_f1': 0.7604395604395604,
#    'lr': 0.0005},
#   {'epoch': 8.0,
#    'train_loss': 0.04042794631205054,
#    'val_loss': 0.043522098538949366,
#    'val_accuracy': 0.7261538461538461,
#    'val_f1': 0.8118393234672304,
#    'lr': 0.0005},
#   {'epoch': 9.0,
#    'train_loss': 0.03749709024770647,
#    'val_loss': 0.05814304378188143,
#    'val_accuracy': 0.7323076923076923,
#    'val_f1': 0.8213552361396304,
#    'lr': 0.0005},
#   {'epoch': 10.0,
#    'train_loss': 0.035874527545056795,
#    'val_loss': 0.05253518562647514,
#    'val_accuracy': 0.6738461538461539,
#    'val_f1': 0.7675438596491229,
#    'lr': 0.0005},
#   {'epoch': 11.0,
#    'train_loss': 0.03609025441874296,
#    'val_loss': 0.06377741132468845,
#    'val_accuracy': 0.6953846153846154,
#    'val_f1': 0.791578947368421,
#    'lr': 0.0005},
#   {'epoch': 12.0,
#    'train_loss': 0.035678206619798626,
#    'val_loss': 0.06078594550382919,
#    'val_accuracy': 0.6461538461538462,
#    'val_f1': 0.7494553376906318,
#    'lr': 0.0005},
#   {'epoch': 13.0,
#    'train_loss': 0.03269574295570198,
#    'val_loss': 0.06737808729562228,
#    'val_accuracy': 0.7353846153846154,
#    'val_f1': 0.8138528138528138,
#    'lr': 0.00025},
#   {'epoch': 14.0,
#    'train_loss': 0.03080174430185913,
#    'val_loss': 0.06856608184632093,
#    'val_accuracy': 0.6430769230769231,
#    'val_f1': 0.7467248908296943,
#    'lr': 0.00025},
#   {'epoch': 15.0,
#    'train_loss': 0.02719743411000977,
#    'val_loss': 0.09228375727380178,
#    'val_accuracy': 0.6553846153846153,
#    'val_f1': 0.7656903765690376,
#    'lr': 0.00025},
#   {'epoch': 16.0,
#    'train_loss': 0.027422627557037223,
#    'val_loss': 0.10272158642892744,
#    'val_accuracy': 0.6338461538461538,
#    'val_f1': 0.7525987525987526,
#    'lr': 0.00025}]}
