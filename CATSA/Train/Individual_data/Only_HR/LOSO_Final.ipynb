# %% [markdown]
# # HR Grand Final Production Training (45/5)
#
# 이 노트북은 `HR_LOSO.ipynb`의 함수/클래스를 재사용하여,
# 50명 전체 피험자를 `Train 45 / Val 5`로 분할해 최종 통합 모델을 학습하고 저장합니다.
#
# - 기본 정규화: `subject_zscore`
# - 기본 손실함수: `focal`
# - 저장 경로: `dataset_root.parent / Save_model / HR_Grand_Final_Production_Model.pt`

# %%
import argparse
import json
import random
from dataclasses import asdict
from pathlib import Path
from typing import Dict, List, Optional

import numpy as np
import torch


def import_symbols_from_notebook(nb_path: Path, symbols: List[str]) -> Dict[str, object]:
    with nb_path.open("r", encoding="utf-8") as f:
        raw_nb = json.load(f)
    code_cells = [c for c in raw_nb.get("cells", []) if c.get("cell_type") == "code"]
    if len(code_cells) == 0:
        raise RuntimeError(f"No code cells found in {nb_path}")

    namespace: Dict[str, object] = {}
    # HR_LOSO의 핵심 정의는 1번 코드 셀에 있으므로 그대로 실행해 재사용한다.
    first_source = code_cells[0].get("source", [])
    if isinstance(first_source, list):
        first_source = "".join(first_source)
    exec(first_source, namespace)

    missing = [name for name in symbols if name not in namespace]
    if missing:
        raise RuntimeError(f"Missing symbols from {nb_path.name}: {missing}")

    return {name: namespace[name] for name in symbols}


def build_arg_parser() -> argparse.ArgumentParser:
    parser = argparse.ArgumentParser(description="Train final HR production model with 45/5 subject split")
    parser.add_argument("--epochs", type=int, default=50)
    parser.add_argument("--batch_size", type=int, default=64)
    parser.add_argument("--lr", type=float, default=0.001)
    parser.add_argument("--norm_mode", type=str, default="subject_zscore", choices=["subject_zscore", "baseline_zscore", "none"])
    parser.add_argument("--loss_name", type=str, default="focal", choices=["focal", "weighted_bce"])
    parser.add_argument("--seed", type=int, default=42)
    return parser


def main(cli_args: Optional[List[str]] = None) -> Dict[str, object]:
    parser = build_arg_parser()
    if cli_args is None:
        args, _ = parser.parse_known_args()
    else:
        args = parser.parse_args(cli_args)

    notebook_dir = Path.cwd()
    loso_nb_path = notebook_dir / "HR_LOSO.ipynb"
    if not loso_nb_path.exists():
        raise FileNotFoundError(f"Cannot find source notebook: {loso_nb_path}")

    symbols = import_symbols_from_notebook(
        loso_nb_path,
        symbols=[
            "HyperParameters",
            "find_dataset_root",
            "discover_complete_subjects",
            "build_split_arrays",
            "make_loader",
            "HR1DCNNTransformer",
            "make_criterion",
            "train_one_epoch",
            "evaluate",
        ],
    )

    HyperParameters = symbols["HyperParameters"]
    find_dataset_root = symbols["find_dataset_root"]
    discover_complete_subjects = symbols["discover_complete_subjects"]
    build_split_arrays = symbols["build_split_arrays"]
    make_loader = symbols["make_loader"]
    HR1DCNNTransformer = symbols["HR1DCNNTransformer"]
    make_criterion = symbols["make_criterion"]
    train_one_epoch = symbols["train_one_epoch"]
    evaluate = symbols["evaluate"]

    np.random.seed(args.seed)
    random.seed(args.seed)
    torch.manual_seed(args.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(args.seed)

    dataset_root = find_dataset_root()
    all_subjects = discover_complete_subjects(dataset_root)
    if len(all_subjects) < 50:
        raise ValueError(f"Need 50 complete subjects, found {len(all_subjects)}")

    # 요구사항: 전체 50명 기준으로 45/5 split
    all_subjects = sorted(all_subjects, key=lambda x: int(x[3:]))[:50]
    val_subjects = sorted(random.sample(all_subjects, 5), key=lambda x: int(x[3:]))
    train_subjects = sorted([s for s in all_subjects if s not in val_subjects], key=lambda x: int(x[3:]))

    hp = HyperParameters(
        random_seed=args.seed,
        window_size=60,
        stride=10,
        batch_size=args.batch_size,
        epochs=args.epochs,
        learning_rate=args.lr,
        dropout_rate=0.3,
        weight_decay=1e-4,
        patience=8,
        transformer_heads=8,
        transformer_layers=2,
        transformer_ff_dim=256,
        transformer_dropout=0.1,
        normalization_mode=args.norm_mode,
        loss_name=args.loss_name,
        focal_gamma=2.0,
        focal_alpha=None,
        save_model=False,
        max_folds=None,
    )

    print("=== Grand Final HR Training (45/5) ===")
    print(f"Normalization: {hp.normalization_mode}")
    print(f"Loss: {hp.loss_name}")
    print(f"Train subjects ({len(train_subjects)}): {train_subjects}")
    print(f"Val subjects ({len(val_subjects)}): {val_subjects}")

    x_train, y_train = build_split_arrays(
        dataset_root,
        train_subjects,
        hp.window_size,
        hp.stride,
        normalization_mode=hp.normalization_mode,
    )
    x_val, y_val = build_split_arrays(
        dataset_root,
        val_subjects,
        hp.window_size,
        hp.stride,
        normalization_mode=hp.normalization_mode,
    )

    train_loader = make_loader(x_train, y_train, hp.batch_size, shuffle=True)
    val_loader = make_loader(x_val, y_val, hp.batch_size, shuffle=False)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = HR1DCNNTransformer(hp=hp).to(device)
    criterion, loss_cfg = make_criterion(y_train, hp, device)
    optimizer = torch.optim.Adam(model.parameters(), lr=hp.learning_rate, weight_decay=hp.weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=4)

    best_val_loss = float("inf")
    best_epoch = -1
    wait = 0
    best_final_state = None
    history: List[Dict[str, float]] = []

    for epoch in range(1, hp.epochs + 1):
        train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
        val_metrics = evaluate(model, val_loader, criterion, device)
        scheduler.step(val_metrics["loss"])

        history.append(
            {
                "epoch": float(epoch),
                "train_loss": float(train_loss),
                "val_loss": float(val_metrics["loss"]),
                "val_accuracy": float(val_metrics["accuracy"]),
                "val_f1": float(val_metrics["f1"]),
                "lr": float(optimizer.param_groups[0]["lr"]),
            }
        )

        if val_metrics["loss"] < best_val_loss:
            best_val_loss = val_metrics["loss"]
            best_epoch = epoch
            wait = 0
            best_final_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            wait += 1
            if wait >= hp.patience:
                print(f"Early stopping at epoch {epoch} (best epoch: {best_epoch})")
                break

    if best_final_state is None:
        raise RuntimeError("best_final_state is None. Training did not produce a valid checkpoint.")

    final_model_path = dataset_root.parent / "Save_model" / "HR_Grand_Final_Production_Model.pt"
    final_model_path.parent.mkdir(parents=True, exist_ok=True)

    payload = {
        "model_state_dict": best_final_state,
        "model_name": "HR_Grand_Final_Production_Model",
        "created_from": "HR_LOSO.ipynb",
        "best_epoch": int(best_epoch),
        "best_val_loss": float(best_val_loss),
        "device_used_for_training": str(device),
        "hyperparameters": asdict(hp),
        "normalization_mode": hp.normalization_mode,
        "loss_config": loss_cfg,
        "subject_split": {"train": train_subjects, "val": val_subjects},
        "history": history,
    }

    torch.save(payload, final_model_path)

    print(f"Saved final production model to: {final_model_path}")
    return payload


# Notebook 실행 시 기본 인자 사용
final_result = main()
final_result
# Out:
# === Fold 1/50 | Test: Sub1 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 42 (best epoch: 34)
# Fold test metrics: {'accuracy': 0.4219, 'f1': 0.5843, 'loss': 0.1153}
#
# === Fold 2/50 | Test: Sub2 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 22 (best epoch: 14)
# Fold test metrics: {'accuracy': 0.9846, 'f1': 0.9903, 'loss': 0.0224}
#
# === Fold 3/50 | Test: Sub3 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 17 (best epoch: 9)
# Fold test metrics: {'accuracy': 0.5385, 'f1': 0.6591, 'loss': 0.0576}
#
# === Fold 4/50 | Test: Sub4 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 19 (best epoch: 11)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.88, 'loss': 0.0426}
#
# === Fold 5/50 | Test: Sub5 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.4615, 'f1': 0.6316, 'loss': 0.0782}
#
# === Fold 6/50 | Test: Sub6 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.7538, 'f1': 0.8182, 'loss': 0.0424}
#
# === Fold 7/50 | Test: Sub7 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 25 (best epoch: 17)
# Fold test metrics: {'accuracy': 0.8462, 'f1': 0.8936, 'loss': 0.0382}
#
# === Fold 8/50 | Test: Sub8 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 21 (best epoch: 13)
# Fold test metrics: {'accuracy': 0.5692, 'f1': 0.6818, 'loss': 0.0545}
#
# === Fold 9/50 | Test: Sub9 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 20 (best epoch: 12)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.8571, 'loss': 0.0364}
#
# === Fold 10/50 | Test: Sub10 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.9692, 'f1': 0.9811, 'loss': 0.0275}
#
# === Fold 11/50 | Test: Sub11 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 26 (best epoch: 18)
# Fold test metrics: {'accuracy': 0.9385, 'f1': 0.9608, 'loss': 0.0298}
#
# === Fold 12/50 | Test: Sub12 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.6, 'f1': 0.6829, 'loss': 0.053}
#
# === Fold 13/50 | Test: Sub13 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.9219, 'f1': 0.9485, 'loss': 0.0349}
#
# === Fold 14/50 | Test: Sub14 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.4769, 'f1': 0.6458, 'loss': 0.0732}
#
# === Fold 15/50 | Test: Sub15 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.8462, 'f1': 0.902, 'loss': 0.0439}
#
# === Fold 16/50 | Test: Sub16 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 41 (best epoch: 33)
# Fold test metrics: {'accuracy': 0.6094, 'f1': 0.7191, 'loss': 0.0496}
#
# === Fold 17/50 | Test: Sub17 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 17 (best epoch: 9)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.875, 'loss': 0.0378}
#
# === Fold 18/50 | Test: Sub18 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 22 (best epoch: 14)
# Fold test metrics: {'accuracy': 0.9077, 'f1': 0.9388, 'loss': 0.0303}
#
# === Fold 19/50 | Test: Sub20 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.8308, 'f1': 0.8817, 'loss': 0.0362}
#
# === Fold 20/50 | Test: Sub21 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 22 (best epoch: 14)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.8687, 'loss': 0.0415}
#
# === Fold 21/50 | Test: Sub22 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.7385, 'f1': 0.8172, 'loss': 0.041}
#
# === Fold 22/50 | Test: Sub23 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.7656, 'f1': 0.8352, 'loss': 0.0405}
#
# === Fold 23/50 | Test: Sub24 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 20 (best epoch: 12)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0216}
#
# === Fold 24/50 | Test: Sub26 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8696, 'loss': 0.0369}
#
# === Fold 25/50 | Test: Sub27 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.4154, 'f1': 0.4722, 'loss': 0.0542}
#
# === Fold 26/50 | Test: Sub28 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.6769, 'f1': 0.8037, 'loss': 0.0776}
#
# === Fold 27/50 | Test: Sub29 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 22 (best epoch: 14)
# Fold test metrics: {'accuracy': 0.4923, 'f1': 0.6118, 'loss': 0.0572}
#
# === Fold 28/50 | Test: Sub30 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8966, 'loss': 0.0585}
#
# === Fold 29/50 | Test: Sub31 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 18 (best epoch: 10)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.029}
#
# === Fold 30/50 | Test: Sub32 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8966, 'loss': 0.0536}
#
# === Fold 31/50 | Test: Sub33 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.4154, 'f1': 0.587, 'loss': 0.0681}
#
# === Fold 32/50 | Test: Sub34 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.8769, 'f1': 0.9167, 'loss': 0.0326}
#
# === Fold 33/50 | Test: Sub35 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.9692, 'f1': 0.9804, 'loss': 0.0261}
#
# === Fold 34/50 | Test: Sub36 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.7969, 'f1': 0.8539, 'loss': 0.0313}
#
# === Fold 35/50 | Test: Sub37 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0297}
#
# === Fold 36/50 | Test: Sub38 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.5077, 'f1': 0.6735, 'loss': 0.08}
#
# === Fold 37/50 | Test: Sub40 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 17 (best epoch: 9)
# Fold test metrics: {'accuracy': 0.6462, 'f1': 0.7473, 'loss': 0.0543}
#
# === Fold 38/50 | Test: Sub41 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.5231, 'f1': 0.6667, 'loss': 0.0638}
#
# === Fold 39/50 | Test: Sub42 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 21 (best epoch: 13)
# Fold test metrics: {'accuracy': 0.3538, 'f1': 0.5, 'loss': 0.0694}
#
# === Fold 40/50 | Test: Sub43 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 33 (best epoch: 25)
# Fold test metrics: {'accuracy': 0.5385, 'f1': 0.6667, 'loss': 0.0581}
#
# === Fold 41/50 | Test: Sub44 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 33 (best epoch: 25)
# Fold test metrics: {'accuracy': 0.5692, 'f1': 0.7021, 'loss': 0.0948}
#
# === Fold 42/50 | Test: Sub45 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.9077, 'f1': 0.9388, 'loss': 0.0347}
#
# === Fold 43/50 | Test: Sub46 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 42 (best epoch: 34)
# Fold test metrics: {'accuracy': 0.7538, 'f1': 0.8222, 'loss': 0.032}
#
# === Fold 44/50 | Test: Sub47 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.7385, 'f1': 0.8211, 'loss': 0.0394}
#
# === Fold 45/50 | Test: Sub48 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 19 (best epoch: 11)
# Fold test metrics: {'accuracy': 0.8923, 'f1': 0.9369, 'loss': 0.048}
#
# === Fold 46/50 | Test: Sub49 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.5538, 'f1': 0.7071, 'loss': 0.0606}
#
# === Fold 47/50 | Test: Sub50 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 41 (best epoch: 33)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8966, 'loss': 0.0552}
#
# === Fold 48/50 | Test: Sub51 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.7692, 'f1': 0.8387, 'loss': 0.0511}
#
# === Fold 49/50 | Test: Sub52 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.9077, 'f1': 0.9388, 'loss': 0.0324}
#
# === Fold 50/50 | Test: Sub53 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.5538, 'f1': 0.7071, 'loss': 0.0621}
#
# === LOSO Training Complete ===
# Saved metadata (hyperparameters + metrics): /home/binghin2/Myproject/Research/CATSA/Train/Only_HR/Save_model/LOSO/hr_1dcnn_transformer_loso_torch_hyperparameters.json
# Saved per-fold best/final checkpoints under LOSO save_dir
# Aggregate mean metrics: {'accuracy': 0.7306, 'precision': 0.8868, 'recall': 0.7579, 'f1': 0.8101, 'loss': 0.0488}
# Aggregate std metrics: {'accuracy': 0.1826, 'precision': 0.1106, 'recall': 0.1747, 'f1': 0.138, 'loss': 0.019}
# === Grand Final HR Training (45/5) ===
# Normalization: subject_zscore
# Loss: focal
# Train subjects (45): ['Sub1', 'Sub3', 'Sub4', 'Sub5', 'Sub6', 'Sub7', 'Sub9', 'Sub10', 'Sub11', 'Sub12', 'Sub13', 'Sub14', 'Sub15', 'Sub16', 'Sub17', 'Sub20', 'Sub21', 'Sub22', 'Sub23', 'Sub24', 'Sub26', 'Sub27', 'Sub28', 'Sub29', 'Sub30', 'Sub31', 'Sub32', 'Sub33', 'Sub34', 'Sub35', 'Sub36', 'Sub37', 'Sub38', 'Sub40', 'Sub41', 'Sub42', 'Sub43', 'Sub45', 'Sub46', 'Sub47', 'Sub48', 'Sub49', 'Sub50', 'Sub52', 'Sub53']
# Val subjects (5): ['Sub2', 'Sub8', 'Sub18', 'Sub44', 'Sub51']
# Early stopping at epoch 20 (best epoch: 12)
# Saved final production model to: /home/binghin2/Myproject/Dataset/Save_model/HR_Grand_Final_Production_Model.pt
# {'model_state_dict': {'pos_embedding': tensor([[[ 0.0014,  0.0004, -0.0117,  ...,  0.0005, -0.0026, -0.0105],
#            [ 0.0116,  0.0034, -0.0188,  ...,  0.0025, -0.0044, -0.0132],
#            [ 0.0091,  0.0014, -0.0096,  ..., -0.0031, -0.0023, -0.0084],
#            ...,
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]]),
#   'cnn.0.weight': tensor([[[ 0.0948,  0.0743, -0.0215,  0.1636, -0.0109]],
#
#           [[ 0.0587, -0.1886,  0.1743,  0.2985, -0.3243]],
#
#           [[ 0.1401, -0.0210,  0.0583,  0.0106,  0.0664]],
#
#           [[-0.0077,  0.1625,  0.0278, -0.1324,  0.1041]],
#
#           [[-0.0779, -0.0081, -0.0007,  0.2352, -0.2013]],
#
#           [[-0.0792, -0.0301, -0.0468,  0.0201, -0.1075]],
#
#           [[ 0.2595, -0.2472,  0.2647,  0.0830, -0.0931]],
#
#           [[ 0.0795,  0.0477,  0.1506,  0.0248, -0.0619]],
#
#           [[ 0.0634, -0.0852,  0.0446,  0.0784,  0.0443]],
#
#           [[-0.1841,  0.2066,  0.0724,  0.2093, -0.2691]],
#
#           [[-0.3205, -0.0999, -0.2624,  0.3837,  0.1704]],
#
#           [[ 0.0929,  0.1139, -0.0084,  0.2564, -0.2391]],
#
#           [[ 0.0659, -0.2681,  0.1676, -0.1182,  0.1726]],
#
#           [[ 0.0006,  0.3901, -0.1595, -0.1589, -0.1446]],
#
#           [[ 0.3773,  0.1332,  0.4034, -0.3738, -0.4462]],
#
#           [[-0.3471, -0.2986,  0.1737,  0.1579,  0.3662]],
#
#           [[-0.1966, -0.2623,  0.2628, -0.1446,  0.3001]],
#
#           [[-0.0528,  0.2921, -0.2573, -0.1424,  0.1760]],
#
#           [[ 0.0930, -0.0906,  0.1748,  0.2414, -0.2339]],
#
#           [[-0.1292,  0.3041, -0.1051, -0.0722, -0.1982]],
#
#           [[-0.0946,  0.0867, -0.0032, -0.0800,  0.0123]],
#
#           [[-0.0414, -0.0486, -0.0184, -0.0784, -0.0559]],
#
#           [[ 0.4495,  0.0912,  0.1395, -0.4097, -0.2848]],
#
#           [[-0.0257,  0.0662, -0.0824,  0.0144, -0.0190]],
#
#           [[ 0.0126, -0.0427, -0.0158, -0.0432, -0.0633]],
#
#           [[-0.0967, -0.0972, -0.1847,  0.2966, -0.0108]],
#
#           [[ 0.2742,  0.0864, -0.3626,  0.2441, -0.1155]],
#
#           [[-0.0033, -0.0336, -0.0954,  0.0013, -0.0126]],
#
#           [[ 0.1457, -0.2613,  0.2524, -0.2230, -0.0436]],
#
#           [[ 0.0503,  0.0188,  0.1510,  0.1713, -0.1822]],
#
#           [[ 0.1335, -0.1767, -0.0384, -0.3254,  0.4161]],
#
#           [[-0.3248,  0.2369,  0.1630,  0.1491, -0.2394]]]),
#   'cnn.0.bias': tensor([ 5.2973e-02, -6.1236e-07, -1.8767e-08, -4.6910e-02,  2.2007e-04,
#            1.8106e-07, -6.1364e-04,  4.2263e-02, -1.4903e-08, -3.4622e-03,
#           -1.6417e-03,  6.3875e-07,  3.7162e-03, -2.7888e-07, -4.3729e-03,
#           -9.4340e-06, -2.2456e-02,  1.8341e-05,  2.6669e-02, -6.0480e-02,
#             0.0314, -0.0480,  0.0235,  0.0519, -0.0061,  0.0959,  0.0124, -0.0026]]),
#   'classifier.3.bias': tensor([0.0522])},
#  'model_name': 'HR_Grand_Final_Production_Model',
#  'created_from': 'HR_LOSO.ipynb',
#  'best_epoch': 12,
#  'best_val_loss': 0.04485569281646839,
#  'device_used_for_training': 'cuda',
#  'hyperparameters': {'random_seed': 42,
#   'val_ratio': 0.1,
#   'min_val_subjects': 4,
#   'max_val_subjects': 5,
#   'window_size': 60,
#   'stride': 10,
#   'batch_size': 64,
#   'epochs': 50,
#   'learning_rate': 0.001,
#   'dropout_rate': 0.3,
#   'weight_decay': 0.0001,
#   'patience': 8,
#   'transformer_heads': 8,
#   'transformer_layers': 2,
#   'transformer_ff_dim': 256,
#   'transformer_dropout': 0.1,
#   'normalization_mode': 'subject_zscore',
#   'loss_name': 'focal',
#   'focal_gamma': 2.0,
#   'focal_alpha': None,
#   'save_model': False,
#   'max_folds': None},
#  'normalization_mode': 'subject_zscore',
#  'loss_config': {'loss_name': 'focal',
#   'pos_weight': 1.0,
#   'focal_gamma': 2.0,
#   'focal_alpha': 0.20041109969167523,
#   'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#  'subject_split': {'train': ['Sub1',
#    'Sub3',
#    'Sub4',
#    'Sub5',
#    'Sub6',
#    'Sub7',
#    'Sub9',
#    'Sub10',
#    'Sub11',
#    'Sub12',
#    'Sub13',
#    'Sub14',
#    'Sub15',
#    'Sub16',
#    'Sub17',
#    'Sub20',
#    'Sub21',
#    'Sub22',
#    'Sub23',
#    'Sub24',
#    'Sub26',
#    'Sub27',
#    'Sub28',
#    'Sub29',
#    'Sub30',
#    'Sub31',
#    'Sub32',
#    'Sub33',
#    'Sub34',
#    'Sub35',
#    'Sub36',
#    'Sub37',
#    'Sub38',
#    'Sub40',
#    'Sub41',
#    'Sub42',
#    'Sub43',
#    'Sub45',
#    'Sub46',
#    'Sub47',
#    'Sub48',
#    'Sub49',
#    'Sub50',
#    'Sub52',
#    'Sub53'],
#   'val': ['Sub2', 'Sub8', 'Sub18', 'Sub44', 'Sub51']},
#  'history': [{'epoch': 1.0,
#    'train_loss': 0.0532719940585239,
#    'val_loss': 0.048232450766059067,
#    'val_accuracy': 0.7784615384615384,
#    'val_f1': 0.854251012145749,
#    'lr': 0.001},
#   {'epoch': 2.0,
#    'train_loss': 0.05077944149343924,
#    'val_loss': 0.04816331396882351,
#    'val_accuracy': 0.6553846153846153,
#    'val_f1': 0.7358490566037735,
#    'lr': 0.001},
#   {'epoch': 3.0,
#    'train_loss': 0.050391958293266675,
#    'val_loss': 0.048173186773291,
#    'val_accuracy': 0.7692307692307693,
#    'val_f1': 0.845360824742268,
#    'lr': 0.001},
#   {'epoch': 4.0,
#    'train_loss': 0.04912505152597947,
#    'val_loss': 0.04827201028855947,
#    'val_accuracy': 0.7846153846153846,
#    'val_f1': 0.8582995951417003,
#    'lr': 0.001},
#   {'epoch': 5.0,
#    'train_loss': 0.04872596711583969,
#    'val_loss': 0.04731939297456008,
#    'val_accuracy': 0.7661538461538462,
#    'val_f1': 0.8416666666666667,
#    'lr': 0.001},
#   {'epoch': 6.0,
#    'train_loss': 0.0491996763293855,
#    'val_loss': 0.04814499132335186,
#    'val_accuracy': 0.7353846153846154,
#    'val_f1': 0.8170212765957447,
#    'lr': 0.001},
#   {'epoch': 7.0,
#    'train_loss': 0.04880127766491534,
#    'val_loss': 0.04699339734820219,
#    'val_accuracy': 0.76,
#    'val_f1': 0.8354430379746836,
#    'lr': 0.001},
#   {'epoch': 8.0,
#    'train_loss': 0.04843653814561484,
#    'val_loss': 0.04816943536011072,
#    'val_accuracy': 0.7753846153846153,
#    'val_f1': 0.8488612836438924,
#    'lr': 0.001},
#   {'epoch': 9.0,
#    'train_loss': 0.04784309997919815,
#    'val_loss': 0.04739714470620339,
#    'val_accuracy': 0.7046153846153846,
#    'val_f1': 0.7857142857142858,
#    'lr': 0.001},
#   {'epoch': 10.0,
#    'train_loss': 0.04891679440435174,
#    'val_loss': 0.04851782491573921,
#    'val_accuracy': 0.7784615384615384,
#    'val_f1': 0.8530612244897958,
#    'lr': 0.001},
#   {'epoch': 11.0,
#    'train_loss': 0.047796237901103295,
#    'val_loss': 0.047845453763237365,
#    'val_accuracy': 0.7815384615384615,
#    'val_f1': 0.8559837728194726,
#    'lr': 0.001},
#   {'epoch': 12.0,
#    'train_loss': 0.04783475404632708,
#    'val_loss': 0.04485569281646839,
#    'val_accuracy': 0.7661538461538462,
#    'val_f1': 0.8396624472573839,
#    'lr': 0.001},
#   {'epoch': 13.0,
#    'train_loss': 0.04764688145924448,
#    'val_loss': 0.046423942097104515,
#    'val_accuracy': 0.7753846153846153,
#    'val_f1': 0.8482328482328483,
#    'lr': 0.001},
#   {'epoch': 14.0,
#    'train_loss': 0.04743960114599867,
#    'val_loss': 0.047442374051763464,
#    'val_accuracy': 0.6953846153846154,
#    'val_f1': 0.7775280898876404,
#    'lr': 0.001},
#   {'epoch': 15.0,
#    'train_loss': 0.04708159579274874,
#    'val_loss': 0.04510419019712852,
#    'val_accuracy': 0.7507692307692307,
#    'val_f1': 0.8265524625267666,
#    'lr': 0.001},
#   {'epoch': 16.0,
#    'train_loss': 0.046773173685819576,
#    'val_loss': 0.046212359672555554,
#    'val_accuracy': 0.7538461538461538,
#    'val_f1': 0.829059829059829,
#    'lr': 0.001},
#   {'epoch': 17.0,
#    'train_loss': 0.04693058051574757,
#    'val_loss': 0.04801808540351116,
#    'val_accuracy': 0.7630769230769231,
#    'val_f1': 0.8493150684931506,
#    'lr': 0.0005},
#   {'epoch': 18.0,
#    'train_loss': 0.04596279393824129,
#    'val_loss': 0.04655168823324717,
#    'val_accuracy': 0.7538461538461538,
#    'val_f1': 0.8312236286919831,
#    'lr': 0.0005},
#   {'epoch': 19.0,
#    'train_loss': 0.04552673894316009,
#    'val_loss': 0.0467561591645846,
#    'val_accuracy': 0.7230769230769231,
#    'val_f1': 0.801762114537445,
#    'lr': 0.0005},
#   {'epoch': 20.0,
#    'train_loss': 0.04554592040930557,
#    'val_loss': 0.04762282229673404,
#    'val_accuracy': 0.7753846153846153,
#    'val_f1': 0.8501026694045174,
#    'lr': 0.0005}]}
