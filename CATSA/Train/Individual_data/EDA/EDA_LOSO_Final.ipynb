# %% [markdown]
# # EDA Grand Final Production Training (45/5)
#
# 이 노트북은 `EDA_LOSO.ipynb`의 함수/클래스를 재사용하여,
# 50명 전체 피험자를 `Train 45 / Val 5`로 분할해 최종 통합 모델을 학습하고 저장합니다.
#
# - 샘플링레이트: `4Hz`
# - 기본 정규화: `subject_zscore`
# - 기본 손실함수: `focal`
# - 저장 경로: `/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/EDA/Save_model/EDA_Grand_Final_Production_Model.pt`

# %%
import argparse
import json
import random
from dataclasses import asdict
from pathlib import Path
from typing import Dict, List, Optional

import numpy as np
import torch


def import_symbols_from_notebook(nb_path: Path, symbols: List[str]) -> Dict[str, object]:
    with nb_path.open("r", encoding="utf-8") as f:
        raw_nb = json.load(f)
    code_cells = [c for c in raw_nb.get("cells", []) if c.get("cell_type") == "code"]
    if len(code_cells) == 0:
        raise RuntimeError(f"No code cells found in {nb_path}")

    namespace: Dict[str, object] = {}
    # EDA_LOSO의 핵심 정의는 1번 코드 셀에 있으므로 그대로 실행해 재사용한다.
    first_source = code_cells[0].get("source", [])
    if isinstance(first_source, list):
        first_source = "".join(first_source)
    exec(first_source, namespace)

    missing = [name for name in symbols if name not in namespace]
    if missing:
        raise RuntimeError(f"Missing symbols from {nb_path.name}: {missing}")

    return {name: namespace[name] for name in symbols}


def build_arg_parser() -> argparse.ArgumentParser:
    parser = argparse.ArgumentParser(description="Train final EDA production model with 45/5 subject split")
    parser.add_argument("--epochs", type=int, default=50)
    parser.add_argument("--batch_size", type=int, default=64)
    parser.add_argument("--lr", type=float, default=0.001)
    parser.add_argument("--norm_mode", type=str, default="subject_zscore", choices=["subject_zscore", "baseline_zscore", "none"])
    parser.add_argument("--loss_name", type=str, default="focal", choices=["focal", "weighted_bce"])
    parser.add_argument("--seed", type=int, default=42)
    return parser


def main(cli_args: Optional[List[str]] = None) -> Dict[str, object]:
    parser = build_arg_parser()
    if cli_args is None:
        args, _ = parser.parse_known_args()
    else:
        args = parser.parse_args(cli_args)

    notebook_dir = Path.cwd()
    loso_nb_path = notebook_dir / "EDA_LOSO.ipynb"
    if not loso_nb_path.exists():
        raise FileNotFoundError(f"Cannot find source notebook: {loso_nb_path}")

    symbols = import_symbols_from_notebook(
        loso_nb_path,
        symbols=[
            "HyperParameters",
            "find_dataset_root",
            "discover_complete_subjects",
            "build_split_arrays",
            "make_loader",
            "Eda1DCNNTransformer",
            "make_criterion",
            "train_one_epoch",
            "evaluate",
            "EDA_SAMPLING_RATE_HZ",
        ],
    )

    HyperParameters = symbols["HyperParameters"]
    find_dataset_root = symbols["find_dataset_root"]
    discover_complete_subjects = symbols["discover_complete_subjects"]
    build_split_arrays = symbols["build_split_arrays"]
    make_loader = symbols["make_loader"]
    Eda1DCNNTransformer = symbols["Eda1DCNNTransformer"]
    make_criterion = symbols["make_criterion"]
    train_one_epoch = symbols["train_one_epoch"]
    evaluate = symbols["evaluate"]
    EDA_SAMPLING_RATE_HZ = int(symbols["EDA_SAMPLING_RATE_HZ"])

    np.random.seed(args.seed)
    random.seed(args.seed)
    torch.manual_seed(args.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(args.seed)

    dataset_root = find_dataset_root()
    all_subjects = discover_complete_subjects(dataset_root)
    if len(all_subjects) < 50:
        raise ValueError(f"Need 50 complete subjects, found {len(all_subjects)}")

    # 요구사항: 전체 50명 기준으로 45/5 split
    all_subjects = sorted(all_subjects, key=lambda x: int(x[3:]))[:50]
    val_subjects = sorted(random.sample(all_subjects, 5), key=lambda x: int(x[3:]))
    train_subjects = sorted([s for s in all_subjects if s not in val_subjects], key=lambda x: int(x[3:]))

    window_seconds = 60
    stride_seconds = 10
    hp = HyperParameters(
        random_seed=args.seed,
        window_size=EDA_SAMPLING_RATE_HZ * window_seconds,
        stride=EDA_SAMPLING_RATE_HZ * stride_seconds,
        batch_size=args.batch_size,
        epochs=args.epochs,
        learning_rate=args.lr,
        dropout_rate=0.3,
        weight_decay=1e-4,
        patience=8,
        transformer_heads=8,
        transformer_layers=2,
        transformer_ff_dim=256,
        transformer_dropout=0.1,
        normalization_mode=args.norm_mode,
        loss_name=args.loss_name,
        focal_gamma=2.0,
        focal_alpha=None,
        save_model=False,
        max_folds=None,
    )

    print("=== Grand Final EDA Training (45/5) ===")
    print(f"Sampling rate: {EDA_SAMPLING_RATE_HZ}Hz")
    print(f"Window/Stride (seconds): {window_seconds}/{stride_seconds}")
    print(f"Window/Stride (samples): {hp.window_size}/{hp.stride}")
    print(f"Normalization: {hp.normalization_mode}")
    print(f"Loss: {hp.loss_name}")
    print(f"Train subjects ({len(train_subjects)}): {train_subjects}")
    print(f"Val subjects ({len(val_subjects)}): {val_subjects}")

    x_train, y_train = build_split_arrays(
        dataset_root,
        train_subjects,
        hp.window_size,
        hp.stride,
        normalization_mode=hp.normalization_mode,
    )
    x_val, y_val = build_split_arrays(
        dataset_root,
        val_subjects,
        hp.window_size,
        hp.stride,
        normalization_mode=hp.normalization_mode,
    )

    train_loader = make_loader(x_train, y_train, hp.batch_size, shuffle=True)
    val_loader = make_loader(x_val, y_val, hp.batch_size, shuffle=False)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = Eda1DCNNTransformer(hp=hp).to(device)
    criterion, loss_cfg = make_criterion(y_train, hp, device)
    optimizer = torch.optim.Adam(model.parameters(), lr=hp.learning_rate, weight_decay=hp.weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=4)

    best_val_loss = float("inf")
    best_epoch = -1
    wait = 0
    best_final_state = None
    history: List[Dict[str, float]] = []

    for epoch in range(1, hp.epochs + 1):
        train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
        val_metrics = evaluate(model, val_loader, criterion, device)
        scheduler.step(val_metrics["loss"])

        history.append(
            {
                "epoch": float(epoch),
                "train_loss": float(train_loss),
                "val_loss": float(val_metrics["loss"]),
                "val_accuracy": float(val_metrics["accuracy"]),
                "val_f1": float(val_metrics["f1"]),
                "lr": float(optimizer.param_groups[0]["lr"]),
            }
        )

        if val_metrics["loss"] < best_val_loss:
            best_val_loss = val_metrics["loss"]
            best_epoch = epoch
            wait = 0
            best_final_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            wait += 1
            if wait >= hp.patience:
                print(f"Early stopping at epoch {epoch} (best epoch: {best_epoch})")
                break

    if best_final_state is None:
        raise RuntimeError("best_final_state is None. Training did not produce a valid checkpoint.")

    save_dir = Path("/home/binghin2/Myproject/Research/CATSA/Train/Individual_data/EDA/Save_model")
    final_model_path = save_dir / "EDA_Grand_Final_Production_Model.pt"
    final_model_path.parent.mkdir(parents=True, exist_ok=True)

    payload = {
        "model_state_dict": best_final_state,
        "model_name": "EDA_Grand_Final_Production_Model",
        "created_from": "EDA_LOSO.ipynb",
        "sampling_rate_hz": EDA_SAMPLING_RATE_HZ,
        "window_seconds": int(window_seconds),
        "stride_seconds": int(stride_seconds),
        "best_epoch": int(best_epoch),
        "best_val_loss": float(best_val_loss),
        "device_used_for_training": str(device),
        "hyperparameters": asdict(hp),
        "normalization_mode": hp.normalization_mode,
        "loss_config": loss_cfg,
        "subject_split": {"train": train_subjects, "val": val_subjects},
        "history": history,
    }

    torch.save(payload, final_model_path)

    print(f"Saved final production model to: {final_model_path}")
    return payload


# Notebook 실행 시 기본 인자 사용
final_result = main()
final_result
# Out:
# === Fold 1/50 | Test: Sub1 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8696, 'loss': 0.0285}
#
# === Fold 2/50 | Test: Sub2 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.8615, 'f1': 0.9053, 'loss': 0.028}
#
# === Fold 3/50 | Test: Sub3 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 18 (best epoch: 10)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.8571, 'loss': 0.0443}
#
# === Fold 4/50 | Test: Sub4 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 31 (best epoch: 23)
# Fold test metrics: {'accuracy': 0.9231, 'f1': 0.9495, 'loss': 0.0134}
#
# === Fold 5/50 | Test: Sub5 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.8615, 'f1': 0.9053, 'loss': 0.042}
#
# === Fold 6/50 | Test: Sub6 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.9077, 'f1': 0.9388, 'loss': 0.0215}
#
# === Fold 7/50 | Test: Sub7 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.7231, 'f1': 0.82, 'loss': 0.078}
#
# === Fold 8/50 | Test: Sub8 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 21 (best epoch: 13)
# Fold test metrics: {'accuracy': 0.6154, 'f1': 0.7573, 'loss': 0.0546}
#
# === Fold 9/50 | Test: Sub9 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.7385, 'f1': 0.8211, 'loss': 0.0396}
#
# === Fold 10/50 | Test: Sub10 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.9692, 'f1': 0.9811, 'loss': 0.0231}
#
# === Fold 11/50 | Test: Sub11 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.4923, 'f1': 0.6598, 'loss': 0.0823}
#
# === Fold 12/50 | Test: Sub12 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.8889, 'loss': 0.0522}
#
# === Fold 13/50 | Test: Sub13 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.9538, 'f1': 0.9703, 'loss': 0.0185}
#
# === Fold 14/50 | Test: Sub14 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 32 (best epoch: 24)
# Fold test metrics: {'accuracy': 0.7385, 'f1': 0.8172, 'loss': 0.0415}
#
# === Fold 15/50 | Test: Sub15 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0226}
#
# === Fold 16/50 | Test: Sub16 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.9077, 'f1': 0.9388, 'loss': 0.0216}
#
# === Fold 17/50 | Test: Sub17 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.8462, 'f1': 0.9123, 'loss': 0.0783}
#
# === Fold 18/50 | Test: Sub18 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 24 (best epoch: 16)
# Fold test metrics: {'accuracy': 0.8615, 'f1': 0.9053, 'loss': 0.0352}
#
# === Fold 19/50 | Test: Sub20 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0162}
#
# === Fold 20/50 | Test: Sub21 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.9231, 'f1': 0.9495, 'loss': 0.0182}
#
# === Fold 21/50 | Test: Sub22 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.9385, 'f1': 0.96, 'loss': 0.0153}
#
# === Fold 22/50 | Test: Sub23 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.4462, 'f1': 0.617, 'loss': 0.1859}
#
# === Fold 23/50 | Test: Sub24 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 9 (best epoch: 1)
# Fold test metrics: {'accuracy': 0.7385, 'f1': 0.809, 'loss': 0.0386}
#
# === Fold 24/50 | Test: Sub26 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 11 (best epoch: 3)
# Fold test metrics: {'accuracy': 0.8615, 'f1': 0.9053, 'loss': 0.0231}
#
# === Fold 25/50 | Test: Sub27 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.8, 'f1': 0.866, 'loss': 0.0445}
#
# === Fold 26/50 | Test: Sub28 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.7385, 'f1': 0.835, 'loss': 0.0615}
#
# === Fold 27/50 | Test: Sub29 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.9538, 'f1': 0.9703, 'loss': 0.0233}
#
# === Fold 28/50 | Test: Sub30 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 35 (best epoch: 27)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8966, 'loss': 0.0597}
#
# === Fold 29/50 | Test: Sub31 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.9385, 'f1': 0.96, 'loss': 0.0189}
#
# === Fold 30/50 | Test: Sub32 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8966, 'loss': 0.0633}
#
# === Fold 31/50 | Test: Sub33 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.9385, 'f1': 0.96, 'loss': 0.0148}
#
# === Fold 32/50 | Test: Sub34 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 26 (best epoch: 18)
# Fold test metrics: {'accuracy': 0.9692, 'f1': 0.9804, 'loss': 0.0172}
#
# === Fold 33/50 | Test: Sub35 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.6923, 'f1': 0.7727, 'loss': 0.0407}
#
# === Fold 34/50 | Test: Sub36 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 16 (best epoch: 8)
# Fold test metrics: {'accuracy': 0.7692, 'f1': 0.8315, 'loss': 0.0396}
#
# === Fold 35/50 | Test: Sub37 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0135}
#
# === Fold 36/50 | Test: Sub38 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 10 (best epoch: 2)
# Fold test metrics: {'accuracy': 0.9846, 'f1': 0.9903, 'loss': 0.0196}
#
# === Fold 37/50 | Test: Sub40 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.6, 'f1': 0.75, 'loss': 0.0936}
#
# === Fold 38/50 | Test: Sub41 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 23 (best epoch: 15)
# Fold test metrics: {'accuracy': 0.9385, 'f1': 0.96, 'loss': 0.012}
#
# === Fold 39/50 | Test: Sub42 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.0159}
#
# === Fold 40/50 | Test: Sub43 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 1.0, 'f1': 1.0, 'loss': 0.032}
#
# === Fold 41/50 | Test: Sub44 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.8769, 'f1': 0.9286, 'loss': 0.0454}
#
# === Fold 42/50 | Test: Sub45 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 21 (best epoch: 13)
# Fold test metrics: {'accuracy': 0.9538, 'f1': 0.9703, 'loss': 0.0165}
#
# === Fold 43/50 | Test: Sub46 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 29 (best epoch: 21)
# Fold test metrics: {'accuracy': 0.9538, 'f1': 0.9703, 'loss': 0.0179}
#
# === Fold 44/50 | Test: Sub47 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 31 (best epoch: 23)
# Fold test metrics: {'accuracy': 0.6, 'f1': 0.75, 'loss': 0.0925}
#
# === Fold 45/50 | Test: Sub48 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 15 (best epoch: 7)
# Fold test metrics: {'accuracy': 0.5846, 'f1': 0.6494, 'loss': 0.045}
#
# === Fold 46/50 | Test: Sub49 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 14 (best epoch: 6)
# Fold test metrics: {'accuracy': 0.6, 'f1': 0.75, 'loss': 0.1002}
#
# === Fold 47/50 | Test: Sub50 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.8154, 'f1': 0.8966, 'loss': 0.0615}
#
# === Fold 48/50 | Test: Sub51 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 13 (best epoch: 5)
# Fold test metrics: {'accuracy': 0.6154, 'f1': 0.7573, 'loss': 0.0843}
#
# === Fold 49/50 | Test: Sub52 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 21 (best epoch: 13)
# Fold test metrics: {'accuracy': 0.9231, 'f1': 0.9495, 'loss': 0.0173}
#
# === Fold 50/50 | Test: Sub53 ===
# Train subjects: 44, Val subjects: 5, Test subjects: 1
# Early stopping at epoch 12 (best epoch: 4)
# Fold test metrics: {'accuracy': 0.9692, 'f1': 0.9804, 'loss': 0.0127}
#
# === LOSO Training Complete ===
# Saved metadata (hyperparameters + metrics): /home/binghin2/Myproject/Research/CATSA/Train/Individual_data/EDA/Save_model/eda_1dcnn_transformer_loso_torch_hyperparameters.json
# Saved per-fold best/final checkpoints under LOSO save_dir
# Aggregate mean metrics: {'accuracy': 0.8314, 'precision': 0.9294, 'recall': 0.8608, 'f1': 0.8882, 'loss': 0.0417}
# Aggregate std metrics: {'accuracy': 0.143, 'precision': 0.0987, 'recall': 0.1289, 'f1': 0.0982, 'loss': 0.0319}
# === Grand Final EDA Training (45/5) ===
# Sampling rate: 4Hz
# Window/Stride (seconds): 60/10
# Window/Stride (samples): 240/40
# Normalization: subject_zscore
# Loss: focal
# Train subjects (45): ['Sub1', 'Sub3', 'Sub4', 'Sub5', 'Sub6', 'Sub7', 'Sub9', 'Sub10', 'Sub11', 'Sub12', 'Sub13', 'Sub14', 'Sub15', 'Sub16', 'Sub17', 'Sub20', 'Sub21', 'Sub22', 'Sub23', 'Sub24', 'Sub26', 'Sub27', 'Sub28', 'Sub29', 'Sub30', 'Sub31', 'Sub32', 'Sub33', 'Sub34', 'Sub35', 'Sub36', 'Sub37', 'Sub38', 'Sub40', 'Sub41', 'Sub42', 'Sub43', 'Sub45', 'Sub46', 'Sub47', 'Sub48', 'Sub49', 'Sub50', 'Sub52', 'Sub53']
# Val subjects (5): ['Sub2', 'Sub8', 'Sub18', 'Sub44', 'Sub51']
# Early stopping at epoch 11 (best epoch: 3)
# Saved final production model to: /home/binghin2/Myproject/Research/CATSA/Train/Individual_data/EDA/Save_model/EDA_Grand_Final_Production_Model.pt
# {'model_state_dict': {'pos_embedding': tensor([[[-0.0066,  0.0027, -0.0028,  ..., -0.0087,  0.0004, -0.0001],
#            [-0.0074,  0.0041, -0.0024,  ..., -0.0062,  0.0016, -0.0013],
#            [-0.0065,  0.0044, -0.0027,  ..., -0.0055,  0.0024, -0.0045],
#            ...,
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]]),
#   'cnn.0.weight': tensor([[[ 0.2415,  0.2635, -0.0564,  0.3107, -0.0486]],
#
#           [[ 0.0888, -0.2032,  0.2516,  0.3809, -0.3089]],
#
#           [[ 0.2888,  0.0504,  0.2518,  0.0346,  0.1430]],
#
#           [[-0.0386,  0.2779,  0.0793, -0.1744,  0.1208]],
#
#           [[-0.1668, -0.0852, -0.1451,  0.2088, -0.2489]],
#
#           [[-0.1101, -0.0582, -0.1589, -0.0151, -0.3184]],
#
#           [[ 0.3626, -0.3603,  0.3222,  0.0778, -0.1275]],
#
#           [[ 0.1933,  0.0531,  0.2683,  0.0533, -0.1027]],
#
#           [[ 0.0914, -0.0739,  0.1271,  0.2810,  0.1553]],
#
#           [[-0.1875,  0.2622,  0.0872,  0.2309, -0.2597]],
#
#           [[-0.3537, -0.1179, -0.2716,  0.3585,  0.1511]],
#
#           [[ 0.1648,  0.1133, -0.0041,  0.3117, -0.2862]],
#
#           [[ 0.0241, -0.2876,  0.1447, -0.1304,  0.1523]],
#
#           [[-0.0873,  0.3314, -0.2408, -0.2318, -0.2275]],
#
#           [[ 0.3932,  0.1429,  0.4178, -0.3667, -0.4428]],
#
#           [[-0.3580, -0.3088,  0.1707,  0.1507,  0.3615]],
#
#           [[-0.2122, -0.2788,  0.2475, -0.1535,  0.2870]],
#
#           [[-0.1057,  0.2272, -0.3246, -0.2028,  0.1251]],
#
#           [[ 0.0831, -0.1110,  0.2390,  0.2840, -0.3196]],
#
#           [[-0.1919,  0.3532, -0.1356, -0.1438, -0.3561]],
#
#           [[-0.1861,  0.0766, -0.0754, -0.2305,  0.0072]],
#
#           [[-0.1900, -0.2519, -0.1326, -0.2639, -0.1650]],
#
#           [[ 0.4375,  0.0760,  0.1291, -0.4242, -0.3016]],
#
#           [[-0.0742,  0.0381, -0.2720, -0.1029, -0.1599]],
#
#           [[ 0.0045, -0.0887, -0.0342, -0.1774, -0.1929]],
#           -9.9582e-03, -9.4007e-03,  2.3712e-03, -1.3967e-02, -1.1785e-02,
#           -8.9890e-03, -2.5750e-03,  1.3521e-02, -2.5876e-03]),
#   'cnn.5.running_mean': tensor([-0.6727, -0.2962, -0.5295, -0.5102, -0.1889, -0.5846, -0.6623, -0.0250,
#           -0.0642, -0.6756, -0.1399, -0.6498, -0.1058, -0.6815,  0.2556,  0.1759,
#            0.0059,  0.6055,  0.8173, -0.5570, -0.5889, -0.6781,  0.7909,  0.0460,
#           -0.0319,  0.2560, -0.6805, -0.7627,  0.0552,  0.3668,  0.7482,  0.5192,
#           -0.4725,  0.8718,  0.0769,  0.2142, -0.7386, -0.6539,  0.0767,  0.5119,
#            0.6440, -0.1323,  0.7518, -0.0920,  0.3072,  0.5073,  0.1236, -0.1984,
#           -0.5387,  0.8137,  0.7468,  0.3839, -0.0372, -0.7028,  0.5840,  0.0160,
#            0.4433, -0.2013,  0.3038,  0.5502,  0.3339, -0.1790, -0.6035, -0.5417]),
#   'cnn.5.running_var': tensor([0.3541, 0.1834, 0.4856, 0.3401, 0.0684, 0.3966, 0.5119, 0.2987, 0.2071,
#           0.5100, 0.4739, 0.3372, 0.3752, 0.3528, 0.3219, 0.3071, 0.2573, 0.2595,
#           0.4079, 0.2169, 0.4140, 0.4888, 0.3705, 0.4113, 0.1584, 0.0759, 0.5868,
#           0.4659, 0.2424, 0.1025, 0.2907, 0.3257, 0.2152, 0.4407, 0.1261, 0.1248,
#           0.5839, 0.3965, 0.0690, 0.2767, 0.2478, 0.0883, 0.3223, 0.2744, 0.3717,
#           0.2385, 0.2701, 0.1918, 0.4079, 0.3933, 0.3298, 0.2077, 0.3211, 0.6080,
#           0.1812, 0.3767, 0.2239, 0.5495, 0.2760, 0.2613, 0.4084, 0.4733, 0.3891,
#           0.2696]),
#   'cnn.5.num_batches_tracked': tensor(138),
#   'cnn.8.weight': tensor([[[ 0.0687, -0.0166,  0.0228],
#            [ 0.0110,  0.0518,  0.0377],
#            [ 0.0030,  0.0435,  0.0020],
#            ...,
#            [-0.0642, -0.0008, -0.0670],
#            [ 0.0403, -0.0670, -0.0147],
#            [ 0.0709, -0.0177, -0.0337]],
#
#           [[ 0.0708, -0.0270,  0.0236],
#            [ 0.0324,  0.0123, -0.0535],
#            [ 0.0566,  0.0275, -0.0473],
#            ...,
#            [-0.0303, -0.0594, -0.0322],
#            [ 0.0045,  0.0697,  0.0487],
#            [ 0.0141, -0.0640,  0.0500]],
#
#           [[ 0.0510, -0.0277,  0.0315],
#            [-0.0624, -0.0385, -0.0246],
#            [-0.0708, -0.0117,  0.0069],
#            ...,
#            [ 0.0069, -0.0656,  0.0317],
#            [ 0.0174,  0.0007,  0.0568],
#            [-0.0144,  0.0246,  0.0341]],
#
#           ...,
#
#           [[ 0.0531,  0.0228, -0.0470],
#            [ 0.0122, -0.0375, -0.0149],
#            [-0.0424,  0.0312, -0.0416],
#            ...,
#            [-0.0303, -0.0102, -0.0500],
#            [ 0.0024,  0.0365,  0.0467],
#           -1.1533e-02, -8.2392e-05,  6.3172e-02,  5.6871e-02, -6.8803e-02,
#            6.8669e-02, -6.9170e-02, -3.7730e-02, -7.3426e-02, -2.5572e-02,
#           -1.8980e-02, -7.6828e-02, -5.6958e-02, -1.9750e-02,  6.1822e-02,
#            7.2781e-02,  4.1028e-02, -5.4197e-02,  4.4305e-02, -6.8765e-02,
#            2.6904e-02,  6.6882e-03,  6.8436e-02, -3.4884e-02, -4.4373e-02,
#            3.5199e-02,  8.1639e-02,  3.4141e-02, -2.8639e-02, -8.4066e-02,
#           -3.4068e-02,  1.7725e-02, -9.0251e-02,  3.8587e-05,  1.7900e-02,
#           -6.1853e-02,  4.2565e-03,  2.8887e-02, -7.6030e-02, -3.8944e-02,
#           -1.6196e-02, -4.5473e-02, -2.1648e-02, -1.6914e-02]),
#   'classifier.3.weight': tensor([[-0.0067,  0.1114,  0.0400,  0.0922,  0.0634,  0.0567, -0.0877,  0.0069,
#             0.0068, -0.0956,  0.0724, -0.0490,  0.0813,  0.0095,  0.1145,  0.0696,
#             0.0058,  0.0798,  0.0911,  0.1096,  0.0274, -0.0003, -0.0475, -0.0626,
#            -0.0902, -0.0250, -0.0580, -0.0087,  0.1110, -0.0641,  0.0773,  0.0669,
#             0.0406,  0.0690,  0.0945,  0.0983,  0.0353,  0.0147, -0.1041,  0.0423,
#            -0.0682,  0.0261, -0.0591, -0.0840, -0.0399, -0.0576, -0.1181, -0.0371,
#             0.0384,  0.0983,  0.0437,  0.0628,  0.0858,  0.0049,  0.0899,  0.0764,
#             0.0206, -0.0592,  0.0036,  0.0923,  0.0267,  0.0964,  0.0132,  0.0261]]),
#   'classifier.3.bias': tensor([0.0485])},
#  'model_name': 'EDA_Grand_Final_Production_Model',
#  'created_from': 'EDA_LOSO.ipynb',
#  'sampling_rate_hz': 4,
#  'window_seconds': 60,
#  'stride_seconds': 10,
#  'best_epoch': 3,
#  'best_val_loss': 0.042331859927911025,
#  'device_used_for_training': 'cuda',
#  'hyperparameters': {'random_seed': 42,
#   'val_ratio': 0.1,
#   'min_val_subjects': 4,
#   'max_val_subjects': 5,
#   'window_size': 240,
#   'stride': 40,
#   'batch_size': 64,
#   'epochs': 50,
#   'learning_rate': 0.001,
#   'dropout_rate': 0.3,
#   'weight_decay': 0.0001,
#   'patience': 8,
#   'transformer_heads': 8,
#   'transformer_layers': 2,
#   'transformer_ff_dim': 256,
#   'transformer_dropout': 0.1,
#   'normalization_mode': 'subject_zscore',
#   'loss_name': 'focal',
#   'focal_gamma': 2.0,
#   'focal_alpha': None,
#   'save_model': False,
#   'max_folds': None},
#  'normalization_mode': 'subject_zscore',
#  'loss_config': {'loss_name': 'focal',
#   'pos_weight': 1.0,
#   'focal_gamma': 2.0,
#   'focal_alpha': 0.2,
#   'weighting_note': 'Focal uses alpha only to avoid duplicate class weighting'},
#  'subject_split': {'train': ['Sub1',
#    'Sub3',
#    'Sub4',
#    'Sub5',
#    'Sub6',
#    'Sub7',
#    'Sub9',
#    'Sub10',
#    'Sub11',
#    'Sub12',
#    'Sub13',
#    'Sub14',
#    'Sub15',
#    'Sub16',
#    'Sub17',
#    'Sub20',
#    'Sub21',
#    'Sub22',
#    'Sub23',
#    'Sub24',
#    'Sub26',
#    'Sub27',
#    'Sub28',
#    'Sub29',
#    'Sub30',
#    'Sub31',
#    'Sub32',
#    'Sub33',
#    'Sub34',
#    'Sub35',
#    'Sub36',
#    'Sub37',
#    'Sub38',
#    'Sub40',
#    'Sub41',
#    'Sub42',
#    'Sub43',
#    'Sub45',
#    'Sub46',
#    'Sub47',
#    'Sub48',
#    'Sub49',
#    'Sub50',
#    'Sub52',
#    'Sub53'],
#   'val': ['Sub2', 'Sub8', 'Sub18', 'Sub44', 'Sub51']},
#  'history': [{'epoch': 1.0,
#    'train_loss': 0.04343348984152843,
#    'val_loss': 0.04543039083480835,
#    'val_accuracy': 0.7815384615384615,
#    'val_f1': 0.8565656565656565,
#    'lr': 0.001},
#   {'epoch': 2.0,
#    'train_loss': 0.03954862602500834,
#    'val_loss': 0.04979283917408723,
#    'val_accuracy': 0.7323076923076923,
#    'val_f1': 0.827037773359841,
#    'lr': 0.001},
#   {'epoch': 3.0,
#    'train_loss': 0.03882314403724467,
#    'val_loss': 0.042331859927911025,
#    'val_accuracy': 0.7784615384615384,
#    'val_f1': 0.8506224066390041,
#    'lr': 0.001},
#   {'epoch': 4.0,
#    'train_loss': 0.0394437345645876,
#    'val_loss': 0.0462778256718929,
#    'val_accuracy': 0.7630769230769231,
#    'val_f1': 0.8487229862475442,
#    'lr': 0.001},
#   {'epoch': 5.0,
#    'train_loss': 0.03961585836532788,
#    'val_loss': 0.04553449830183616,
#    'val_accuracy': 0.7692307692307693,
#    'val_f1': 0.8502994011976048,
#    'lr': 0.001},
#   {'epoch': 6.0,
#    'train_loss': 0.038811396481389676,
#    'val_loss': 0.046889183016923755,
#    'val_accuracy': 0.7692307692307693,
#    'val_f1': 0.8508946322067594,
#    'lr': 0.001},
#   {'epoch': 7.0,
#    'train_loss': 0.037938573371905544,
#    'val_loss': 0.04928321476166065,
#    'val_accuracy': 0.76,
#    'val_f1': 0.844621513944223,
#    'lr': 0.001},
#   {'epoch': 8.0,
#    'train_loss': 0.04004472895183115,
#    'val_loss': 0.04540934929480919,
#    'val_accuracy': 0.76,
#    'val_f1': 0.8464566929133859,
#    'lr': 0.0005},
#   {'epoch': 9.0,
#    'train_loss': 0.036984358119786294,
#    'val_loss': 0.04450648305507807,
#    'val_accuracy': 0.7569230769230769,
#    'val_f1': 0.8416833667334669,
#    'lr': 0.0005},
#   {'epoch': 10.0,
#    'train_loss': 0.03677525517013338,
#    'val_loss': 0.045567014446625344,
#    'val_accuracy': 0.7661538461538462,
#    'val_f1': 0.8455284552845529,
#    'lr': 0.0005},
#   {'epoch': 11.0,
#    'train_loss': 0.03759073559035603,
#    'val_loss': 0.04549166752741887,
#    'val_accuracy': 0.7569230769230769,
#    'val_f1': 0.8441814595660749,
#    'lr': 0.0005}]}
